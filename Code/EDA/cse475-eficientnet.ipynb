# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1306.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1466.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1410.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1479.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1689.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1818.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1721.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1548.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1812.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1402.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1236.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1627.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1724.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1895.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1703.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1908.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1242.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1460.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1594.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1375.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1310.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1522.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1424.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1816.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1448.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1798.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1736.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1801.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1754.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1456.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1825.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1616.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1469.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1644.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1370.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1833.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1386.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1187.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1563.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1305.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1752.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1543.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1186.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1585.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1727.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1541.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1431.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1605.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1731.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1657.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1494.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1443.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1811.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1325.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1912.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1512.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1673.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1806.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1276.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1782.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1407.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1176.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1339.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1409.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1857.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1316.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1870.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1355.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1571.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1753.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1786.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1354.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1793.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1913.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1546.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1317.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1421.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1502.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1351.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1221.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1649.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1534.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1206.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1879.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1866.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1702.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1862.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1588.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1178.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1734.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1320.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1601.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1620.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1600.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1248.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1615.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1438.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1656.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1202.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1858.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1664.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1604.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1623.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1845.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1678.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1538.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1300.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1708.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1861.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1720.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1761.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1185.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1454.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1850.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1229.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1789.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1712.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1595.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1791.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1225.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1869.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1250.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1177.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1471.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1768.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1779.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1530.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1686.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1246.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1343.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1701.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1371.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1182.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1804.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1591.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1439.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1863.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1788.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1628.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1554.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1909.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1435.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1593.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1358.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1462.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1447.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1442.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1872.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1389.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1860.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1374.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1453.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1790.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1778.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1364.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1349.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1400.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1558.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1396.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1733.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1380.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1547.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1333.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1587.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1193.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1170.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1294.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1268.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1328.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1854.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1211.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1851.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1639.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1220.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1725.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1263.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1227.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1222.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1766.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1501.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1821.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1799.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1228.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1319.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1506.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1730.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1797.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1481.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1397.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1881.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1817.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1687.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1652.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1525.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1301.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1271.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1427.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1477.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1867.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1387.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1342.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1792.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1634.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1774.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1589.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1174.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1181.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1321.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1335.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1669.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1847.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1513.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1820.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1485.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1490.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1259.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1518.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1743.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1293.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1608.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1794.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1813.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1444.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1278.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1696.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1750.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1353.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1884.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1356.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1480.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1539.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1814.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1849.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1737.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1617.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1577.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1536.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1289.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1232.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1488.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1831.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1392.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1511.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1235.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1338.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1882.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1775.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1258.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1449.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1852.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1662.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1529.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1422.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1272.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1401.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1885.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1905.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1326.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1507.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1683.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1191.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1621.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1590.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1900.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1519.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1446.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1318.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1243.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1457.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1646.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1751.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1474.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1209.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1188.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1655.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1210.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1567.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1728.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1413.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1532.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1674.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1420.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1643.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1197.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1758.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1552.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1491.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1403.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1910.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1205.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1575.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1390.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1715.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1398.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1844.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1350.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1379.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1451.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1429.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1815.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1796.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1455.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1599.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1393.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1667.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1517.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1770.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1693.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1893.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1680.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1629.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1266.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1695.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1368.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1357.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1441.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1584.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1486.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1264.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1826.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1835.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1213.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1376.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1545.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1323.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1489.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1576.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1698.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1363.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1780.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1824.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1868.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1499.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1341.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1597.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1787.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1172.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1497.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1640.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1183.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1903.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1764.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1549.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1478.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1372.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1234.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1384.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1412.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1894.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1688.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1800.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1495.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1672.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1395.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1215.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1783.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1675.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1853.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1551.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1416.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1757.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1245.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1411.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1880.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1432.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1415.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1556.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1555.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1476.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1496.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1273.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1212.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1201.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1681.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1648.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1418.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1378.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1864.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1706.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1878.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1284.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1839.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1726.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1828.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1544.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1784.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1700.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1336.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1524.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1805.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1508.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1846.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1492.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1670.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1503.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1679.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1832.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1288.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1619.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1729.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1361.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1607.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1459.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1385.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1514.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1340.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1304.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1405.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1440.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1606.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1425.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1309.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1468.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1238.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1299.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1638.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1365.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1631.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1838.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1281.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1746.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1217.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1653.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1216.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1347.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1714.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1275.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1876.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1198.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1809.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1841.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1654.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1277.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1755.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1521.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1684.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1483.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1330.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1840.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1614.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1890.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1461.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1463.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1819.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1658.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1763.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1557.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1255.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1765.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1856.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1865.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1907.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1394.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1570.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1723.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1253.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1911.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1645.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1682.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1344.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1889.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1795.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1697.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1195.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1184.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1346.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1419.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1848.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1509.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1296.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1417.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1437.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1360.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1560.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1573.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1175.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1888.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1261.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1239.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1603.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1692.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1581.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1523.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1592.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1704.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1540.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1663.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1612.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1373.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1668.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1542.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1762.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1659.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1169.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1741.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1303.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1334.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1596.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1233.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1677.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1711.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1537.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1482.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1223.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1760.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1699.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1377.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1744.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1279.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1637.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1230.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1436.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1196.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1515.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1262.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1781.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1705.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1527.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1493.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1578.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1635.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1694.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1887.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1722.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1842.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1307.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1626.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1747.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1382.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1498.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1282.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1257.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1464.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1475.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1633.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1252.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1231.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1569.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1270.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1651.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1345.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1871.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1470.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1719.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1312.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1647.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1553.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1660.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1433.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1388.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1260.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1610.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1314.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1580.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1383.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1173.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1280.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1892.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1505.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1203.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1526.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1568.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1583.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1666.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1369.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1564.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1735.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1199.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1452.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1254.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1897.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1244.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1773.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1717.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1877.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1624.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1237.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1327.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1579.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1802.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1622.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1204.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1504.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1898.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1332.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1487.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1829.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1886.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1241.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1748.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1240.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1785.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1618.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1465.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1598.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1671.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1837.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1322.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1219.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1189.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1738.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1329.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1709.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1636.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1423.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1902.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1859.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1875.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1745.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1586.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1179.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1516.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1348.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1190.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1896.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1207.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1661.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1807.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1224.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1559.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1707.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1904.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1256.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1408.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1218.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1249.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1359.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1535.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1550.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1574.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1406.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1247.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1565.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1308.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1771.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1528.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1362.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1298.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1891.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1777.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1352.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1315.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1337.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1500.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1767.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1713.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1810.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1283.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1367.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1685.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1665.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1625.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1710.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1650.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1582.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1458.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1286.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1192.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1291.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1331.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1404.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1691.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1613.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1749.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1285.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1226.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1630.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1834.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1274.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1399.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1883.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1520.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1609.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1562.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1472.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1739.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1391.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1297.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1267.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1484.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1194.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1776.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1769.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1450.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1836.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1302.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1690.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1642.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1718.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1251.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1803.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1445.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1510.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1531.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1208.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1180.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1265.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1602.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1414.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1676.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1572.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1467.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1324.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1901.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/infacted/IMG_1772.JPG
# ...
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610175248.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG_20230612_130817.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230807183840.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG_20230612_130815.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610180441.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610175941.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610181902.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610175843.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG_1990.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230807183156.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610182935.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610180249.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG-20230529-WA0021.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610175325.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG_2057.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610182347.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG_2065.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610181114.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610181501.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610181000.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610182620.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610182553.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610181829.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610181548.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610182958.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230807183118.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610180218.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610180743.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG_2016.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230807183444.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG_20230612_130000.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610181049.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG-20230611-WA0030.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG_1979.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610182352.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG_2021.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230807183350.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230807183142.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610182732.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG_1973.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG_1992.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG_20230616_153500.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610175355.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG_20230612_130011.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG_2002.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG_2047.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610182612.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG-20230529-WA0058.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230807183254.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG_1995.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610180154.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG-20230529-WA0030.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610183110.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG_20230612_130319.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610175720.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610180401.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG_3228.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610181237.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230807183517.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG-20230529-WA0022.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610182246.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG-20230529-WA0040.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG-20230611-WA0034.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610181153.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610182550.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG-20230529-WA0033.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610180803.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610181600.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG-20230611-WA0009.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610183047.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610182341.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG_2004.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG_2094.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610182711.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG-20230529-WA0020.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610181125.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610182932.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG_2092.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230807183129.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG_1989.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG_2070.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610180414.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230807183944.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610180335.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG-20230529-WA0043.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610181341.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230807183248.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610182556.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG_20230612_130055.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG-20230529-WA0039.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG_1980.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG_2095.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG_2005.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610180720.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG_2066.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610180822.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610175439.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG_20230612_125907.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230807183123.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230807183242.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610175401.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610180423.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG_20230612_130740.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG-20230529-WA0046.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG_2023.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610181241.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610175859.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610175939.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230807183922.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230807183559.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610183052.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230807183331.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610180340.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG-20230529-WA0038.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610175513.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG-20230611-WA0025.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230807183638.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230807183101.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG_1975.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610180232.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG_1999.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610182635.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG-20230529-WA0000.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG_1969.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG_3231.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG_1972.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230807183739.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610180815.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610182729.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230807183251.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG-20230529-WA0067.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610181120.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230807183159.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG-20230611-WA0007.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG_3240.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG-20230529-WA0045.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610180122.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230807183520.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610181353.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230807183231.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG_20230612_125915.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG-20230611-WA0008.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230807183145.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230807183622.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG_1968.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG_2058.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610180418.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610180523.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG_2014.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610180359.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230807183239.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610181617.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG-20230529-WA0006.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG-20230529-WA0032.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG_3239.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG-20230529-WA0015.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230807183126.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG-20230611-WA0037.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610175922.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG_2001.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230807183258.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG_20230616_153344.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230807183048.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG-20230529-WA0005.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230807183835.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG_2091.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG-20230529-WA0008.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610181404.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610182539.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG_20230612_130405.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610174916.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230807183054.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG_2037.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG_20230612_130039.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610175258.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610181207.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610182520.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG_20230616_153459.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG_20230618_002604.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610180326.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG_1983.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG-20230529-WA0057.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG_20230612_130400.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610180520.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG-20230529-WA0062.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610175815.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610175910.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610181741.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610182345.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610181332.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610175021.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230807183202.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610180431.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610175936.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG-20230529-WA0009.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG-20230529-WA0047.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610182301.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG_1984.JPG
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG20230610181316.jpg
# /kaggle/input/orgial-dataset-arsenic/Original/not_infacted/IMG_3234.JPG

# %% [markdown]
# # Import file

# %%
import os
import glob
import shutil
import itertools
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
from tqdm.notebook import tqdm
from sklearn.model_selection import GroupShuffleSplit
import torchvision.transforms as T
import cv2

# %% [markdown]
# # DATASET PATH VERIFICATION

# %%
# ============================================================
# STEP 1: DATASET PATH VERIFICATION
# ============================================================
data_dir = '/kaggle/input/orgial-dataset-arsenic/Original'
print("Dataset path:", data_dir)
print("Exists:", os.path.exists(data_dir))
print("Subfolders:", os.listdir(data_dir))

# Optional: Copy to local path for faster I/O
local_dir = '/content/Original_Data'
if not os.path.exists(local_dir):
    shutil.copytree(data_dir, local_dir)
    print("Dataset copied locally to:", local_dir)
else:
    print("Local dataset already exists at:", local_dir)

BASE_PATH = local_dir

filepaths = []
labels = []
groups = [] 


for label in os.listdir(BASE_PATH):
    label_path = os.path.join(BASE_PATH, label)
    if os.path.isdir(label_path):
        for fname in os.listdir(label_path):
            if fname.lower().endswith(('.jpg', '.jpeg', '.png')):
                filepaths.append(os.path.join(label_path, fname))
                labels.append(label)
                groups.append(label)  


df = pd.DataFrame({
    "filepath": filepaths,
    "label": labels,
    "group": groups
})

print("Total samples:", len(df))
print(df.head())
# Out:
# Dataset path: /kaggle/input/orgial-dataset-arsenic/Original
# Exists: True
# Subfolders: ['infacted', 'not_infacted']
# Dataset copied locally to: /content/Original_Data
# Total samples: 1287
#                                             filepath         label  \
# 0  /content/Original_Data/not_infacted/IMG2023061...  not_infacted
# 1  /content/Original_Data/not_infacted/IMG2023080...  not_infacted
# 2  /content/Original_Data/not_infacted/IMG2023080...  not_infacted
# 3  /content/Original_Data/not_infacted/IMG2023061...  not_infacted
# 4  /content/Original_Data/not_infacted/IMG2023080...  not_infacted
#
#           group
# 0  not_infacted
# 1  not_infacted
# 2  not_infacted
# 3  not_infacted
# 4  not_infacted

# %% [markdown]
# # CLASS DETECTION FROM FOLDER NAMES

# %%
available_classes = [f for f in os.listdir(BASE_PATH) if os.path.isdir(os.path.join(BASE_PATH, f))]
print("Available class folders:", available_classes)

if not available_classes:
    raise ValueError("No class folders found. Check dataset path.")

CLASSES = available_classes
# Out:
# Available class folders: ['not_infacted', 'infacted']

# %% [markdown]
# # COMPUTE IMAGE STATISTICS

# %%
def compute_image_stats(image):
    if image.mode != "RGB":
        image = image.convert("RGB")

    arr = np.asarray(image, dtype=np.float32) / 255.0
    hsv = np.asarray(image.convert("HSV"), dtype=np.float32) / 255.0

    stats = {}
    for i, c in enumerate(['R', 'G', 'B']):
        stats[f'{c}_mean'] = arr[:, :, i].mean()
        stats[f'{c}_std'] = arr[:, :, i].std()
    for i, c in enumerate(['H', 'S', 'V']):
        stats[f'{c}_mean'] = hsv[:, :, i].mean()
        stats[f'{c}_std'] = hsv[:, :, i].std()

    stats['brightness'] = hsv[:, :, 2].mean()
    stats['contrast'] = arr.std(axis=(0,1)).mean()

    s = hsv[:, :, 1]
    stats['sat_clip_low'] = np.mean(s < 0.05)
    stats['sat_clip_high'] = np.mean(s > 0.95)

    stats['width'], stats['height'] = image.size
    stats['aspect_ratio'] = image.width / image.height

    return stats

rows = []
MAX_IMAGES = None  # Set to a number for testing (e.g., 200)

for cls in CLASSES:
    folder = os.path.join(BASE_PATH, cls)
    img_paths = glob.glob(os.path.join(folder, "*.*"))
    if MAX_IMAGES:
        img_paths = img_paths[:MAX_IMAGES]

    if not img_paths:
        print(f"No images found in folder: {folder}")
        continue

    print(f"Processing {len(img_paths)} images in class '{cls}'...")
    for path in tqdm(img_paths, desc=f"{cls} images"):
        if not path.lower().endswith((".jpg", ".jpeg", ".png", ".bmp")):
            continue
        try:
            img = Image.open(path)
            stats = compute_image_stats(img)
            stats["class"] = cls
            stats["filename"] = os.path.basename(path)
            rows.append(stats)
        except:
            continue

if not rows:
    raise ValueError("No valid images found. Check dataset path or folder structure.")

df_stats = pd.DataFrame(rows)
print("Total images processed:", len(df_stats))
display(df_stats.head())
# Out:
# Processing 546 images in class 'not_infacted'...
# not_infacted images:   0%|          | 0/546 [00:00<?, ?it/s]
# Processing 741 images in class 'infacted'...
# infacted images:   0%|          | 0/741 [00:00<?, ?it/s]
# Total images processed: 1287
#      R_mean     R_std    G_mean     G_std    B_mean     B_std    H_mean  \
# 0  0.695316  0.088976  0.572566  0.088561  0.451598  0.090655  0.080867
# 1  0.577354  0.080682  0.503701  0.082955  0.405659  0.083312  0.093330
# 2  0.633974  0.059775  0.607313  0.069123  0.567375  0.078073  0.105668
# 3  0.707919  0.082438  0.577458  0.084216  0.462828  0.086566  0.075615
# 4  0.573293  0.057554  0.544498  0.059090  0.499595  0.060271  0.099822
#
#       H_std    S_mean     S_std  ...     V_std  brightness  contrast  \
# 0  0.005082  0.354899  0.062826  ...  0.088976    0.695316  0.093286
# 1  0.004695  0.302068  0.050794  ...  0.080682    0.577354  0.086205
# 2  0.033857  0.106743  0.056050  ...  0.059873    0.634150  0.076029
# 3  0.006143  0.350953  0.071282  ...  0.082438    0.707919  0.086152
# 4  0.009901  0.128594  0.023085  ...  0.057554    0.573294  0.060929
#
#    sat_clip_low  sat_clip_high  width  height  aspect_ratio         class  \
# 0  1.371910e-06   4.913934e-05   3468    4624          0.75  not_infacted
# 1  0.000000e+00   0.000000e+00   3468    4624          0.75  not_infacted
# 2  1.479995e-01   0.000000e+00   3468    4624          0.75  not_infacted
# 3  3.117978e-05   9.131935e-04   3468    4624          0.75  not_infacted
# 4  1.870787e-07   6.235957e-08   3468    4624          0.75  not_infacted
#
#                 filename
# 0  IMG20230610181733.jpg
# 1  IMG20230807183520.jpg
# 2  IMG20230807183123.jpg
# 3  IMG20230610181308.jpg
# 4  IMG20230807183248.jpg
#
# [5 rows x 21 columns]

# %% [markdown]
# # HISTOGRAM VISUALIZATION

# %%
sample_row = df_stats.iloc[0]
sample_img_path = os.path.join(BASE_PATH, sample_row["class"], sample_row["filename"])
sample_img = Image.open(sample_img_path)
arr = np.asarray(sample_img)

plt.figure(figsize=(12,4))
for i,color in enumerate(['r','g','b']):
    plt.hist(arr[:,:,i].ravel(), bins=256, color=color, alpha=0.5, label=color.upper())
plt.title("RGB Histogram (Sample)")
plt.legend()
plt.show()

hsv = np.asarray(sample_img.convert("HSV"))
plt.figure(figsize=(12,4))
for i,color in enumerate(['h','s','v']):
    plt.hist(hsv[:,:,i].ravel(), bins=256, alpha=0.5, label=color.upper())
plt.title("HSV Histogram (Sample)")
plt.legend()
plt.show()

# %% [markdown]
# # PER-CLASS SUMMARY STATISTICS

# %%
numeric_cols = df_stats.select_dtypes(include=np.number).columns.tolist()
summary = df_stats.groupby("class")[numeric_cols].agg(["mean","std"])
print("Per-Class Mean & STD:")
display(summary)

# Brightness vs Contrast
plt.figure(figsize=(7,6))
sns.scatterplot(data=df_stats, x="brightness", y="contrast", hue="class", alpha=0.7)
plt.title("Brightness vs Contrast Spread")
plt.show()

# Saturation Clipping
plt.figure(figsize=(6,5))
sns.boxplot(data=df_stats, x="class", y="sat_clip_high")
plt.title("Saturation Clipping (High values)")
plt.show()

# Resolution and Aspect Ratio
plt.figure(figsize=(7,5))
sns.histplot(data=df_stats, x="width", bins=30, hue="class", element="step")
plt.title("Width Distribution per Class")
plt.show()

plt.figure(figsize=(7,5))
sns.histplot(data=df_stats, x="height", bins=30, hue="class", element="step")
plt.title("Height Distribution per Class")
plt.show()

plt.figure(figsize=(7,5))
sns.histplot(data=df_stats, x="aspect_ratio", bins=30, hue="class", element="step")
plt.title("Aspect Ratio Distribution per Class")
plt.show()

# Suggested Resize Target
mean_w, mean_h = df_stats['width'].mean(), df_stats['height'].mean()
print(f"Suggested resize target: ({int(mean_w)}x{int(mean_h)})")
print("""
Suggested Strategy:
- Resize all images to a fixed size (e.g., 256×256)
- Maintain aspect ratio by padding (black or mean color)
- For CNNs, use random crop + resize augmentation
""")
# Out:
# Per-Class Mean & STD:
#                 R_mean               R_std              G_mean            \
#                   mean       std      mean       std      mean       std
# class
# infacted      0.684950  0.081812  0.140340  0.037378  0.545283  0.061217
# not_infacted  0.659803  0.077076  0.100049  0.039741  0.569448  0.080927
#
#                  G_std              B_mean            ... sat_clip_low  \
#                   mean       std      mean       std  ...         mean
# class                                                 ...
# infacted      0.139184  0.035920  0.456526  0.059377  ...     0.008509
# not_infacted  0.106481  0.042616  0.496035  0.083903  ...     0.029440
#
#                        sat_clip_high                  width              \
#                    std          mean       std         mean         std
# class
# infacted      0.029280      0.001327  0.005978  4032.000000     0.00000
# not_infacted  0.083165      0.001277  0.004610  3196.294872  1047.82375
#
#                    height              aspect_ratio
#                      mean          std         mean       std
# class
# infacted      3024.000000     0.000000     1.333333  0.000000
# not_infacted  3656.826007  1244.889474     0.929098  0.386921
#
# [2 rows x 38 columns]
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# Suggested resize target: (3677x3292)
#
# Suggested Strategy:
# - Resize all images to a fixed size (e.g., 256×256)
# - Maintain aspect ratio by padding (black or mean color)
# - For CNNs, use random crop + resize augmentation

# %% [markdown]
# # IMAGE QUALITY METRICS (LAPLACIAN VARIANCE & NOISE)

# %%
def laplacian_variance(image_path):
    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    if img is None:
        return None
    lap = cv2.Laplacian(img, cv2.CV_64F)
    return lap.var()

def noise_proxy(image_path):
    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    if img is None:
        return None
    blurred = cv2.GaussianBlur(img, (3, 3), 0)
    noise = img.astype("float") - blurred.astype("float")
    return noise.var()

categories = CLASSES
quality_data = []

for category in categories:
    folder_path = os.path.join(BASE_PATH, category)
    for filename in tqdm(os.listdir(folder_path), desc=f"Quality check: {category}"):
        img_path = os.path.join(folder_path, filename)
        lap_var = laplacian_variance(img_path)
        noise_val = noise_proxy(img_path)
        quality_data.append({
            'filename': filename,
            'category': category,
            'laplacian_variance': lap_var,
            'noise_proxy': noise_val
        })

df_quality = pd.DataFrame(quality_data)
output_csv = '/content/laplacian_noise_results.csv'
df_quality.to_csv(output_csv, index=False)
print("CSV saved to:", output_csv)
print(df_quality.groupby('category')[['laplacian_variance', 'noise_proxy']].mean())
# Out:
# Quality check: not_infacted:   0%|          | 0/546 [00:00<?, ?it/s]
# Quality check: infacted:   0%|          | 0/741 [00:00<?, ?it/s]
# CSV saved to: /content/laplacian_noise_results.csv
#               laplacian_variance  noise_proxy
# category
# infacted               22.096996     1.227764
# not_infacted           30.358032     1.568775

# %% [markdown]
# # DUPLICATE DETECTION (Perceptual Hashing)

# %%
def gray_world_correction(pil_image):
    if pil_image.mode != 'RGB':
        pil_image = pil_image.convert('RGB')
    arr = np.asarray(pil_image).astype(np.float32)
    mean_r, mean_g, mean_b = arr[:,:,0].mean(), arr[:,:,1].mean(), arr[:,:,2].mean()
    mean_gray = (mean_r + mean_g + mean_b) / 3.0
    arr[:,:,0] = np.clip(arr[:,:,0] * (mean_gray / mean_r), 0, 255)
    arr[:,:,1] = np.clip(arr[:,:,1] * (mean_gray / mean_g), 0, 255)
    arr[:,:,2] = np.clip(arr[:,:,2] * (mean_gray / mean_b), 0, 255)
    return Image.fromarray(arr.astype(np.uint8))

def ahash(image, hash_size=8):
    image = image.convert('L').resize((hash_size, hash_size), Image.Resampling.LANCZOS)
    pixels = np.array(image)
    avg = pixels.mean()
    return ''.join(['1' if p > avg else '0' for p in pixels.flatten()])

def dhash(image, hash_size=8):
    image = image.convert('L').resize((hash_size + 1, hash_size), Image.Resampling.LANCZOS)
    pixels = np.array(image)
    diff = pixels[:, 1:] > pixels[:, :-1]
    return ''.join(['1' if v else '0' for v in diff.flatten()])

def hamming_distance(hash1, hash2):
    return sum(c1 != c2 for c1, c2 in zip(hash1, hash2))

image_paths = glob.glob(os.path.join(BASE_PATH, '**', '*.*'), recursive=True)
image_paths = [p for p in image_paths if p.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp'))]
print("Total image paths found:", len(image_paths))

rows = []
for img_path in tqdm(image_paths, desc="Perceptual hashing"):
    try:
        img = Image.open(img_path)
        row = {
            "filename": os.path.basename(img_path),
            "path": img_path,
            "ahash": ahash(img),
            "dhash": dhash(img)
        }
        rows.append(row)
    except Exception as e:
        print(f"Error processing {img_path}: {e}")

if not rows:
    print("No valid image data found.")
else:
    df_hash = pd.DataFrame(rows)
    df_hash = df_hash.sort_values("filename").reset_index(drop=True)
    print("Hash DataFrame:")
    display(df_hash.head())

    duplicates = []
    threshold = 5
    for (i1, row1), (i2, row2) in itertools.combinations(df_hash.iterrows(), 2):
        hd_ahash = hamming_distance(row1['ahash'], row2['ahash'])
        hd_dhash = hamming_distance(row1['dhash'], row2['dhash'])
        if hd_ahash <= threshold and hd_dhash <= threshold:
            duplicates.append({
                "file1": row1['filename'],
                "file2": row2['filename'],
                "ahash_dist": hd_ahash,
                "dhash_dist": hd_dhash
            })

    dup_df = pd.DataFrame(duplicates)
    if not dup_df.empty:
        print("Duplicates found:")
        display(dup_df)
    else:
        print("No duplicates detected.")
# Out:
# Total image paths found: 1287
# Perceptual hashing:   0%|          | 0/1287 [00:00<?, ?it/s]
# Hash DataFrame:
#                   filename                                               path  \
# 0  IMG-20230529-WA0000.jpg  /content/Original_Data/not_infacted/IMG-202305...
# 1  IMG-20230529-WA0001.jpg  /content/Original_Data/not_infacted/IMG-202305...
# 2  IMG-20230529-WA0002.jpg  /content/Original_Data/not_infacted/IMG-202305...
# 3  IMG-20230529-WA0003.jpg  /content/Original_Data/not_infacted/IMG-202305...
# 4  IMG-20230529-WA0004.jpg  /content/Original_Data/not_infacted/IMG-202305...
#
#                                                ahash  \
# 0  0000000000000000000000011000011111011111111111...
# 1  0000111100111111011011010100110100010111000101...
# 2  0000011100001111000001110000011100001111000011...
# 3  0101111111001111110011101000000010000100000001...
# 4  0000111100001111000001110000011101111111111111...
#
#                                                dhash
# 0  1011011111101010011011110011110100110100100101...
# 1  0111101101101111110110011101100111110100011101...
# 2  1111111011111110011111101110111011101100111011...
# 3  1001101110011010000110100010100100111101001011...
# 4  1111111000111110111111101110111111011011110000...
# Duplicates found:
#                       file1                    file2  ahash_dist  dhash_dist
# 0   IMG-20230529-WA0019.jpg  IMG-20230529-WA0067.jpg           2           2
# 1   IMG-20230529-WA0021.jpg  IMG-20230529-WA0060.jpg           4           4
# 2   IMG-20230529-WA0021.jpg  IMG_20230612_130410.jpg           2           5
# 3   IMG-20230529-WA0042.jpg  IMG-20230529-WA0046.jpg           4           3
# 4   IMG-20230529-WA0042.jpg    IMG20230610182635.jpg           5           4
# ..                      ...                      ...         ...         ...
# 77  IMG_20230612_130815.jpg  IMG_20230612_130817.jpg           4           2
# 78  IMG_20230616_153459.jpg  IMG_20230616_153500.jpg           3           1
# 79             IMG_2025.JPG             IMG_2026.JPG           1           2
# 80             IMG_2074.JPG             IMG_2075.JPG           1           5
# 81             IMG_2074.JPG             IMG_2076.JPG           1           4
#
# [82 rows x 4 columns]

# %% [markdown]
# # DATAFRAME BUILDING & GROUPED TRAIN-TEST SPLIT

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import GroupShuffleSplit

train_groups = []
test_groups = []

# Split safely per label
for lbl, sub_df in df.groupby("label"):
    groups = sub_df["group"].unique()
    n_groups = len(groups)

    if n_groups < 2:
        print(f" Label '{lbl}' has only {n_groups} group(s) — assigning all to train.")
        train_groups.extend(groups)
        continue

    # otherwise, do normal 80/20 split
    gss = GroupShuffleSplit(n_splits=1, train_size=0.8, random_state=42)
    train_idx, test_idx = next(gss.split(groups, groups=groups))
    train_groups.extend(groups[train_idx])
    test_groups.extend(groups[test_idx])

# build full DataFrames
train_df = df[df["group"].isin(train_groups)].reset_index(drop=True)
test_df = df[df["group"].isin(test_groups)].reset_index(drop=True)

# print summary
print("\n Safe Label-wise Group Split Complete")
print("---------------------------------------")
print(f"Train size: {len(train_df)}")
print(f"Test size: {len(test_df)}")
print("Unique groups in train:", train_df["group"].nunique())
print("Unique groups in test:", test_df["group"].nunique())

print("\n Train class distribution:")
print(train_df["label"].value_counts())
print("\nTest class distribution:")
print(test_df["label"].value_counts())

# save csvs
train_df.to_csv("/kaggle/working/train_split.csv", index=False)
test_df.to_csv("/kaggle/working/test_split.csv", index=False)
print("\n Train/Test split CSVs saved in /kaggle/working/")
# Out:
#  Label 'infacted' has only 1 group(s) — assigning all to train.
#  Label 'not_infacted' has only 1 group(s) — assigning all to train.
#
#  Safe Label-wise Group Split Complete
# ---------------------------------------
# Train size: 1287
# Test size: 0
# Unique groups in train: 2
# Unique groups in test: 0
#
#  Train class distribution:
# label
# infacted        741
# not_infacted    546
# Name: count, dtype: int64
#
# Test class distribution:
# Series([], Name: count, dtype: int64)
#
#  Train/Test split CSVs saved in /kaggle/working/

# %% [markdown]
# # : AUGMENTATION PROBE

# %%
sample_path = train_df['filepath'].sample(1, random_state=42).iloc[0]
img = Image.open(sample_path)

augmentations = {
    "RandomCrop": T.RandomResizedCrop(size=244, scale=(0.8, 1.0)),
    "HorizontalFlip": T.RandomHorizontalFlip(p=1.0),
    "ColorJitter": T.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
    "GaussianBlur": T.GaussianBlur(kernel_size=5),
    "HeavyRotation": T.RandomRotation(degrees=90),
}

fig, axes = plt.subplots(1, len(augmentations)+1, figsize=(18,5))
axes[0].imshow(img)
axes[0].set_title("Original")
axes[0].axis("off")

for i, (name, aug) in enumerate(augmentations.items(), 1):
    transformed = aug(img)
    axes[i].imshow(transformed)
    axes[i].set_title(name)
    axes[i].axis("off")

plt.tight_layout()
plt.show()

print("Augmentation probe complete. Visually inspect which transforms are helpful or harmful.")
# Out:
# Augmentation probe complete. Visually inspect which transforms are helpful or harmful.

# %% [markdown]
# # Validation Split
# # train (90%)
# # test (10%)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Example: df should have columns ['filepath', 'label', 'group']

# Train 90% + Test 10%
train_df, test_df = train_test_split(
    df,
    test_size=0.1,
    stratify=df["label"],
    random_state=42
)

# Validation = 10% of total dataset → 10 / 90 = 0.1111 of train
train_df, val_df = train_test_split(
    train_df,
    test_size=0.1,
    stratify=train_df["label"],
    random_state=42
)

# Step 3: Print results
print("Train size:", len(train_df))
print("Validation size:", len(val_df))
print("Test size:", len(test_df))

print("\nTrain class distribution:")
print(train_df["label"].value_counts())
print("\nValidation class distribution:")
print(val_df["label"].value_counts())
print("\nTest class distribution:")
print(test_df["label"].value_counts())

# Step 4: Save CSVs
train_df.to_csv("/kaggle/working/train_split.csv", index=False)
val_df.to_csv("/kaggle/working/val_split.csv", index=False)
test_df.to_csv("/kaggle/working/test_split.csv", index=False)

print("\n Train/Val/Test CSVs saved successfully!")
# Out:
# Train size: 1042
# Validation size: 116
# Test size: 129
#
# Train class distribution:
# label
# infacted        600
# not_infacted    442
# Name: count, dtype: int64
#
# Validation class distribution:
# label
# infacted        67
# not_infacted    49
# Name: count, dtype: int64
#
# Test class distribution:
# label
# infacted        74
# not_infacted    55
# Name: count, dtype: int64
#
#  Train/Val/Test CSVs saved successfully!

# %% [markdown]
# # EfficientNetB0 Version

# %%
import time
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
from sklearn.preprocessing import label_binarize
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.layers import GlobalAveragePooling2D, Dropout, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# ======= Adjustable Epochs =======
EPOCHS = 50  # 🔁 Change this number anytime
BATCH_SIZE = 32
IMAGE_SIZE = (224, 224)

# ======= Load CSVs =======
train_df = pd.read_csv("/kaggle/working/train_split.csv")
val_df = pd.read_csv("/kaggle/working/val_split.csv")
test_df = pd.read_csv("/kaggle/working/test_split.csv")

# ======= Image Data Generators =======
train_datagen = ImageDataGenerator(rescale=1./255, horizontal_flip=True)
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_gen = train_datagen.flow_from_dataframe(
    train_df, 
    x_col="filepath", 
    y_col="label",
    target_size=IMAGE_SIZE, 
    batch_size=BATCH_SIZE, 
    class_mode="categorical",
    shuffle=True
)

val_gen = val_datagen.flow_from_dataframe(
    val_df, 
    x_col="filepath", 
    y_col="label",
    target_size=IMAGE_SIZE, 
    batch_size=BATCH_SIZE, 
    class_mode="categorical",
    shuffle=False
)

test_gen = test_datagen.flow_from_dataframe(
    test_df, 
    x_col="filepath", 
    y_col="label",
    target_size=IMAGE_SIZE, 
    batch_size=BATCH_SIZE, 
    class_mode="categorical",
    shuffle=False
)

num_classes = len(train_gen.class_indices)


# ======= Build EfficientNetB0 Model =======
base_model = EfficientNetB0(weights="imagenet", include_top=False, input_shape=(224, 224, 3))
x = GlobalAveragePooling2D()(base_model.output)
x = Dropout(0.3)(x)
output = Dense(num_classes, activation="softmax")(x)

model = Model(inputs=base_model.input, outputs=output)

for layer in base_model.layers:
    layer.trainable = False

model.compile(optimizer=Adam(1e-4), loss="categorical_crossentropy", metrics=["accuracy"])


print("Classes in train set:", train_gen.class_indices)
print("Classes in test set:", test_gen.class_indices)


# ======= Train =======
start_train = time.time()
history = model.fit(train_gen, validation_data=val_gen, epochs=EPOCHS)
train_time = time.time() - start_train

# ======= Evaluate =======
start_test = time.time()
test_loss, test_acc = model.evaluate(test_gen)
test_time = time.time() - start_test

print(f"\n Test Accuracy: {test_acc:.4f}")
print(f"⏱ Training Time: {train_time:.2f}s | Testing Time: {test_time:.2f}s")

# ======= Predictions =======
y_true = test_gen.classes
y_pred_probs = model.predict(test_gen)
y_pred = np.argmax(y_pred_probs, axis=1)
class_labels = list(test_gen.class_indices.keys())

# ======= Metrics =======
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_labels))

# ======= Confusion Matrix =======
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.title("Confusion Matrix — EfficientNetB0")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# ======= ROC–AUC for binary classification =======
from sklearn.metrics import roc_auc_score, roc_curve, auc

# Use probability of 'not_infacted' or positive class
y_pred_prob_pos = y_pred_probs[:, 1]  # probability of class 1

auc_score = roc_auc_score(y_true, y_pred_prob_pos)
fpr, tpr, _ = roc_curve(y_true, y_pred_prob_pos)

plt.figure()
plt.plot(fpr, tpr, label=f"Binary ROC (AUC={auc_score:.2f})")
plt.plot([0, 1], [0, 1], 'k--')
plt.title("ROC Curve — EfficientNetB0")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.show()

print(f"\nROC–AUC: {auc_score:.4f}")


# ======= GFLOPs =======
import os
import tensorflow as tf
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2

# ======= Suppress TensorFlow GPU info logs =======
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'  # Only show warnings and errors

# ======= Define your model =======
input_shape = (224, 224, 3)  # Fixed input size
model = EfficientNetB0(input_shape=input_shape, include_top=True, weights=None)

# ======= Convert to ConcreteFunction =======
full_model = tf.function(lambda x: model(x))
full_model = full_model.get_concrete_function(
    tf.TensorSpec([1, *input_shape], model.inputs[0].dtype)
)

# ======= Freeze the graph =======
frozen_func = convert_variables_to_constants_v2(full_model)
graph_def = frozen_func.graph.as_graph_def()

# ======= Use TF Profiler to calculate FLOPs =======
with tf.Graph().as_default() as graph:
    tf.import_graph_def(graph_def, name='')
    run_meta = tf.compat.v1.RunMetadata()
    opts = tf.compat.v1.profiler.ProfileOptionBuilder.float_operation()
    flops = tf.compat.v1.profiler.profile(graph=graph, run_meta=run_meta, cmd='op', options=opts)

# ======= Print GFLOPs per inference =======
print(f"\n⚙️ GFLOPs per inference (input size {input_shape}): {flops.total_float_ops / 1e9:.4f} GFLOPs")
# Out:
# 2025-10-27 18:43:25.635369: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761590605.801642      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761590605.852014      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Found 1042 validated image filenames belonging to 2 classes.
# Found 116 validated image filenames belonging to 2 classes.
# Found 129 validated image filenames belonging to 2 classes.
# I0000 00:00:1761590615.947902      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Classes in train set: {'infacted': 0, 'not_infacted': 1}
# Classes in test set: {'infacted': 0, 'not_infacted': 1}
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1761590642.043498      66 service.cc:148] XLA service 0x78be500063b0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1761590642.044251      66 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1761590644.043195      66 cuda_dnn.cc:529] Loaded cuDNN version 90300
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 15:02 28s/step - accuracy: 0.5000 - loss: 0.7074
# I0000 00:00:1761590652.698521      66 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 129s 3s/step - accuracy: 0.5403 - loss: 0.6901 - val_accuracy: 0.5776 - val_loss: 0.6811
# Epoch 2/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 91s 3s/step - accuracy: 0.5795 - loss: 0.6829 - val_accuracy: 0.5776 - val_loss: 0.6813
# Epoch 3/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 87s 3s/step - accuracy: 0.5488 - loss: 0.6911 - val_accuracy: 0.5776 - val_loss: 0.6811
# Epoch 4/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 81s 2s/step - accuracy: 0.5824 - loss: 0.6836 - val_accuracy: 0.5776 - val_loss: 0.6813
# Epoch 5/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 87s 3s/step - accuracy: 0.5854 - loss: 0.6767 - val_accuracy: 0.5776 - val_loss: 0.6812
# Epoch 6/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 80s 2s/step - accuracy: 0.5392 - loss: 0.6936 - val_accuracy: 0.5776 - val_loss: 0.6812
# Epoch 7/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 86s 3s/step - accuracy: 0.5709 - loss: 0.6817 - val_accuracy: 0.5776 - val_loss: 0.6811
# Epoch 8/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 95s 3s/step - accuracy: 0.5817 - loss: 0.6836 - val_accuracy: 0.5776 - val_loss: 0.6812
# Epoch 9/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.5672 - loss: 0.6839 - val_accuracy: 0.5776 - val_loss: 0.6812
# Epoch 10/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.5338 - loss: 0.7016 - val_accuracy: 0.5776 - val_loss: 0.6811
# Epoch 11/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 93s 3s/step - accuracy: 0.5579 - loss: 0.6959 - val_accuracy: 0.5776 - val_loss: 0.6812
# Epoch 12/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.5526 - loss: 0.6968 - val_accuracy: 0.5776 - val_loss: 0.6814
# Epoch 13/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 91s 3s/step - accuracy: 0.5408 - loss: 0.6929 - val_accuracy: 0.5776 - val_loss: 0.6813
# Epoch 14/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 88s 3s/step - accuracy: 0.5386 - loss: 0.7012 - val_accuracy: 0.5776 - val_loss: 0.6813
# Epoch 15/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 83s 2s/step - accuracy: 0.6051 - loss: 0.6773 - val_accuracy: 0.5776 - val_loss: 0.6814
# Epoch 16/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.5538 - loss: 0.6929 - val_accuracy: 0.5776 - val_loss: 0.6812
# Epoch 17/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 85s 3s/step - accuracy: 0.6024 - loss: 0.6705 - val_accuracy: 0.5776 - val_loss: 0.6812
# Epoch 18/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 90s 3s/step - accuracy: 0.5629 - loss: 0.6889 - val_accuracy: 0.5776 - val_loss: 0.6812
# Epoch 19/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 83s 3s/step - accuracy: 0.5691 - loss: 0.6837 - val_accuracy: 0.5776 - val_loss: 0.6812
# Epoch 20/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 88s 3s/step - accuracy: 0.5774 - loss: 0.6901 - val_accuracy: 0.5776 - val_loss: 0.6811
# Epoch 21/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 93s 3s/step - accuracy: 0.5659 - loss: 0.6877 - val_accuracy: 0.5776 - val_loss: 0.6812
# Epoch 22/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 87s 3s/step - accuracy: 0.5370 - loss: 0.6958 - val_accuracy: 0.5776 - val_loss: 0.6813
# Epoch 23/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 83s 3s/step - accuracy: 0.5861 - loss: 0.6851 - val_accuracy: 0.5776 - val_loss: 0.6813
# Epoch 24/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 91s 3s/step - accuracy: 0.5604 - loss: 0.6856 - val_accuracy: 0.5776 - val_loss: 0.6812
# Epoch 25/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 94s 3s/step - accuracy: 0.5422 - loss: 0.6866 - val_accuracy: 0.5776 - val_loss: 0.6811
# Epoch 26/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.5648 - loss: 0.6920 - val_accuracy: 0.5776 - val_loss: 0.6811
# Epoch 27/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 85s 3s/step - accuracy: 0.5712 - loss: 0.6837 - val_accuracy: 0.5776 - val_loss: 0.6811
# Epoch 28/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.5591 - loss: 0.6821 - val_accuracy: 0.5776 - val_loss: 0.6811
# Epoch 29/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 80s 2s/step - accuracy: 0.5768 - loss: 0.6870 - val_accuracy: 0.5776 - val_loss: 0.6813
# Epoch 30/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 83s 2s/step - accuracy: 0.5608 - loss: 0.6873 - val_accuracy: 0.5776 - val_loss: 0.6811
# Epoch 31/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.5917 - loss: 0.6839 - val_accuracy: 0.5776 - val_loss: 0.6811
# Epoch 32/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 84s 3s/step - accuracy: 0.5737 - loss: 0.6904 - val_accuracy: 0.5776 - val_loss: 0.6811
# Epoch 33/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 89s 3s/step - accuracy: 0.5518 - loss: 0.6932 - val_accuracy: 0.5776 - val_loss: 0.6811
# Epoch 34/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 87s 3s/step - accuracy: 0.5692 - loss: 0.6789 - val_accuracy: 0.5776 - val_loss: 0.6811
# Epoch 35/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 83s 3s/step - accuracy: 0.5278 - loss: 0.6993 - val_accuracy: 0.5776 - val_loss: 0.6811
# Epoch 36/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 82s 3s/step - accuracy: 0.5645 - loss: 0.6890 - val_accuracy: 0.5776 - val_loss: 0.6811
# Epoch 37/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 87s 3s/step - accuracy: 0.5733 - loss: 0.6879 - val_accuracy: 0.5776 - val_loss: 0.6810
# Epoch 38/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.5333 - loss: 0.6956 - val_accuracy: 0.5776 - val_loss: 0.6813
# Epoch 39/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 88s 3s/step - accuracy: 0.5401 - loss: 0.6963 - val_accuracy: 0.5776 - val_loss: 0.6810
# Epoch 40/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 83s 2s/step - accuracy: 0.5720 - loss: 0.6880 - val_accuracy: 0.5776 - val_loss: 0.6811
# Epoch 41/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 81s 2s/step - accuracy: 0.5726 - loss: 0.6796 - val_accuracy: 0.5776 - val_loss: 0.6811
# Epoch 42/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 83s 3s/step - accuracy: 0.5706 - loss: 0.6873 - val_accuracy: 0.5776 - val_loss: 0.6816
# Epoch 43/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 91s 3s/step - accuracy: 0.5603 - loss: 0.6926 - val_accuracy: 0.5776 - val_loss: 0.6810
# Epoch 44/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 81s 2s/step - accuracy: 0.5557 - loss: 0.6918 - val_accuracy: 0.5776 - val_loss: 0.6810
# Epoch 45/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 81s 2s/step - accuracy: 0.5709 - loss: 0.6846 - val_accuracy: 0.5776 - val_loss: 0.6810
# Epoch 46/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 92s 3s/step - accuracy: 0.5528 - loss: 0.6891 - val_accuracy: 0.5776 - val_loss: 0.6810
# Epoch 47/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 83s 3s/step - accuracy: 0.5453 - loss: 0.6999 - val_accuracy: 0.5776 - val_loss: 0.6814
# Epoch 48/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 82s 3s/step - accuracy: 0.5738 - loss: 0.6782 - val_accuracy: 0.5776 - val_loss: 0.6810
# Epoch 49/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.5810 - loss: 0.6788 - val_accuracy: 0.5776 - val_loss: 0.6811
# Epoch 50/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 84s 3s/step - accuracy: 0.5325 - loss: 0.7015 - val_accuracy: 0.5776 - val_loss: 0.6812
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 14s 3s/step - accuracy: 0.5788 - loss: 0.6808
#
#  Test Accuracy: 0.5736
# ⏱ Training Time: 4320.33s | Testing Time: 20.44s
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     infacted       0.57      1.00      0.73        74
# not_infacted       0.00      0.00      0.00        55
#
#     accuracy                           0.57       129
#    macro avg       0.29      0.50      0.36       129
# weighted avg       0.33      0.57      0.42       129
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ROC–AUC: 0.5980
# I0000 00:00:1761594989.312041      19 devices.cc:67] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 1
# I0000 00:00:1761594989.312228      19 single_machine.cc:361] Starting new session
# I0000 00:00:1761594989.313402      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# op: The nodes are operation kernel type, such as MatMul, Conv2D. Graph nodes belonging to the same type are aggregated together.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# Conv2D                   700.01m float_ops (100.00%, 87.17%)
# DepthwiseConv2dNative    69.06m float_ops (12.83%, 8.60%)
# Mul                      21.55m float_ops (4.23%, 2.68%)
# AddV2                    7.12m float_ops (1.55%, 0.89%)
# MatMul                   2.56m float_ops (0.66%, 0.32%)
# Mean                     2.37m float_ops (0.34%, 0.30%)
# Sub                      171.54k float_ops (0.05%, 0.02%)
# RealDiv                  150.53k float_ops (0.03%, 0.02%)
# Rsqrt                    42.02k float_ops (0.01%, 0.01%)
# BiasAdd                  10.34k float_ops (0.00%, 0.00%)
# Softmax                  5.00k float_ops (0.00%, 0.00%)
# Maximum                      3 float_ops (0.00%, 0.00%)
#
# ======================End of Report==========================
#
# ⚙️ GFLOPs per inference (input size (224, 224, 3)): 0.8031 GFLOPs

# %% [markdown]
# # Validation Split
# # train (80%)
# # test (20%)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Example: df should have columns ['filepath', 'label', 'group']

train_df, test_df = train_test_split(
    df,
    test_size=0.2,
    stratify=df["label"],
    random_state=42
)


train_df, val_df = train_test_split(
    train_df,
    test_size=0.1,
    stratify=train_df["label"],
    random_state=42
)


# Step 3: Print results
print("Train size:", len(train_df))
print("Validation size:", len(val_df))
print("Test size:", len(test_df))

print("\nTrain class distribution:")
print(train_df["label"].value_counts())
print("\nValidation class distribution:")
print(val_df["label"].value_counts())
print("\nTest class distribution:")
print(test_df["label"].value_counts())

# Step 4: Save CSVs
train_df.to_csv("/kaggle/working/train_split.csv", index=False)
val_df.to_csv("/kaggle/working/val_split.csv", index=False)
test_df.to_csv("/kaggle/working/test_split.csv", index=False)

print("\n Train/Val/Test CSVs saved successfully!")
# Out:
# Train size: 926
# Validation size: 103
# Test size: 258
#
# Train class distribution:
# label
# infacted        533
# not_infacted    393
# Name: count, dtype: int64
#
# Validation class distribution:
# label
# infacted        59
# not_infacted    44
# Name: count, dtype: int64
#
# Test class distribution:
# label
# infacted        149
# not_infacted    109
# Name: count, dtype: int64
#
#  Train/Val/Test CSVs saved successfully!

# %% [markdown]
# # EfficientNetB0 Version

# %%
import time
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
from sklearn.preprocessing import label_binarize
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.layers import GlobalAveragePooling2D, Dropout, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# ======= Adjustable Epochs =======
EPOCHS = 50  # 🔁 Change this number anytime
BATCH_SIZE = 32
IMAGE_SIZE = (224, 224)

# ======= Load CSVs =======
train_df = pd.read_csv("/kaggle/working/train_split.csv")
val_df = pd.read_csv("/kaggle/working/val_split.csv")
test_df = pd.read_csv("/kaggle/working/test_split.csv")

# ======= Image Data Generators =======
train_datagen = ImageDataGenerator(rescale=1./255, horizontal_flip=True)
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_gen = train_datagen.flow_from_dataframe(
    train_df, 
    x_col="filepath", 
    y_col="label",
    target_size=IMAGE_SIZE, 
    batch_size=BATCH_SIZE, 
    class_mode="categorical",
    shuffle=True
)

val_gen = val_datagen.flow_from_dataframe(
    val_df, 
    x_col="filepath", 
    y_col="label",
    target_size=IMAGE_SIZE, 
    batch_size=BATCH_SIZE, 
    class_mode="categorical",
    shuffle=False
)

test_gen = test_datagen.flow_from_dataframe(
    test_df, 
    x_col="filepath", 
    y_col="label",
    target_size=IMAGE_SIZE, 
    batch_size=BATCH_SIZE, 
    class_mode="categorical",
    shuffle=False
)

num_classes = len(train_gen.class_indices)


# ======= Build EfficientNetB0 Model =======
base_model = EfficientNetB0(weights="imagenet", include_top=False, input_shape=(224, 224, 3))
x = GlobalAveragePooling2D()(base_model.output)
x = Dropout(0.3)(x)
output = Dense(num_classes, activation="softmax")(x)

model = Model(inputs=base_model.input, outputs=output)

for layer in base_model.layers:
    layer.trainable = False

model.compile(optimizer=Adam(1e-4), loss="categorical_crossentropy", metrics=["accuracy"])


print("Classes in train set:", train_gen.class_indices)
print("Classes in test set:", test_gen.class_indices)


# ======= Train =======
start_train = time.time()
history = model.fit(train_gen, validation_data=val_gen, epochs=EPOCHS)
train_time = time.time() - start_train

# ======= Evaluate =======
start_test = time.time()
test_loss, test_acc = model.evaluate(test_gen)
test_time = time.time() - start_test

print(f"\n✅ Test Accuracy: {test_acc:.4f}")
print(f"⏱ Training Time: {train_time:.2f}s | Testing Time: {test_time:.2f}s")

# ======= Predictions =======
y_true = test_gen.classes
y_pred_probs = model.predict(test_gen)
y_pred = np.argmax(y_pred_probs, axis=1)
class_labels = list(test_gen.class_indices.keys())

# ======= Metrics =======
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_labels))

# ======= Confusion Matrix =======
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.title("Confusion Matrix — EfficientNetB0")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# ======= ROC–AUC for binary classification =======
from sklearn.metrics import roc_auc_score, roc_curve, auc

# Use probability of 'not_infacted' or positive class
y_pred_prob_pos = y_pred_probs[:, 1]  # probability of class 1

auc_score = roc_auc_score(y_true, y_pred_prob_pos)
fpr, tpr, _ = roc_curve(y_true, y_pred_prob_pos)

plt.figure()
plt.plot(fpr, tpr, label=f"Binary ROC (AUC={auc_score:.2f})")
plt.plot([0, 1], [0, 1], 'k--')
plt.title("ROC Curve — EfficientNetB0")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.show()

print(f"\nROC–AUC: {auc_score:.4f}")


# ======= GFLOPs =======
import os
import tensorflow as tf
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2

# ======= Suppress TensorFlow GPU info logs =======
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'  # Only show warnings and errors

# ======= Define your model =======
input_shape = (224, 224, 3)  # Fixed input size
model = EfficientNetB0(input_shape=input_shape, include_top=True, weights=None)

# ======= Convert to ConcreteFunction =======
full_model = tf.function(lambda x: model(x))
full_model = full_model.get_concrete_function(
    tf.TensorSpec([1, *input_shape], model.inputs[0].dtype)
)

# ======= Freeze the graph =======
frozen_func = convert_variables_to_constants_v2(full_model)
graph_def = frozen_func.graph.as_graph_def()

# ======= Use TF Profiler to calculate FLOPs =======
with tf.Graph().as_default() as graph:
    tf.import_graph_def(graph_def, name='')
    run_meta = tf.compat.v1.RunMetadata()
    opts = tf.compat.v1.profiler.ProfileOptionBuilder.float_operation()
    flops = tf.compat.v1.profiler.profile(graph=graph, run_meta=run_meta, cmd='op', options=opts)

# ======= Print GFLOPs per inference =======
print(f"\n⚙️ GFLOPs per inference (input size {input_shape}): {flops.total_float_ops / 1e9:.4f} GFLOPs")
# Out:
# Found 926 validated image filenames belonging to 2 classes.
# Found 103 validated image filenames belonging to 2 classes.
# Found 258 validated image filenames belonging to 2 classes.
# Classes in train set: {'infacted': 0, 'not_infacted': 1}
# Classes in test set: {'infacted': 0, 'not_infacted': 1}
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 113s 3s/step - accuracy: 0.5499 - loss: 0.6866 - val_accuracy: 0.5728 - val_loss: 0.6824
# Epoch 2/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 81s 3s/step - accuracy: 0.5611 - loss: 0.6850 - val_accuracy: 0.5728 - val_loss: 0.6825
# Epoch 3/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 71s 2s/step - accuracy: 0.5558 - loss: 0.6859 - val_accuracy: 0.5728 - val_loss: 0.6823
# Epoch 4/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 72s 2s/step - accuracy: 0.5609 - loss: 0.6853 - val_accuracy: 0.5728 - val_loss: 0.6824
# Epoch 5/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 73s 3s/step - accuracy: 0.5250 - loss: 0.6924 - val_accuracy: 0.5728 - val_loss: 0.6824
# Epoch 6/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 87s 3s/step - accuracy: 0.5369 - loss: 0.6981 - val_accuracy: 0.5728 - val_loss: 0.6824
# Epoch 7/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 77s 3s/step - accuracy: 0.5553 - loss: 0.6865 - val_accuracy: 0.5728 - val_loss: 0.6825
# Epoch 8/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - accuracy: 0.5601 - loss: 0.6939 - val_accuracy: 0.5728 - val_loss: 0.6835
# Epoch 9/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - accuracy: 0.5513 - loss: 0.6982 - val_accuracy: 0.5728 - val_loss: 0.6823
# Epoch 10/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 75s 3s/step - accuracy: 0.5664 - loss: 0.6825 - val_accuracy: 0.5728 - val_loss: 0.6824
# Epoch 11/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 71s 2s/step - accuracy: 0.5845 - loss: 0.6835 - val_accuracy: 0.5728 - val_loss: 0.6824
# Epoch 12/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 77s 3s/step - accuracy: 0.5444 - loss: 0.6942 - val_accuracy: 0.5728 - val_loss: 0.6825
# Epoch 13/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 80s 3s/step - accuracy: 0.5663 - loss: 0.6862 - val_accuracy: 0.5728 - val_loss: 0.6823
# Epoch 14/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 77s 3s/step - accuracy: 0.5569 - loss: 0.6863 - val_accuracy: 0.5728 - val_loss: 0.6823
# Epoch 15/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 81s 3s/step - accuracy: 0.5674 - loss: 0.6839 - val_accuracy: 0.5728 - val_loss: 0.6827
# Epoch 16/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 73s 3s/step - accuracy: 0.5742 - loss: 0.6845 - val_accuracy: 0.5728 - val_loss: 0.6824
# Epoch 17/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 77s 3s/step - accuracy: 0.5570 - loss: 0.6948 - val_accuracy: 0.5728 - val_loss: 0.6824
# Epoch 18/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 73s 3s/step - accuracy: 0.5797 - loss: 0.6836 - val_accuracy: 0.5728 - val_loss: 0.6824
# Epoch 19/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 80s 3s/step - accuracy: 0.5353 - loss: 0.6973 - val_accuracy: 0.5728 - val_loss: 0.6826
# Epoch 20/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 72s 2s/step - accuracy: 0.5700 - loss: 0.6919 - val_accuracy: 0.5728 - val_loss: 0.6826
# Epoch 21/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 72s 2s/step - accuracy: 0.5934 - loss: 0.6774 - val_accuracy: 0.5728 - val_loss: 0.6823
# Epoch 22/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 74s 3s/step - accuracy: 0.5346 - loss: 0.6925 - val_accuracy: 0.5728 - val_loss: 0.6824
# Epoch 23/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 74s 3s/step - accuracy: 0.5727 - loss: 0.6915 - val_accuracy: 0.5728 - val_loss: 0.6829
# Epoch 24/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 82s 3s/step - accuracy: 0.5638 - loss: 0.6915 - val_accuracy: 0.5728 - val_loss: 0.6824
# Epoch 25/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 77s 3s/step - accuracy: 0.5284 - loss: 0.6993 - val_accuracy: 0.5728 - val_loss: 0.6824
# Epoch 26/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 75s 3s/step - accuracy: 0.5556 - loss: 0.6872 - val_accuracy: 0.5728 - val_loss: 0.6824
# Epoch 27/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 73s 3s/step - accuracy: 0.5328 - loss: 0.6954 - val_accuracy: 0.5728 - val_loss: 0.6823
# Epoch 28/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 75s 3s/step - accuracy: 0.5395 - loss: 0.6984 - val_accuracy: 0.5728 - val_loss: 0.6825
# Epoch 29/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 72s 2s/step - accuracy: 0.5409 - loss: 0.6951 - val_accuracy: 0.5728 - val_loss: 0.6829
# Epoch 30/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 81s 3s/step - accuracy: 0.5626 - loss: 0.6899 - val_accuracy: 0.5728 - val_loss: 0.6823
# Epoch 31/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 81s 3s/step - accuracy: 0.5492 - loss: 0.7009 - val_accuracy: 0.5728 - val_loss: 0.6824
# Epoch 32/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 82s 3s/step - accuracy: 0.5532 - loss: 0.6952 - val_accuracy: 0.5728 - val_loss: 0.6829
# Epoch 33/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 71s 2s/step - accuracy: 0.5411 - loss: 0.6939 - val_accuracy: 0.5728 - val_loss: 0.6823
# Epoch 34/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 87s 3s/step - accuracy: 0.5621 - loss: 0.6865 - val_accuracy: 0.5728 - val_loss: 0.6824
# Epoch 35/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 74s 3s/step - accuracy: 0.5463 - loss: 0.6958 - val_accuracy: 0.5728 - val_loss: 0.6826
# Epoch 36/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - accuracy: 0.5645 - loss: 0.6847 - val_accuracy: 0.5728 - val_loss: 0.6824
# Epoch 37/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 85s 3s/step - accuracy: 0.5459 - loss: 0.6791 - val_accuracy: 0.5728 - val_loss: 0.6829
# Epoch 38/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 81s 3s/step - accuracy: 0.5692 - loss: 0.6860 - val_accuracy: 0.5728 - val_loss: 0.6824
# Epoch 39/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 82s 3s/step - accuracy: 0.5942 - loss: 0.6748 - val_accuracy: 0.5728 - val_loss: 0.6823
# Epoch 40/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 72s 3s/step - accuracy: 0.5471 - loss: 0.6853 - val_accuracy: 0.5728 - val_loss: 0.6824
# Epoch 41/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 81s 3s/step - accuracy: 0.5797 - loss: 0.6827 - val_accuracy: 0.5728 - val_loss: 0.6830
# Epoch 42/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 73s 3s/step - accuracy: 0.5745 - loss: 0.6785 - val_accuracy: 0.5728 - val_loss: 0.6826
# Epoch 43/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - accuracy: 0.5482 - loss: 0.6911 - val_accuracy: 0.5728 - val_loss: 0.6825
# Epoch 44/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 72s 2s/step - accuracy: 0.5196 - loss: 0.7025 - val_accuracy: 0.5728 - val_loss: 0.6823
# Epoch 45/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - accuracy: 0.5440 - loss: 0.6911 - val_accuracy: 0.5728 - val_loss: 0.6828
# Epoch 46/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 82s 3s/step - accuracy: 0.5511 - loss: 0.6970 - val_accuracy: 0.5728 - val_loss: 0.6823
# Epoch 47/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 74s 3s/step - accuracy: 0.5679 - loss: 0.6866 - val_accuracy: 0.5728 - val_loss: 0.6826
# Epoch 48/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 72s 2s/step - accuracy: 0.5507 - loss: 0.6955 - val_accuracy: 0.5728 - val_loss: 0.6823
# Epoch 49/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 76s 3s/step - accuracy: 0.5078 - loss: 0.7033 - val_accuracy: 0.5728 - val_loss: 0.6824
# Epoch 50/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 81s 3s/step - accuracy: 0.5622 - loss: 0.6836 - val_accuracy: 0.5728 - val_loss: 0.6840
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 23s 3s/step - accuracy: 0.5901 - loss: 0.6769
#
# ✅ Test Accuracy: 0.5775
# ⏱ Training Time: 3888.73s | Testing Time: 29.23s
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 30s 3s/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     infacted       0.58      1.00      0.73       149
# not_infacted       0.00      0.00      0.00       109
#
#     accuracy                           0.58       258
#    macro avg       0.29      0.50      0.37       258
# weighted avg       0.33      0.58      0.42       258
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ROC–AUC: 0.7042
# I0000 00:00:1761598953.010991      19 devices.cc:67] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 1
# I0000 00:00:1761598953.011170      19 single_machine.cc:361] Starting new session
# I0000 00:00:1761598953.012259      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# op: The nodes are operation kernel type, such as MatMul, Conv2D. Graph nodes belonging to the same type are aggregated together.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# Conv2D                   700.01m float_ops (100.00%, 87.17%)
# DepthwiseConv2dNative    69.06m float_ops (12.83%, 8.60%)
# Mul                      21.55m float_ops (4.23%, 2.68%)
# AddV2                    7.12m float_ops (1.55%, 0.89%)
# MatMul                   2.56m float_ops (0.66%, 0.32%)
# Mean                     2.37m float_ops (0.34%, 0.30%)
# Sub                      171.54k float_ops (0.05%, 0.02%)
# RealDiv                  150.53k float_ops (0.03%, 0.02%)
# Rsqrt                    42.02k float_ops (0.01%, 0.01%)
# BiasAdd                  10.34k float_ops (0.00%, 0.00%)
# Softmax                  5.00k float_ops (0.00%, 0.00%)
# Maximum                      3 float_ops (0.00%, 0.00%)
#
# ======================End of Report==========================
#
# ⚙️ GFLOPs per inference (input size (224, 224, 3)): 0.8031 GFLOPs

# %% [markdown]
# # Validation Split
# # train (70%)
# # test (30%)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Example: df should have columns ['filepath', 'label', 'group']

train_df, test_df = train_test_split(
    df,
    test_size=0.3,
    stratify=df["label"],
    random_state=42
)

# Validation = 10% of total dataset → 10 / 70 ≈ 0.1429 of train
train_df, val_df = train_test_split(
    train_df,
    test_size=0.1,
    stratify=train_df["label"],
    random_state=42
)

# Step 3: Print results
print("Train size:", len(train_df))
print("Validation size:", len(val_df))
print("Test size:", len(test_df))

print("\nTrain class distribution:")
print(train_df["label"].value_counts())
print("\nValidation class distribution:")
print(val_df["label"].value_counts())
print("\nTest class distribution:")
print(test_df["label"].value_counts())

# Step 4: Save CSVs
train_df.to_csv("/kaggle/working/train_split.csv", index=False)
val_df.to_csv("/kaggle/working/val_split.csv", index=False)
test_df.to_csv("/kaggle/working/test_split.csv", index=False)

print("\n Train/Val/Test CSVs saved successfully!")
# Out:
# Train size: 810
# Validation size: 90
# Test size: 387
#
# Train class distribution:
# label
# infacted        466
# not_infacted    344
# Name: count, dtype: int64
#
# Validation class distribution:
# label
# infacted        52
# not_infacted    38
# Name: count, dtype: int64
#
# Test class distribution:
# label
# infacted        223
# not_infacted    164
# Name: count, dtype: int64
#
#  Train/Val/Test CSVs saved successfully!

# %% [markdown]
# # EfficientNetB0 Version

# %%
import time
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
from sklearn.preprocessing import label_binarize
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.layers import GlobalAveragePooling2D, Dropout, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# ======= Adjustable Epochs =======
EPOCHS = 50  # 🔁 Change this number anytime
BATCH_SIZE = 32
IMAGE_SIZE = (224, 224)

# ======= Load CSVs =======
train_df = pd.read_csv("/kaggle/working/train_split.csv")
val_df = pd.read_csv("/kaggle/working/val_split.csv")
test_df = pd.read_csv("/kaggle/working/test_split.csv")

# ======= Image Data Generators =======
train_datagen = ImageDataGenerator(rescale=1./255, horizontal_flip=True)
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_gen = train_datagen.flow_from_dataframe(
    train_df, 
    x_col="filepath", 
    y_col="label",
    target_size=IMAGE_SIZE, 
    batch_size=BATCH_SIZE, 
    class_mode="categorical",
    shuffle=True
)

val_gen = val_datagen.flow_from_dataframe(
    val_df, 
    x_col="filepath", 
    y_col="label",
    target_size=IMAGE_SIZE, 
    batch_size=BATCH_SIZE, 
    class_mode="categorical",
    shuffle=False
)

test_gen = test_datagen.flow_from_dataframe(
    test_df, 
    x_col="filepath", 
    y_col="label",
    target_size=IMAGE_SIZE, 
    batch_size=BATCH_SIZE, 
    class_mode="categorical",
    shuffle=False
)

num_classes = len(train_gen.class_indices)


# ======= Build EfficientNetB0 Model =======
base_model = EfficientNetB0(weights="imagenet", include_top=False, input_shape=(224, 224, 3))
x = GlobalAveragePooling2D()(base_model.output)
x = Dropout(0.3)(x)
output = Dense(num_classes, activation="softmax")(x)

model = Model(inputs=base_model.input, outputs=output)

for layer in base_model.layers:
    layer.trainable = False

model.compile(optimizer=Adam(1e-4), loss="categorical_crossentropy", metrics=["accuracy"])


print("Classes in train set:", train_gen.class_indices)
print("Classes in test set:", test_gen.class_indices)


# ======= Train =======
start_train = time.time()
history = model.fit(train_gen, validation_data=val_gen, epochs=EPOCHS)
train_time = time.time() - start_train

# ======= Evaluate =======
start_test = time.time()
test_loss, test_acc = model.evaluate(test_gen)
test_time = time.time() - start_test

print(f"\n✅ Test Accuracy: {test_acc:.4f}")
print(f"⏱ Training Time: {train_time:.2f}s | Testing Time: {test_time:.2f}s")

# ======= Predictions =======
y_true = test_gen.classes
y_pred_probs = model.predict(test_gen)
y_pred = np.argmax(y_pred_probs, axis=1)
class_labels = list(test_gen.class_indices.keys())

# ======= Metrics =======
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_labels))

# ======= Confusion Matrix =======
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.title("Confusion Matrix — EfficientNetB0")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# ======= ROC–AUC for binary classification =======
from sklearn.metrics import roc_auc_score, roc_curve, auc

# Use probability of 'not_infacted' or positive class
y_pred_prob_pos = y_pred_probs[:, 1]  # probability of class 1

auc_score = roc_auc_score(y_true, y_pred_prob_pos)
fpr, tpr, _ = roc_curve(y_true, y_pred_prob_pos)

plt.figure()
plt.plot(fpr, tpr, label=f"Binary ROC (AUC={auc_score:.2f})")
plt.plot([0, 1], [0, 1], 'k--')
plt.title("ROC Curve — EfficientNetB0")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.show()

print(f"\nROC–AUC: {auc_score:.4f}")


# ======= GFLOPs =======
import os
import tensorflow as tf
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2

# ======= Suppress TensorFlow GPU info logs =======
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'  # Only show warnings and errors

# ======= Define your model =======
input_shape = (224, 224, 3)  # Fixed input size
model = EfficientNetB0(input_shape=input_shape, include_top=True, weights=None)

# ======= Convert to ConcreteFunction =======
full_model = tf.function(lambda x: model(x))
full_model = full_model.get_concrete_function(
    tf.TensorSpec([1, *input_shape], model.inputs[0].dtype)
)

# ======= Freeze the graph =======
frozen_func = convert_variables_to_constants_v2(full_model)
graph_def = frozen_func.graph.as_graph_def()

# ======= Use TF Profiler to calculate FLOPs =======
with tf.Graph().as_default() as graph:
    tf.import_graph_def(graph_def, name='')
    run_meta = tf.compat.v1.RunMetadata()
    opts = tf.compat.v1.profiler.ProfileOptionBuilder.float_operation()
    flops = tf.compat.v1.profiler.profile(graph=graph, run_meta=run_meta, cmd='op', options=opts)

# ======= Print GFLOPs per inference =======
print(f"\n⚙️ GFLOPs per inference (input size {input_shape}): {flops.total_float_ops / 1e9:.4f} GFLOPs")
# Out:
# Found 810 validated image filenames belonging to 2 classes.
# Found 90 validated image filenames belonging to 2 classes.
# Found 387 validated image filenames belonging to 2 classes.
# Classes in train set: {'infacted': 0, 'not_infacted': 1}
# Classes in test set: {'infacted': 0, 'not_infacted': 1}
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 104s 3s/step - accuracy: 0.5003 - loss: 0.7026 - val_accuracy: 0.5778 - val_loss: 0.6824
# Epoch 2/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 72s 3s/step - accuracy: 0.5466 - loss: 0.6946 - val_accuracy: 0.5778 - val_loss: 0.6811
# Epoch 3/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 66s 3s/step - accuracy: 0.5577 - loss: 0.6913 - val_accuracy: 0.5778 - val_loss: 0.6811
# Epoch 4/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 72s 3s/step - accuracy: 0.5820 - loss: 0.6867 - val_accuracy: 0.5778 - val_loss: 0.6811
# Epoch 5/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 64s 2s/step - accuracy: 0.5432 - loss: 0.6930 - val_accuracy: 0.5778 - val_loss: 0.6810
# Epoch 6/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 80s 3s/step - accuracy: 0.5747 - loss: 0.6807 - val_accuracy: 0.5778 - val_loss: 0.6811
# Epoch 7/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 64s 2s/step - accuracy: 0.5463 - loss: 0.6958 - val_accuracy: 0.5778 - val_loss: 0.6811
# Epoch 8/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 67s 3s/step - accuracy: 0.5519 - loss: 0.6913 - val_accuracy: 0.5778 - val_loss: 0.6810
# Epoch 9/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 70s 3s/step - accuracy: 0.5708 - loss: 0.6918 - val_accuracy: 0.5778 - val_loss: 0.6810
# Epoch 10/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 64s 2s/step - accuracy: 0.5461 - loss: 0.6968 - val_accuracy: 0.5778 - val_loss: 0.6810
# Epoch 11/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 66s 3s/step - accuracy: 0.5817 - loss: 0.6774 - val_accuracy: 0.5778 - val_loss: 0.6810
# Epoch 12/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 65s 3s/step - accuracy: 0.5616 - loss: 0.6875 - val_accuracy: 0.5778 - val_loss: 0.6811
# Epoch 13/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 64s 2s/step - accuracy: 0.5416 - loss: 0.6967 - val_accuracy: 0.5778 - val_loss: 0.6811
# Epoch 14/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 67s 3s/step - accuracy: 0.5903 - loss: 0.6807 - val_accuracy: 0.5778 - val_loss: 0.6810
# Epoch 15/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 72s 3s/step - accuracy: 0.5230 - loss: 0.6952 - val_accuracy: 0.5778 - val_loss: 0.6818
# Epoch 16/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 64s 2s/step - accuracy: 0.5235 - loss: 0.6942 - val_accuracy: 0.5778 - val_loss: 0.6811
# Epoch 17/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 70s 3s/step - accuracy: 0.5598 - loss: 0.6965 - val_accuracy: 0.5778 - val_loss: 0.6810
# Epoch 18/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - accuracy: 0.5380 - loss: 0.7000 - val_accuracy: 0.5778 - val_loss: 0.6810
# Epoch 19/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 63s 2s/step - accuracy: 0.5334 - loss: 0.6954 - val_accuracy: 0.5778 - val_loss: 0.6818
# Epoch 20/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 70s 3s/step - accuracy: 0.5657 - loss: 0.6952 - val_accuracy: 0.5778 - val_loss: 0.6811
# Epoch 21/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - accuracy: 0.5677 - loss: 0.6816 - val_accuracy: 0.5778 - val_loss: 0.6812
# Epoch 22/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 74s 3s/step - accuracy: 0.5794 - loss: 0.6827 - val_accuracy: 0.5778 - val_loss: 0.6814
# Epoch 23/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 76s 3s/step - accuracy: 0.5861 - loss: 0.6741 - val_accuracy: 0.5778 - val_loss: 0.6811
# Epoch 24/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 74s 3s/step - accuracy: 0.5846 - loss: 0.6775 - val_accuracy: 0.5778 - val_loss: 0.6811
# Epoch 25/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 70s 3s/step - accuracy: 0.5174 - loss: 0.6966 - val_accuracy: 0.5778 - val_loss: 0.6810
# Epoch 26/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 67s 3s/step - accuracy: 0.5593 - loss: 0.6823 - val_accuracy: 0.5778 - val_loss: 0.6811
# Epoch 27/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 64s 2s/step - accuracy: 0.5335 - loss: 0.6886 - val_accuracy: 0.5778 - val_loss: 0.6810
# Epoch 28/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 82s 3s/step - accuracy: 0.5730 - loss: 0.6821 - val_accuracy: 0.5778 - val_loss: 0.6813
# Epoch 29/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 74s 3s/step - accuracy: 0.5397 - loss: 0.6921 - val_accuracy: 0.5778 - val_loss: 0.6815
# Epoch 30/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 70s 3s/step - accuracy: 0.5445 - loss: 0.6867 - val_accuracy: 0.5778 - val_loss: 0.6811
# Epoch 31/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 65s 2s/step - accuracy: 0.5632 - loss: 0.7037 - val_accuracy: 0.5778 - val_loss: 0.6811
# Epoch 32/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 67s 3s/step - accuracy: 0.5508 - loss: 0.6981 - val_accuracy: 0.5778 - val_loss: 0.6815
# Epoch 33/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 72s 3s/step - accuracy: 0.5439 - loss: 0.6915 - val_accuracy: 0.5778 - val_loss: 0.6810
# Epoch 34/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 71s 3s/step - accuracy: 0.5672 - loss: 0.6908 - val_accuracy: 0.5778 - val_loss: 0.6810
# Epoch 35/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 66s 3s/step - accuracy: 0.5297 - loss: 0.7056 - val_accuracy: 0.5778 - val_loss: 0.6810
# Epoch 36/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 67s 3s/step - accuracy: 0.5965 - loss: 0.6774 - val_accuracy: 0.5778 - val_loss: 0.6810
# Epoch 37/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 67s 3s/step - accuracy: 0.5558 - loss: 0.6895 - val_accuracy: 0.5778 - val_loss: 0.6814
# Epoch 38/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 66s 3s/step - accuracy: 0.5585 - loss: 0.6857 - val_accuracy: 0.5778 - val_loss: 0.6810
# Epoch 39/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - accuracy: 0.5516 - loss: 0.6887 - val_accuracy: 0.5778 - val_loss: 0.6811
# Epoch 40/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - accuracy: 0.5834 - loss: 0.6879 - val_accuracy: 0.5778 - val_loss: 0.6810
# Epoch 41/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 75s 3s/step - accuracy: 0.5281 - loss: 0.6965 - val_accuracy: 0.5778 - val_loss: 0.6810
# Epoch 42/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 66s 3s/step - accuracy: 0.5638 - loss: 0.6790 - val_accuracy: 0.5778 - val_loss: 0.6810
# Epoch 43/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 70s 3s/step - accuracy: 0.5672 - loss: 0.6893 - val_accuracy: 0.5778 - val_loss: 0.6810
# Epoch 44/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 65s 3s/step - accuracy: 0.5105 - loss: 0.7025 - val_accuracy: 0.5778 - val_loss: 0.6811
# Epoch 45/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 69s 3s/step - accuracy: 0.5395 - loss: 0.6968 - val_accuracy: 0.5778 - val_loss: 0.6810
# Epoch 46/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 65s 3s/step - accuracy: 0.5377 - loss: 0.7038 - val_accuracy: 0.5778 - val_loss: 0.6810
# Epoch 47/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - accuracy: 0.5590 - loss: 0.6890 - val_accuracy: 0.5778 - val_loss: 0.6810
# Epoch 48/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 76s 3s/step - accuracy: 0.5555 - loss: 0.6874 - val_accuracy: 0.5778 - val_loss: 0.6811
# Epoch 49/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 63s 2s/step - accuracy: 0.5291 - loss: 0.6975 - val_accuracy: 0.5778 - val_loss: 0.6810
# Epoch 50/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 67s 3s/step - accuracy: 0.5323 - loss: 0.7018 - val_accuracy: 0.5778 - val_loss: 0.6810
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 34s 3s/step - accuracy: 0.6024 - loss: 0.6729
#
# ✅ Test Accuracy: 0.5762
# ⏱ Training Time: 3478.42s | Testing Time: 39.79s
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     infacted       0.58      1.00      0.73       223
# not_infacted       0.00      0.00      0.00       164
#
#     accuracy                           0.58       387
#    macro avg       0.29      0.50      0.37       387
# weighted avg       0.33      0.58      0.42       387
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ROC–AUC: 0.5048
# I0000 00:00:1761602527.649409      19 devices.cc:67] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 1
# I0000 00:00:1761602527.649591      19 single_machine.cc:361] Starting new session
# I0000 00:00:1761602527.650709      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# op: The nodes are operation kernel type, such as MatMul, Conv2D. Graph nodes belonging to the same type are aggregated together.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# Conv2D                   700.01m float_ops (100.00%, 87.17%)
# DepthwiseConv2dNative    69.06m float_ops (12.83%, 8.60%)
# Mul                      21.55m float_ops (4.23%, 2.68%)
# AddV2                    7.12m float_ops (1.55%, 0.89%)
# MatMul                   2.56m float_ops (0.66%, 0.32%)
# Mean                     2.37m float_ops (0.34%, 0.30%)
# Sub                      171.54k float_ops (0.05%, 0.02%)
# RealDiv                  150.53k float_ops (0.03%, 0.02%)
# Rsqrt                    42.02k float_ops (0.01%, 0.01%)
# BiasAdd                  10.34k float_ops (0.00%, 0.00%)
# Softmax                  5.00k float_ops (0.00%, 0.00%)
# Maximum                      3 float_ops (0.00%, 0.00%)
#
# ======================End of Report==========================
#
# ⚙️ GFLOPs per inference (input size (224, 224, 3)): 0.8031 GFLOPs

# %% [markdown]
# # Validation Split
# # train (60%)
# # test (40%)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Example: df should have columns ['filepath', 'label', 'group']

train_df, test_df = train_test_split(
    df,
    test_size=0.4,
    stratify=df["label"],
    random_state=42
)

# Validation = 10% of total dataset → 10 / 60 ≈ 0.1667 of train
train_df, val_df = train_test_split(
    train_df,
    test_size=0.1,
    stratify=train_df["label"],
    random_state=42
)

# Step 3: Print results
print("Train size:", len(train_df))
print("Validation size:", len(val_df))
print("Test size:", len(test_df))

print("\nTrain class distribution:")
print(train_df["label"].value_counts())
print("\nValidation class distribution:")
print(val_df["label"].value_counts())
print("\nTest class distribution:")
print(test_df["label"].value_counts())

# Step 4: Save CSVs
train_df.to_csv("/kaggle/working/train_split.csv", index=False)
val_df.to_csv("/kaggle/working/val_split.csv", index=False)
test_df.to_csv("/kaggle/working/test_split.csv", index=False)

print("\n Train/Val/Test CSVs saved successfully!")
# Out:
# Train size: 694
# Validation size: 78
# Test size: 515
#
# Train class distribution:
# label
# infacted        399
# not_infacted    295
# Name: count, dtype: int64
#
# Validation class distribution:
# label
# infacted        45
# not_infacted    33
# Name: count, dtype: int64
#
# Test class distribution:
# label
# infacted        297
# not_infacted    218
# Name: count, dtype: int64
#
#  Train/Val/Test CSVs saved successfully!

# %% [markdown]
# # EfficientNetB0 Version

# %%
import time
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
from sklearn.preprocessing import label_binarize
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.layers import GlobalAveragePooling2D, Dropout, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# ======= Adjustable Epochs =======
EPOCHS = 50  # 🔁 Change this number anytime
BATCH_SIZE = 32
IMAGE_SIZE = (224, 224)

# ======= Load CSVs =======
train_df = pd.read_csv("/kaggle/working/train_split.csv")
val_df = pd.read_csv("/kaggle/working/val_split.csv")
test_df = pd.read_csv("/kaggle/working/test_split.csv")

# ======= Image Data Generators =======
train_datagen = ImageDataGenerator(rescale=1./255, horizontal_flip=True)
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_gen = train_datagen.flow_from_dataframe(
    train_df, 
    x_col="filepath", 
    y_col="label",
    target_size=IMAGE_SIZE, 
    batch_size=BATCH_SIZE, 
    class_mode="categorical",
    shuffle=True
)

val_gen = val_datagen.flow_from_dataframe(
    val_df, 
    x_col="filepath", 
    y_col="label",
    target_size=IMAGE_SIZE, 
    batch_size=BATCH_SIZE, 
    class_mode="categorical",
    shuffle=False
)

test_gen = test_datagen.flow_from_dataframe(
    test_df, 
    x_col="filepath", 
    y_col="label",
    target_size=IMAGE_SIZE, 
    batch_size=BATCH_SIZE, 
    class_mode="categorical",
    shuffle=False
)

num_classes = len(train_gen.class_indices)


# ======= Build EfficientNetB0 Model =======
base_model = EfficientNetB0(weights="imagenet", include_top=False, input_shape=(224, 224, 3))
x = GlobalAveragePooling2D()(base_model.output)
x = Dropout(0.3)(x)
output = Dense(num_classes, activation="softmax")(x)

model = Model(inputs=base_model.input, outputs=output)

for layer in base_model.layers:
    layer.trainable = False

model.compile(optimizer=Adam(1e-4), loss="categorical_crossentropy", metrics=["accuracy"])


print("Classes in train set:", train_gen.class_indices)
print("Classes in test set:", test_gen.class_indices)


# ======= Train =======
start_train = time.time()
history = model.fit(train_gen, validation_data=val_gen, epochs=EPOCHS)
train_time = time.time() - start_train

# ======= Evaluate =======
start_test = time.time()
test_loss, test_acc = model.evaluate(test_gen)
test_time = time.time() - start_test

print(f"\n✅ Test Accuracy: {test_acc:.4f}")
print(f"⏱ Training Time: {train_time:.2f}s | Testing Time: {test_time:.2f}s")

# ======= Predictions =======
y_true = test_gen.classes
y_pred_probs = model.predict(test_gen)
y_pred = np.argmax(y_pred_probs, axis=1)
class_labels = list(test_gen.class_indices.keys())

# ======= Metrics =======
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_labels))

# ======= Confusion Matrix =======
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.title("Confusion Matrix — EfficientNetB0")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# ======= ROC–AUC for binary classification =======
from sklearn.metrics import roc_auc_score, roc_curve, auc

# Use probability of 'not_infacted' or positive class
y_pred_prob_pos = y_pred_probs[:, 1]  # probability of class 1

auc_score = roc_auc_score(y_true, y_pred_prob_pos)
fpr, tpr, _ = roc_curve(y_true, y_pred_prob_pos)

plt.figure()
plt.plot(fpr, tpr, label=f"Binary ROC (AUC={auc_score:.2f})")
plt.plot([0, 1], [0, 1], 'k--')
plt.title("ROC Curve — EfficientNetB0")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.show()

print(f"\nROC–AUC: {auc_score:.4f}")


# ======= GFLOPs =======
import os
import tensorflow as tf
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2

# ======= Suppress TensorFlow GPU info logs =======
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'  # Only show warnings and errors

# ======= Define your model =======
input_shape = (224, 224, 3)  # Fixed input size
model = EfficientNetB0(input_shape=input_shape, include_top=True, weights=None)

# ======= Convert to ConcreteFunction =======
full_model = tf.function(lambda x: model(x))
full_model = full_model.get_concrete_function(
    tf.TensorSpec([1, *input_shape], model.inputs[0].dtype)
)

# ======= Freeze the graph =======
frozen_func = convert_variables_to_constants_v2(full_model)
graph_def = frozen_func.graph.as_graph_def()

# ======= Use TF Profiler to calculate FLOPs =======
with tf.Graph().as_default() as graph:
    tf.import_graph_def(graph_def, name='')
    run_meta = tf.compat.v1.RunMetadata()
    opts = tf.compat.v1.profiler.ProfileOptionBuilder.float_operation()
    flops = tf.compat.v1.profiler.profile(graph=graph, run_meta=run_meta, cmd='op', options=opts)

# ======= Print GFLOPs per inference =======
print(f"\n⚙️ GFLOPs per inference (input size {input_shape}): {flops.total_float_ops / 1e9:.4f} GFLOPs")
# Out:
# Found 694 validated image filenames belonging to 2 classes.
# Found 78 validated image filenames belonging to 2 classes.
# Found 515 validated image filenames belonging to 2 classes.
# Classes in train set: {'infacted': 0, 'not_infacted': 1}
# Classes in test set: {'infacted': 0, 'not_infacted': 1}
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 103s 4s/step - accuracy: 0.4173 - loss: 0.7263 - val_accuracy: 0.5769 - val_loss: 0.6816
# Epoch 2/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 57s 3s/step - accuracy: 0.5098 - loss: 0.7098 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 3/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - accuracy: 0.5567 - loss: 0.6923 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 4/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 56s 3s/step - accuracy: 0.5522 - loss: 0.6969 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 5/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 57s 3s/step - accuracy: 0.5576 - loss: 0.6887 - val_accuracy: 0.5769 - val_loss: 0.6815
# Epoch 6/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.5626 - loss: 0.6854 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 7/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - accuracy: 0.5157 - loss: 0.6994 - val_accuracy: 0.5769 - val_loss: 0.6817
# Epoch 8/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 57s 3s/step - accuracy: 0.5399 - loss: 0.6918 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 9/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.5537 - loss: 0.6943 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 10/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 55s 3s/step - accuracy: 0.5730 - loss: 0.6879 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 11/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 57s 3s/step - accuracy: 0.5750 - loss: 0.6946 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 12/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 56s 3s/step - accuracy: 0.5754 - loss: 0.6941 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 13/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - accuracy: 0.5543 - loss: 0.6897 - val_accuracy: 0.5769 - val_loss: 0.6817
# Epoch 14/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 56s 3s/step - accuracy: 0.5471 - loss: 0.7082 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 15/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 56s 3s/step - accuracy: 0.5704 - loss: 0.6910 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 16/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 63s 3s/step - accuracy: 0.5699 - loss: 0.6896 - val_accuracy: 0.5769 - val_loss: 0.6815
# Epoch 17/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 56s 3s/step - accuracy: 0.5281 - loss: 0.6866 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 18/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 57s 3s/step - accuracy: 0.5353 - loss: 0.6910 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 19/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.5717 - loss: 0.6814 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 20/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 60s 3s/step - accuracy: 0.5708 - loss: 0.6829 - val_accuracy: 0.5769 - val_loss: 0.6814
# Epoch 21/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 58s 3s/step - accuracy: 0.5740 - loss: 0.6842 - val_accuracy: 0.5769 - val_loss: 0.6815
# Epoch 22/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.5444 - loss: 0.6902 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 23/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 56s 3s/step - accuracy: 0.5367 - loss: 0.6904 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 24/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 62s 3s/step - accuracy: 0.5197 - loss: 0.6935 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 25/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 55s 3s/step - accuracy: 0.5514 - loss: 0.6844 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 26/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - accuracy: 0.5992 - loss: 0.6802 - val_accuracy: 0.5769 - val_loss: 0.6815
# Epoch 27/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 58s 3s/step - accuracy: 0.5615 - loss: 0.6764 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 28/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 57s 3s/step - accuracy: 0.5510 - loss: 0.6926 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 29/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 62s 3s/step - accuracy: 0.5733 - loss: 0.6751 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 30/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 58s 3s/step - accuracy: 0.5614 - loss: 0.6866 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 31/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 62s 3s/step - accuracy: 0.5251 - loss: 0.7098 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 32/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.5139 - loss: 0.7006 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 33/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 57s 3s/step - accuracy: 0.5419 - loss: 0.6902 - val_accuracy: 0.5769 - val_loss: 0.6814
# Epoch 34/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 58s 3s/step - accuracy: 0.5430 - loss: 0.6916 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 35/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 56s 3s/step - accuracy: 0.5435 - loss: 0.6993 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 36/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 55s 3s/step - accuracy: 0.5719 - loss: 0.6818 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 37/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 62s 3s/step - accuracy: 0.5505 - loss: 0.6867 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 38/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 56s 3s/step - accuracy: 0.5608 - loss: 0.6901 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 39/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 58s 3s/step - accuracy: 0.5598 - loss: 0.6910 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 40/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 56s 3s/step - accuracy: 0.5586 - loss: 0.6919 - val_accuracy: 0.5769 - val_loss: 0.6814
# Epoch 41/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 56s 3s/step - accuracy: 0.5522 - loss: 0.6841 - val_accuracy: 0.5769 - val_loss: 0.6815
# Epoch 42/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 62s 3s/step - accuracy: 0.5641 - loss: 0.6947 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 43/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - accuracy: 0.5623 - loss: 0.6959 - val_accuracy: 0.5769 - val_loss: 0.6814
# Epoch 44/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 63s 3s/step - accuracy: 0.5693 - loss: 0.6893 - val_accuracy: 0.5769 - val_loss: 0.6815
# Epoch 45/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.5292 - loss: 0.6926 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 46/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 60s 3s/step - accuracy: 0.5541 - loss: 0.6892 - val_accuracy: 0.5769 - val_loss: 0.6812
# Epoch 47/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - accuracy: 0.5181 - loss: 0.7029 - val_accuracy: 0.5769 - val_loss: 0.6812
# Epoch 48/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 56s 3s/step - accuracy: 0.5562 - loss: 0.6920 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 49/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - accuracy: 0.5717 - loss: 0.6803 - val_accuracy: 0.5769 - val_loss: 0.6812
# Epoch 50/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - accuracy: 0.5225 - loss: 0.7021 - val_accuracy: 0.5769 - val_loss: 0.6814
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.5903 - loss: 0.6778
#
# ✅ Test Accuracy: 0.5767
# ⏱ Training Time: 2936.35s | Testing Time: 48.31s
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 51s 3s/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     infacted       0.58      1.00      0.73       297
# not_infacted       0.00      0.00      0.00       218
#
#     accuracy                           0.58       515
#    macro avg       0.29      0.50      0.37       515
# weighted avg       0.33      0.58      0.42       515
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ROC–AUC: 0.5050
# I0000 00:00:1761605580.543394      19 devices.cc:67] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 1
# I0000 00:00:1761605580.543563      19 single_machine.cc:361] Starting new session
# I0000 00:00:1761605580.544730      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# op: The nodes are operation kernel type, such as MatMul, Conv2D. Graph nodes belonging to the same type are aggregated together.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# Conv2D                   700.01m float_ops (100.00%, 87.17%)
# DepthwiseConv2dNative    69.06m float_ops (12.83%, 8.60%)
# Mul                      21.55m float_ops (4.23%, 2.68%)
# AddV2                    7.12m float_ops (1.55%, 0.89%)
# MatMul                   2.56m float_ops (0.66%, 0.32%)
# Mean                     2.37m float_ops (0.34%, 0.30%)
# Sub                      171.54k float_ops (0.05%, 0.02%)
# RealDiv                  150.53k float_ops (0.03%, 0.02%)
# Rsqrt                    42.02k float_ops (0.01%, 0.01%)
# BiasAdd                  10.34k float_ops (0.00%, 0.00%)
# Softmax                  5.00k float_ops (0.00%, 0.00%)
# Maximum                      3 float_ops (0.00%, 0.00%)
#
# ======================End of Report==========================
#
# ⚙️ GFLOPs per inference (input size (224, 224, 3)): 0.8031 GFLOPs

# %% [markdown]
# # Validation Split
# # train (50%)
# # test (50%)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Example: df should have columns ['filepath', 'label', 'group']

train_df, test_df = train_test_split(
    df,
    test_size=0.5,
    stratify=df["label"],
    random_state=42
)

# Validation = 10% of total dataset → 10 / 50 = 0.2 of train
train_df, val_df = train_test_split(
    train_df,
    test_size=0.1,
    stratify=train_df["label"],
    random_state=42
)

# Step 3: Print results
print("Train size:", len(train_df))
print("Validation size:", len(val_df))
print("Test size:", len(test_df))

print("\nTrain class distribution:")
print(train_df["label"].value_counts())
print("\nValidation class distribution:")
print(val_df["label"].value_counts())
print("\nTest class distribution:")
print(test_df["label"].value_counts())

# Step 4: Save CSVs
train_df.to_csv("/kaggle/working/train_split.csv", index=False)
val_df.to_csv("/kaggle/working/val_split.csv", index=False)
test_df.to_csv("/kaggle/working/test_split.csv", index=False)

print("\n Train/Val/Test CSVs saved successfully!")
# Out:
# Train size: 578
# Validation size: 65
# Test size: 644
#
# Train class distribution:
# label
# infacted        333
# not_infacted    245
# Name: count, dtype: int64
#
# Validation class distribution:
# label
# infacted        37
# not_infacted    28
# Name: count, dtype: int64
#
# Test class distribution:
# label
# infacted        371
# not_infacted    273
# Name: count, dtype: int64
#
#  Train/Val/Test CSVs saved successfully!

# %% [markdown]
# # EfficientNetB0 Version

# %%
import time
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
from sklearn.preprocessing import label_binarize
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.layers import GlobalAveragePooling2D, Dropout, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# ======= Adjustable Epochs =======
EPOCHS = 50  # 🔁 Change this number anytime
BATCH_SIZE = 32
IMAGE_SIZE = (224, 224)

# ======= Load CSVs =======
train_df = pd.read_csv("/kaggle/working/train_split.csv")
val_df = pd.read_csv("/kaggle/working/val_split.csv")
test_df = pd.read_csv("/kaggle/working/test_split.csv")

# ======= Image Data Generators =======
train_datagen = ImageDataGenerator(rescale=1./255, horizontal_flip=True)
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_gen = train_datagen.flow_from_dataframe(
    train_df, 
    x_col="filepath", 
    y_col="label",
    target_size=IMAGE_SIZE, 
    batch_size=BATCH_SIZE, 
    class_mode="categorical",
    shuffle=True
)

val_gen = val_datagen.flow_from_dataframe(
    val_df, 
    x_col="filepath", 
    y_col="label",
    target_size=IMAGE_SIZE, 
    batch_size=BATCH_SIZE, 
    class_mode="categorical",
    shuffle=False
)

test_gen = test_datagen.flow_from_dataframe(
    test_df, 
    x_col="filepath", 
    y_col="label",
    target_size=IMAGE_SIZE, 
    batch_size=BATCH_SIZE, 
    class_mode="categorical",
    shuffle=False
)

num_classes = len(train_gen.class_indices)


# ======= Build EfficientNetB0 Model =======
base_model = EfficientNetB0(weights="imagenet", include_top=False, input_shape=(224, 224, 3))
x = GlobalAveragePooling2D()(base_model.output)
x = Dropout(0.3)(x)
output = Dense(num_classes, activation="softmax")(x)

model = Model(inputs=base_model.input, outputs=output)

for layer in base_model.layers:
    layer.trainable = False

model.compile(optimizer=Adam(1e-4), loss="categorical_crossentropy", metrics=["accuracy"])


print("Classes in train set:", train_gen.class_indices)
print("Classes in test set:", test_gen.class_indices)


# ======= Train =======
start_train = time.time()
history = model.fit(train_gen, validation_data=val_gen, epochs=EPOCHS)
train_time = time.time() - start_train

# ======= Evaluate =======
start_test = time.time()
test_loss, test_acc = model.evaluate(test_gen)
test_time = time.time() - start_test

print(f"\n✅ Test Accuracy: {test_acc:.4f}")
print(f"⏱ Training Time: {train_time:.2f}s | Testing Time: {test_time:.2f}s")

# ======= Predictions =======
y_true = test_gen.classes
y_pred_probs = model.predict(test_gen)
y_pred = np.argmax(y_pred_probs, axis=1)
class_labels = list(test_gen.class_indices.keys())

# ======= Metrics =======
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_labels))

# ======= Confusion Matrix =======
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.title("Confusion Matrix — EfficientNetB0")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# ======= ROC–AUC for binary classification =======
from sklearn.metrics import roc_auc_score, roc_curve, auc

# Use probability of 'not_infacted' or positive class
y_pred_prob_pos = y_pred_probs[:, 1]  # probability of class 1

auc_score = roc_auc_score(y_true, y_pred_prob_pos)
fpr, tpr, _ = roc_curve(y_true, y_pred_prob_pos)

plt.figure()
plt.plot(fpr, tpr, label=f"Binary ROC (AUC={auc_score:.2f})")
plt.plot([0, 1], [0, 1], 'k--')
plt.title("ROC Curve — EfficientNetB0")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.show()

print(f"\nROC–AUC: {auc_score:.4f}")


# ======= GFLOPs =======
import os
import tensorflow as tf
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2

# ======= Suppress TensorFlow GPU info logs =======
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'  # Only show warnings and errors

# ======= Define your model =======
input_shape = (224, 224, 3)  # Fixed input size
model = EfficientNetB0(input_shape=input_shape, include_top=True, weights=None)

# ======= Convert to ConcreteFunction =======
full_model = tf.function(lambda x: model(x))
full_model = full_model.get_concrete_function(
    tf.TensorSpec([1, *input_shape], model.inputs[0].dtype)
)

# ======= Freeze the graph =======
frozen_func = convert_variables_to_constants_v2(full_model)
graph_def = frozen_func.graph.as_graph_def()

# ======= Use TF Profiler to calculate FLOPs =======
with tf.Graph().as_default() as graph:
    tf.import_graph_def(graph_def, name='')
    run_meta = tf.compat.v1.RunMetadata()
    opts = tf.compat.v1.profiler.ProfileOptionBuilder.float_operation()
    flops = tf.compat.v1.profiler.profile(graph=graph, run_meta=run_meta, cmd='op', options=opts)

# ======= Print GFLOPs per inference =======
print(f"\n⚙️ GFLOPs per inference (input size {input_shape}): {flops.total_float_ops / 1e9:.4f} GFLOPs")
# Out:
# Found 578 validated image filenames belonging to 2 classes.
# Found 65 validated image filenames belonging to 2 classes.
# Found 644 validated image filenames belonging to 2 classes.
# Classes in train set: {'infacted': 0, 'not_infacted': 1}
# Classes in test set: {'infacted': 0, 'not_infacted': 1}
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 86s 3s/step - accuracy: 0.5448 - loss: 0.6899 - val_accuracy: 0.5692 - val_loss: 0.6851
# Epoch 2/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 50s 3s/step - accuracy: 0.5468 - loss: 0.6995 - val_accuracy: 0.5692 - val_loss: 0.6867
# Epoch 3/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 47s 2s/step - accuracy: 0.5330 - loss: 0.7130 - val_accuracy: 0.5692 - val_loss: 0.6845
# Epoch 4/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 53s 3s/step - accuracy: 0.5987 - loss: 0.6802 - val_accuracy: 0.5692 - val_loss: 0.6846
# Epoch 5/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 52s 3s/step - accuracy: 0.5563 - loss: 0.6935 - val_accuracy: 0.5692 - val_loss: 0.6838
# Epoch 6/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 49s 3s/step - accuracy: 0.5330 - loss: 0.6944 - val_accuracy: 0.5692 - val_loss: 0.6838
# Epoch 7/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 47s 2s/step - accuracy: 0.5575 - loss: 0.6861 - val_accuracy: 0.5692 - val_loss: 0.6850
# Epoch 8/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 50s 3s/step - accuracy: 0.5812 - loss: 0.6825 - val_accuracy: 0.5692 - val_loss: 0.6838
# Epoch 9/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 49s 3s/step - accuracy: 0.5634 - loss: 0.6783 - val_accuracy: 0.5692 - val_loss: 0.6839
# Epoch 10/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 56s 3s/step - accuracy: 0.5929 - loss: 0.6918 - val_accuracy: 0.5692 - val_loss: 0.6848
# Epoch 11/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 48s 3s/step - accuracy: 0.5598 - loss: 0.6875 - val_accuracy: 0.5692 - val_loss: 0.6838
# Epoch 12/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 51s 3s/step - accuracy: 0.6144 - loss: 0.6769 - val_accuracy: 0.5692 - val_loss: 0.6838
# Epoch 13/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 50s 3s/step - accuracy: 0.5452 - loss: 0.6935 - val_accuracy: 0.5692 - val_loss: 0.6842
# Epoch 14/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 47s 2s/step - accuracy: 0.5190 - loss: 0.6977 - val_accuracy: 0.5692 - val_loss: 0.6838
# Epoch 15/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 52s 3s/step - accuracy: 0.5513 - loss: 0.6891 - val_accuracy: 0.5692 - val_loss: 0.6854
# Epoch 16/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 47s 2s/step - accuracy: 0.5796 - loss: 0.6769 - val_accuracy: 0.5692 - val_loss: 0.6838
# Epoch 17/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 47s 2s/step - accuracy: 0.5214 - loss: 0.7000 - val_accuracy: 0.5692 - val_loss: 0.6840
# Epoch 18/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 48s 3s/step - accuracy: 0.5663 - loss: 0.6906 - val_accuracy: 0.5692 - val_loss: 0.6839
# Epoch 19/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 49s 3s/step - accuracy: 0.5658 - loss: 0.6858 - val_accuracy: 0.5692 - val_loss: 0.6846
# Epoch 20/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 47s 2s/step - accuracy: 0.5311 - loss: 0.6945 - val_accuracy: 0.5692 - val_loss: 0.6838
# Epoch 21/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 54s 3s/step - accuracy: 0.6138 - loss: 0.6757 - val_accuracy: 0.5692 - val_loss: 0.6840
# Epoch 22/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 49s 3s/step - accuracy: 0.5151 - loss: 0.7130 - val_accuracy: 0.5692 - val_loss: 0.6850
# Epoch 23/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 48s 3s/step - accuracy: 0.5416 - loss: 0.6931 - val_accuracy: 0.5692 - val_loss: 0.6842
# Epoch 24/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 47s 2s/step - accuracy: 0.5924 - loss: 0.6778 - val_accuracy: 0.5692 - val_loss: 0.6838
# Epoch 25/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 46s 2s/step - accuracy: 0.5737 - loss: 0.6882 - val_accuracy: 0.5692 - val_loss: 0.6838
# Epoch 26/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 51s 3s/step - accuracy: 0.5487 - loss: 0.6983 - val_accuracy: 0.5692 - val_loss: 0.6838
# Epoch 27/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 50s 3s/step - accuracy: 0.5709 - loss: 0.6791 - val_accuracy: 0.5692 - val_loss: 0.6846
# Epoch 28/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 52s 3s/step - accuracy: 0.5914 - loss: 0.6718 - val_accuracy: 0.5692 - val_loss: 0.6840
# Epoch 29/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 48s 3s/step - accuracy: 0.5917 - loss: 0.6808 - val_accuracy: 0.5692 - val_loss: 0.6850
# Epoch 30/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 48s 3s/step - accuracy: 0.5374 - loss: 0.6951 - val_accuracy: 0.5692 - val_loss: 0.6837
# Epoch 31/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 46s 2s/step - accuracy: 0.5742 - loss: 0.6916 - val_accuracy: 0.5692 - val_loss: 0.6844
# Epoch 32/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 50s 3s/step - accuracy: 0.5342 - loss: 0.6920 - val_accuracy: 0.5692 - val_loss: 0.6850
# Epoch 33/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 48s 3s/step - accuracy: 0.5861 - loss: 0.6860 - val_accuracy: 0.5692 - val_loss: 0.6840
# Epoch 34/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 53s 3s/step - accuracy: 0.5407 - loss: 0.6950 - val_accuracy: 0.5692 - val_loss: 0.6838
# Epoch 35/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 52s 3s/step - accuracy: 0.5640 - loss: 0.6943 - val_accuracy: 0.5692 - val_loss: 0.6840
# Epoch 36/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 47s 2s/step - accuracy: 0.5744 - loss: 0.6824 - val_accuracy: 0.5692 - val_loss: 0.6840
# Epoch 37/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 48s 3s/step - accuracy: 0.5359 - loss: 0.6916 - val_accuracy: 0.5692 - val_loss: 0.6841
# Epoch 38/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 46s 2s/step - accuracy: 0.5769 - loss: 0.6881 - val_accuracy: 0.5692 - val_loss: 0.6842
# Epoch 39/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 51s 3s/step - accuracy: 0.5204 - loss: 0.6996 - val_accuracy: 0.5692 - val_loss: 0.6841
# Epoch 40/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 46s 2s/step - accuracy: 0.5870 - loss: 0.6843 - val_accuracy: 0.5692 - val_loss: 0.6841
# Epoch 41/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 53s 3s/step - accuracy: 0.5575 - loss: 0.6807 - val_accuracy: 0.5692 - val_loss: 0.6851
# Epoch 42/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 51s 3s/step - accuracy: 0.5373 - loss: 0.7010 - val_accuracy: 0.5692 - val_loss: 0.6838
# Epoch 43/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 51s 3s/step - accuracy: 0.5312 - loss: 0.6925 - val_accuracy: 0.5692 - val_loss: 0.6839
# Epoch 44/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 49s 3s/step - accuracy: 0.5866 - loss: 0.6721 - val_accuracy: 0.5692 - val_loss: 0.6843
# Epoch 45/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 55s 3s/step - accuracy: 0.5680 - loss: 0.6890 - val_accuracy: 0.5692 - val_loss: 0.6843
# Epoch 46/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 46s 2s/step - accuracy: 0.5491 - loss: 0.6950 - val_accuracy: 0.5692 - val_loss: 0.6852
# Epoch 47/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 48s 3s/step - accuracy: 0.5592 - loss: 0.7069 - val_accuracy: 0.5692 - val_loss: 0.6840
# Epoch 48/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 46s 2s/step - accuracy: 0.6043 - loss: 0.6807 - val_accuracy: 0.5692 - val_loss: 0.6842
# Epoch 49/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 49s 3s/step - accuracy: 0.5486 - loss: 0.6847 - val_accuracy: 0.5692 - val_loss: 0.6837
# Epoch 50/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 47s 2s/step - accuracy: 0.5027 - loss: 0.7099 - val_accuracy: 0.5692 - val_loss: 0.6839
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 54s 3s/step - accuracy: 0.5705 - loss: 0.6835
#
# ✅ Test Accuracy: 0.5761
# ⏱ Training Time: 2502.62s | Testing Time: 60.51s
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 64s 3s/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     infacted       0.58      1.00      0.73       371
# not_infacted       0.00      0.00      0.00       273
#
#     accuracy                           0.58       644
#    macro avg       0.29      0.50      0.37       644
# weighted avg       0.33      0.58      0.42       644
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ROC–AUC: 0.3017
# I0000 00:00:1761608225.849303      19 devices.cc:67] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 1
# I0000 00:00:1761608225.849480      19 single_machine.cc:361] Starting new session
# I0000 00:00:1761608225.850481      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# op: The nodes are operation kernel type, such as MatMul, Conv2D. Graph nodes belonging to the same type are aggregated together.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# Conv2D                   700.01m float_ops (100.00%, 87.17%)
# DepthwiseConv2dNative    69.06m float_ops (12.83%, 8.60%)
# Mul                      21.55m float_ops (4.23%, 2.68%)
# AddV2                    7.12m float_ops (1.55%, 0.89%)
# MatMul                   2.56m float_ops (0.66%, 0.32%)
# Mean                     2.37m float_ops (0.34%, 0.30%)
# Sub                      171.54k float_ops (0.05%, 0.02%)
# RealDiv                  150.53k float_ops (0.03%, 0.02%)
# Rsqrt                    42.02k float_ops (0.01%, 0.01%)
# BiasAdd                  10.34k float_ops (0.00%, 0.00%)
# Softmax                  5.00k float_ops (0.00%, 0.00%)
# Maximum                      3 float_ops (0.00%, 0.00%)
#
# ======================End of Report==========================
#
# ⚙️ GFLOPs per inference (input size (224, 224, 3)): 0.8031 GFLOPs

# %% [markdown]
# # Validation Split
# # train (40%)
# # test (60%)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Example: df should have columns ['filepath', 'label', 'group']

train_df, test_df = train_test_split(
    df,
    test_size=0.6,
    stratify=df["label"],
    random_state=42
)

# Validation = 10% of total dataset → 10 / 40 = 0.25 of train
train_df, val_df = train_test_split(
    train_df,
    test_size=0.1,
    stratify=train_df["label"],
    random_state=42
)

# Step 3: Print results
print("Train size:", len(train_df))
print("Validation size:", len(val_df))
print("Test size:", len(test_df))

print("\nTrain class distribution:")
print(train_df["label"].value_counts())
print("\nValidation class distribution:")
print(val_df["label"].value_counts())
print("\nTest class distribution:")
print(test_df["label"].value_counts())

# Step 4: Save CSVs
train_df.to_csv("/kaggle/working/train_split.csv", index=False)
val_df.to_csv("/kaggle/working/val_split.csv", index=False)
test_df.to_csv("/kaggle/working/test_split.csv", index=False)

print("\n Train/Val/Test CSVs saved successfully!")
# Out:
# Train size: 462
# Validation size: 52
# Test size: 773
#
# Train class distribution:
# label
# infacted        266
# not_infacted    196
# Name: count, dtype: int64
#
# Validation class distribution:
# label
# infacted        30
# not_infacted    22
# Name: count, dtype: int64
#
# Test class distribution:
# label
# infacted        445
# not_infacted    328
# Name: count, dtype: int64
#
#  Train/Val/Test CSVs saved successfully!

# %% [markdown]
# # EfficientNetB0 Version

# %%
import time
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
from sklearn.preprocessing import label_binarize
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.layers import GlobalAveragePooling2D, Dropout, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# ======= Adjustable Epochs =======
EPOCHS = 50  # 🔁 Change this number anytime
BATCH_SIZE = 32
IMAGE_SIZE = (224, 224)

# ======= Load CSVs =======
train_df = pd.read_csv("/kaggle/working/train_split.csv")
val_df = pd.read_csv("/kaggle/working/val_split.csv")
test_df = pd.read_csv("/kaggle/working/test_split.csv")

# ======= Image Data Generators =======
train_datagen = ImageDataGenerator(rescale=1./255, horizontal_flip=True)
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_gen = train_datagen.flow_from_dataframe(
    train_df, 
    x_col="filepath", 
    y_col="label",
    target_size=IMAGE_SIZE, 
    batch_size=BATCH_SIZE, 
    class_mode="categorical",
    shuffle=True
)

val_gen = val_datagen.flow_from_dataframe(
    val_df, 
    x_col="filepath", 
    y_col="label",
    target_size=IMAGE_SIZE, 
    batch_size=BATCH_SIZE, 
    class_mode="categorical",
    shuffle=False
)

test_gen = test_datagen.flow_from_dataframe(
    test_df, 
    x_col="filepath", 
    y_col="label",
    target_size=IMAGE_SIZE, 
    batch_size=BATCH_SIZE, 
    class_mode="categorical",
    shuffle=False
)

num_classes = len(train_gen.class_indices)


# ======= Build EfficientNetB0 Model =======
base_model = EfficientNetB0(weights="imagenet", include_top=False, input_shape=(224, 224, 3))
x = GlobalAveragePooling2D()(base_model.output)
x = Dropout(0.3)(x)
output = Dense(num_classes, activation="softmax")(x)

model = Model(inputs=base_model.input, outputs=output)

for layer in base_model.layers:
    layer.trainable = False

model.compile(optimizer=Adam(1e-4), loss="categorical_crossentropy", metrics=["accuracy"])


print("Classes in train set:", train_gen.class_indices)
print("Classes in test set:", test_gen.class_indices)


# ======= Train =======
start_train = time.time()
history = model.fit(train_gen, validation_data=val_gen, epochs=EPOCHS)
train_time = time.time() - start_train

# ======= Evaluate =======
start_test = time.time()
test_loss, test_acc = model.evaluate(test_gen)
test_time = time.time() - start_test

print(f"\n✅ Test Accuracy: {test_acc:.4f}")
print(f"⏱ Training Time: {train_time:.2f}s | Testing Time: {test_time:.2f}s")

# ======= Predictions =======
y_true = test_gen.classes
y_pred_probs = model.predict(test_gen)
y_pred = np.argmax(y_pred_probs, axis=1)
class_labels = list(test_gen.class_indices.keys())

# ======= Metrics =======
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_labels))

# ======= Confusion Matrix =======
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.title("Confusion Matrix — EfficientNetB0")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# ======= ROC–AUC for binary classification =======
from sklearn.metrics import roc_auc_score, roc_curve, auc

# Use probability of 'not_infacted' or positive class
y_pred_prob_pos = y_pred_probs[:, 1]  # probability of class 1

auc_score = roc_auc_score(y_true, y_pred_prob_pos)
fpr, tpr, _ = roc_curve(y_true, y_pred_prob_pos)

plt.figure()
plt.plot(fpr, tpr, label=f"Binary ROC (AUC={auc_score:.2f})")
plt.plot([0, 1], [0, 1], 'k--')
plt.title("ROC Curve — EfficientNetB0")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.show()

print(f"\nROC–AUC: {auc_score:.4f}")


# ======= GFLOPs =======
import os
import tensorflow as tf
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2

# ======= Suppress TensorFlow GPU info logs =======
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'  # Only show warnings and errors

# ======= Define your model =======
input_shape = (224, 224, 3)  # Fixed input size
model = EfficientNetB0(input_shape=input_shape, include_top=True, weights=None)

# ======= Convert to ConcreteFunction =======
full_model = tf.function(lambda x: model(x))
full_model = full_model.get_concrete_function(
    tf.TensorSpec([1, *input_shape], model.inputs[0].dtype)
)

# ======= Freeze the graph =======
frozen_func = convert_variables_to_constants_v2(full_model)
graph_def = frozen_func.graph.as_graph_def()

# ======= Use TF Profiler to calculate FLOPs =======
with tf.Graph().as_default() as graph:
    tf.import_graph_def(graph_def, name='')
    run_meta = tf.compat.v1.RunMetadata()
    opts = tf.compat.v1.profiler.ProfileOptionBuilder.float_operation()
    flops = tf.compat.v1.profiler.profile(graph=graph, run_meta=run_meta, cmd='op', options=opts)

# ======= Print GFLOPs per inference =======
print(f"\n⚙️ GFLOPs per inference (input size {input_shape}): {flops.total_float_ops / 1e9:.4f} GFLOPs")
# Out:
# Found 462 validated image filenames belonging to 2 classes.
# Found 52 validated image filenames belonging to 2 classes.
# Found 773 validated image filenames belonging to 2 classes.
# Classes in train set: {'infacted': 0, 'not_infacted': 1}
# Classes in test set: {'infacted': 0, 'not_infacted': 1}
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 78s 4s/step - accuracy: 0.4280 - loss: 0.7463 - val_accuracy: 0.5769 - val_loss: 0.6902
# Epoch 2/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.4574 - loss: 0.7042 - val_accuracy: 0.5769 - val_loss: 0.6814
# Epoch 3/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 42s 3s/step - accuracy: 0.5492 - loss: 0.6795 - val_accuracy: 0.5769 - val_loss: 0.6822
# Epoch 4/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 42s 3s/step - accuracy: 0.5479 - loss: 0.6806 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 5/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.5329 - loss: 0.7010 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 6/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.5135 - loss: 0.7023 - val_accuracy: 0.5769 - val_loss: 0.6815
# Epoch 7/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.5271 - loss: 0.6921 - val_accuracy: 0.5769 - val_loss: 0.6814
# Epoch 8/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.5395 - loss: 0.6969 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 9/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.5675 - loss: 0.6932 - val_accuracy: 0.5769 - val_loss: 0.6817
# Epoch 10/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 43s 3s/step - accuracy: 0.5597 - loss: 0.6840 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 11/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.5520 - loss: 0.6968 - val_accuracy: 0.5769 - val_loss: 0.6814
# Epoch 12/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.5546 - loss: 0.6882 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 13/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.5833 - loss: 0.6881 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 14/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.5590 - loss: 0.6942 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 15/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.5519 - loss: 0.6942 - val_accuracy: 0.5769 - val_loss: 0.6812
# Epoch 16/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.5858 - loss: 0.6896 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 17/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.5804 - loss: 0.6928 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 18/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.5578 - loss: 0.6956 - val_accuracy: 0.5769 - val_loss: 0.6825
# Epoch 19/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.5530 - loss: 0.6902 - val_accuracy: 0.5769 - val_loss: 0.6812
# Epoch 20/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.5434 - loss: 0.6869 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 21/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.5676 - loss: 0.6864 - val_accuracy: 0.5769 - val_loss: 0.6812
# Epoch 22/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.6110 - loss: 0.6759 - val_accuracy: 0.5769 - val_loss: 0.6812
# Epoch 23/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.5280 - loss: 0.7042 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 24/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.5653 - loss: 0.6846 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 25/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.5629 - loss: 0.6956 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 26/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 42s 3s/step - accuracy: 0.5504 - loss: 0.6859 - val_accuracy: 0.5769 - val_loss: 0.6815
# Epoch 27/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.5517 - loss: 0.6900 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 28/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 43s 3s/step - accuracy: 0.5478 - loss: 0.6923 - val_accuracy: 0.5769 - val_loss: 0.6812
# Epoch 29/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.5644 - loss: 0.6827 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 30/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.5466 - loss: 0.6990 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 31/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.5281 - loss: 0.6984 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 32/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 36s 3s/step - accuracy: 0.5261 - loss: 0.6980 - val_accuracy: 0.5769 - val_loss: 0.6812
# Epoch 33/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.5654 - loss: 0.6917 - val_accuracy: 0.5769 - val_loss: 0.6816
# Epoch 34/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.5339 - loss: 0.6923 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 35/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.5695 - loss: 0.6820 - val_accuracy: 0.5769 - val_loss: 0.6817
# Epoch 36/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 42s 3s/step - accuracy: 0.5535 - loss: 0.6871 - val_accuracy: 0.5769 - val_loss: 0.6812
# Epoch 37/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.5739 - loss: 0.6861 - val_accuracy: 0.5769 - val_loss: 0.6812
# Epoch 38/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.5575 - loss: 0.6876 - val_accuracy: 0.5769 - val_loss: 0.6817
# Epoch 39/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.5580 - loss: 0.6824 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 40/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.5481 - loss: 0.7048 - val_accuracy: 0.5769 - val_loss: 0.6812
# Epoch 41/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.5257 - loss: 0.7069 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 42/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.5697 - loss: 0.6928 - val_accuracy: 0.5769 - val_loss: 0.6814
# Epoch 43/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.5456 - loss: 0.6896 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 44/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.6012 - loss: 0.6767 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 45/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.6045 - loss: 0.6685 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 46/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.5176 - loss: 0.7006 - val_accuracy: 0.5769 - val_loss: 0.6817
# Epoch 47/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.5634 - loss: 0.6864 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 48/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.5906 - loss: 0.6755 - val_accuracy: 0.5769 - val_loss: 0.6814
# Epoch 49/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.5707 - loss: 0.6771 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 50/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 43s 3s/step - accuracy: 0.5369 - loss: 0.7009 - val_accuracy: 0.5769 - val_loss: 0.6818
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 58s 2s/step - accuracy: 0.5706 - loss: 0.6841
#
# ✅ Test Accuracy: 0.5757
# ⏱ Training Time: 1993.51s | Testing Time: 63.80s
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 67s 2s/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     infacted       0.58      1.00      0.73       445
# not_infacted       0.00      0.00      0.00       328
#
#     accuracy                           0.58       773
#    macro avg       0.29      0.50      0.37       773
# weighted avg       0.33      0.58      0.42       773
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ROC–AUC: 0.6549
# I0000 00:00:1761610370.249948      19 devices.cc:67] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 1
# I0000 00:00:1761610370.250141      19 single_machine.cc:361] Starting new session
# I0000 00:00:1761610370.251262      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# op: The nodes are operation kernel type, such as MatMul, Conv2D. Graph nodes belonging to the same type are aggregated together.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# Conv2D                   700.01m float_ops (100.00%, 87.17%)
# DepthwiseConv2dNative    69.06m float_ops (12.83%, 8.60%)
# Mul                      21.55m float_ops (4.23%, 2.68%)
# AddV2                    7.12m float_ops (1.55%, 0.89%)
# MatMul                   2.56m float_ops (0.66%, 0.32%)
# Mean                     2.37m float_ops (0.34%, 0.30%)
# Sub                      171.54k float_ops (0.05%, 0.02%)
# RealDiv                  150.53k float_ops (0.03%, 0.02%)
# Rsqrt                    42.02k float_ops (0.01%, 0.01%)
# BiasAdd                  10.34k float_ops (0.00%, 0.00%)
# Softmax                  5.00k float_ops (0.00%, 0.00%)
# Maximum                      3 float_ops (0.00%, 0.00%)
#
# ======================End of Report==========================
#
# ⚙️ GFLOPs per inference (input size (224, 224, 3)): 0.8031 GFLOPs

# %% [markdown]
# # Validation Split
# # train (30%)
# # test (70%)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Example: df should have columns ['filepath', 'label', 'group']

# Train 90% + Test 10%
train_df, test_df = train_test_split(
    df,
    test_size=0.7,
    stratify=df["label"],
    random_state=42
)

# Validation = 10% of total dataset → 10 / 30 ≈ 0.3333 of train
train_df, val_df = train_test_split(
    train_df,
    test_size=0.1,
    stratify=train_df["label"],
    random_state=42
)

# Step 3: Print results
print("Train size:", len(train_df))
print("Validation size:", len(val_df))
print("Test size:", len(test_df))

print("\nTrain class distribution:")
print(train_df["label"].value_counts())
print("\nValidation class distribution:")
print(val_df["label"].value_counts())
print("\nTest class distribution:")
print(test_df["label"].value_counts())

# Step 4: Save CSVs
train_df.to_csv("/kaggle/working/train_split.csv", index=False)
val_df.to_csv("/kaggle/working/val_split.csv", index=False)
test_df.to_csv("/kaggle/working/test_split.csv", index=False)

print("\n Train/Val/Test CSVs saved successfully!")
# Out:
# Train size: 347
# Validation size: 39
# Test size: 901
#
# Train class distribution:
# label
# infacted        200
# not_infacted    147
# Name: count, dtype: int64
#
# Validation class distribution:
# label
# infacted        22
# not_infacted    17
# Name: count, dtype: int64
#
# Test class distribution:
# label
# infacted        519
# not_infacted    382
# Name: count, dtype: int64
#
#  Train/Val/Test CSVs saved successfully!

# %% [markdown]
# # EfficientNetB0 Version

# %%
import time
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
from sklearn.preprocessing import label_binarize
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.layers import GlobalAveragePooling2D, Dropout, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# ======= Adjustable Epochs =======
EPOCHS = 50  # 🔁 Change this number anytime
BATCH_SIZE = 32
IMAGE_SIZE = (224, 224)

# ======= Load CSVs =======
train_df = pd.read_csv("/kaggle/working/train_split.csv")
val_df = pd.read_csv("/kaggle/working/val_split.csv")
test_df = pd.read_csv("/kaggle/working/test_split.csv")

# ======= Image Data Generators =======
train_datagen = ImageDataGenerator(rescale=1./255, horizontal_flip=True)
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_gen = train_datagen.flow_from_dataframe(
    train_df, 
    x_col="filepath", 
    y_col="label",
    target_size=IMAGE_SIZE, 
    batch_size=BATCH_SIZE, 
    class_mode="categorical",
    shuffle=True
)

val_gen = val_datagen.flow_from_dataframe(
    val_df, 
    x_col="filepath", 
    y_col="label",
    target_size=IMAGE_SIZE, 
    batch_size=BATCH_SIZE, 
    class_mode="categorical",
    shuffle=False
)

test_gen = test_datagen.flow_from_dataframe(
    test_df, 
    x_col="filepath", 
    y_col="label",
    target_size=IMAGE_SIZE, 
    batch_size=BATCH_SIZE, 
    class_mode="categorical",
    shuffle=False
)

num_classes = len(train_gen.class_indices)


# ======= Build EfficientNetB0 Model =======
base_model = EfficientNetB0(weights="imagenet", include_top=False, input_shape=(224, 224, 3))
x = GlobalAveragePooling2D()(base_model.output)
x = Dropout(0.3)(x)
output = Dense(num_classes, activation="softmax")(x)

model = Model(inputs=base_model.input, outputs=output)

for layer in base_model.layers:
    layer.trainable = False

model.compile(optimizer=Adam(1e-4), loss="categorical_crossentropy", metrics=["accuracy"])


print("Classes in train set:", train_gen.class_indices)
print("Classes in test set:", test_gen.class_indices)


# ======= Train =======
start_train = time.time()
history = model.fit(train_gen, validation_data=val_gen, epochs=EPOCHS)
train_time = time.time() - start_train

# ======= Evaluate =======
start_test = time.time()
test_loss, test_acc = model.evaluate(test_gen)
test_time = time.time() - start_test

print(f"\n✅ Test Accuracy: {test_acc:.4f}")
print(f"⏱ Training Time: {train_time:.2f}s | Testing Time: {test_time:.2f}s")

# ======= Predictions =======
y_true = test_gen.classes
y_pred_probs = model.predict(test_gen)
y_pred = np.argmax(y_pred_probs, axis=1)
class_labels = list(test_gen.class_indices.keys())

# ======= Metrics =======
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_labels))

# ======= Confusion Matrix =======
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.title("Confusion Matrix — EfficientNetB0")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# ======= ROC–AUC for binary classification =======
from sklearn.metrics import roc_auc_score, roc_curve, auc

# Use probability of 'not_infacted' or positive class
y_pred_prob_pos = y_pred_probs[:, 1]  # probability of class 1

auc_score = roc_auc_score(y_true, y_pred_prob_pos)
fpr, tpr, _ = roc_curve(y_true, y_pred_prob_pos)

plt.figure()
plt.plot(fpr, tpr, label=f"Binary ROC (AUC={auc_score:.2f})")
plt.plot([0, 1], [0, 1], 'k--')
plt.title("ROC Curve — EfficientNetB0")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.show()

print(f"\nROC–AUC: {auc_score:.4f}")


# ======= GFLOPs =======
import os
import tensorflow as tf
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2

# ======= Suppress TensorFlow GPU info logs =======
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'  # Only show warnings and errors

# ======= Define your model =======
input_shape = (224, 224, 3)  # Fixed input size
model = EfficientNetB0(input_shape=input_shape, include_top=True, weights=None)

# ======= Convert to ConcreteFunction =======
full_model = tf.function(lambda x: model(x))
full_model = full_model.get_concrete_function(
    tf.TensorSpec([1, *input_shape], model.inputs[0].dtype)
)

# ======= Freeze the graph =======
frozen_func = convert_variables_to_constants_v2(full_model)
graph_def = frozen_func.graph.as_graph_def()

# ======= Use TF Profiler to calculate FLOPs =======
with tf.Graph().as_default() as graph:
    tf.import_graph_def(graph_def, name='')
    run_meta = tf.compat.v1.RunMetadata()
    opts = tf.compat.v1.profiler.ProfileOptionBuilder.float_operation()
    flops = tf.compat.v1.profiler.profile(graph=graph, run_meta=run_meta, cmd='op', options=opts)

# ======= Print GFLOPs per inference =======
print(f"\n⚙️ GFLOPs per inference (input size {input_shape}): {flops.total_float_ops / 1e9:.4f} GFLOPs")
# Out:
# Found 347 validated image filenames belonging to 2 classes.
# Found 39 validated image filenames belonging to 2 classes.
# Found 901 validated image filenames belonging to 2 classes.
# Classes in train set: {'infacted': 0, 'not_infacted': 1}
# Classes in test set: {'infacted': 0, 'not_infacted': 1}
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 68s 4s/step - accuracy: 0.5150 - loss: 0.6907 - val_accuracy: 0.5641 - val_loss: 0.6849
# Epoch 2/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 28s 3s/step - accuracy: 0.5446 - loss: 0.6903 - val_accuracy: 0.5641 - val_loss: 0.6867
# Epoch 3/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 29s 3s/step - accuracy: 0.6208 - loss: 0.6678 - val_accuracy: 0.5641 - val_loss: 0.6883
# Epoch 4/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 29s 3s/step - accuracy: 0.5894 - loss: 0.6772 - val_accuracy: 0.5641 - val_loss: 0.6862
# Epoch 5/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 31s 3s/step - accuracy: 0.5752 - loss: 0.6879 - val_accuracy: 0.5641 - val_loss: 0.6854
# Epoch 6/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 30s 3s/step - accuracy: 0.5801 - loss: 0.6792 - val_accuracy: 0.5641 - val_loss: 0.6854
# Epoch 7/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 30s 3s/step - accuracy: 0.6061 - loss: 0.6743 - val_accuracy: 0.5641 - val_loss: 0.6855
# Epoch 8/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 30s 3s/step - accuracy: 0.5200 - loss: 0.7010 - val_accuracy: 0.5641 - val_loss: 0.6850
# Epoch 9/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 29s 3s/step - accuracy: 0.5999 - loss: 0.6720 - val_accuracy: 0.5641 - val_loss: 0.6851
# Epoch 10/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 30s 3s/step - accuracy: 0.5752 - loss: 0.6947 - val_accuracy: 0.5641 - val_loss: 0.6850
# Epoch 11/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 29s 3s/step - accuracy: 0.5859 - loss: 0.6891 - val_accuracy: 0.5641 - val_loss: 0.6856
# Epoch 12/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 30s 3s/step - accuracy: 0.5575 - loss: 0.6819 - val_accuracy: 0.5641 - val_loss: 0.6863
# Epoch 13/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 28s 3s/step - accuracy: 0.5674 - loss: 0.6859 - val_accuracy: 0.5641 - val_loss: 0.6853
# Epoch 14/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 29s 3s/step - accuracy: 0.5159 - loss: 0.7027 - val_accuracy: 0.5641 - val_loss: 0.6851
# Epoch 15/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 29s 3s/step - accuracy: 0.5534 - loss: 0.6919 - val_accuracy: 0.5641 - val_loss: 0.6854
# Epoch 16/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 30s 3s/step - accuracy: 0.6117 - loss: 0.6641 - val_accuracy: 0.5641 - val_loss: 0.6859
# Epoch 17/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 31s 3s/step - accuracy: 0.5774 - loss: 0.6860 - val_accuracy: 0.5641 - val_loss: 0.6853
# Epoch 18/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 30s 3s/step - accuracy: 0.5830 - loss: 0.6971 - val_accuracy: 0.5641 - val_loss: 0.6850
# Epoch 19/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 30s 3s/step - accuracy: 0.5472 - loss: 0.6932 - val_accuracy: 0.5641 - val_loss: 0.6852
# Epoch 20/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 29s 3s/step - accuracy: 0.5680 - loss: 0.6947 - val_accuracy: 0.5641 - val_loss: 0.6856
# Epoch 21/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 30s 3s/step - accuracy: 0.5468 - loss: 0.6979 - val_accuracy: 0.5641 - val_loss: 0.6852
# Epoch 22/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 30s 3s/step - accuracy: 0.4904 - loss: 0.7090 - val_accuracy: 0.5641 - val_loss: 0.6854
# Epoch 23/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 28s 3s/step - accuracy: 0.5814 - loss: 0.6953 - val_accuracy: 0.5641 - val_loss: 0.6863
# Epoch 24/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 29s 3s/step - accuracy: 0.6197 - loss: 0.6713 - val_accuracy: 0.5641 - val_loss: 0.6863
# Epoch 25/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 32s 3s/step - accuracy: 0.5687 - loss: 0.6957 - val_accuracy: 0.5641 - val_loss: 0.6852
# Epoch 26/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 28s 3s/step - accuracy: 0.5446 - loss: 0.6991 - val_accuracy: 0.5641 - val_loss: 0.6851
# Epoch 27/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 30s 3s/step - accuracy: 0.6026 - loss: 0.6872 - val_accuracy: 0.5641 - val_loss: 0.6855
# Epoch 28/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 31s 3s/step - accuracy: 0.5596 - loss: 0.6837 - val_accuracy: 0.5641 - val_loss: 0.6856
# Epoch 29/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 28s 3s/step - accuracy: 0.5484 - loss: 0.6912 - val_accuracy: 0.5641 - val_loss: 0.6852
# Epoch 30/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 31s 3s/step - accuracy: 0.5551 - loss: 0.6903 - val_accuracy: 0.5641 - val_loss: 0.6850
# Epoch 31/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 30s 3s/step - accuracy: 0.5527 - loss: 0.6912 - val_accuracy: 0.5641 - val_loss: 0.6858
# Epoch 32/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - accuracy: 0.5824 - loss: 0.6688 - val_accuracy: 0.5641 - val_loss: 0.6857
# Epoch 33/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 31s 3s/step - accuracy: 0.5729 - loss: 0.6936 - val_accuracy: 0.5641 - val_loss: 0.6851
# Epoch 34/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 28s 3s/step - accuracy: 0.5652 - loss: 0.6878 - val_accuracy: 0.5641 - val_loss: 0.6851
# Epoch 35/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 29s 3s/step - accuracy: 0.5943 - loss: 0.6646 - val_accuracy: 0.5641 - val_loss: 0.6856
# Epoch 36/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 29s 3s/step - accuracy: 0.5662 - loss: 0.6918 - val_accuracy: 0.5641 - val_loss: 0.6851
# Epoch 37/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 26s 2s/step - accuracy: 0.6174 - loss: 0.6696 - val_accuracy: 0.5641 - val_loss: 0.6854
# Epoch 38/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 28s 3s/step - accuracy: 0.5634 - loss: 0.6962 - val_accuracy: 0.5641 - val_loss: 0.6855
# Epoch 39/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 32s 3s/step - accuracy: 0.5399 - loss: 0.6887 - val_accuracy: 0.5641 - val_loss: 0.6852
# Epoch 40/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 29s 3s/step - accuracy: 0.5944 - loss: 0.6691 - val_accuracy: 0.5641 - val_loss: 0.6858
# Epoch 41/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 30s 3s/step - accuracy: 0.5274 - loss: 0.7029 - val_accuracy: 0.5641 - val_loss: 0.6850
# Epoch 42/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 29s 3s/step - accuracy: 0.5399 - loss: 0.6813 - val_accuracy: 0.5641 - val_loss: 0.6862
# Epoch 43/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 29s 3s/step - accuracy: 0.5692 - loss: 0.6799 - val_accuracy: 0.5641 - val_loss: 0.6863
# Epoch 44/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 31s 3s/step - accuracy: 0.5628 - loss: 0.6945 - val_accuracy: 0.5641 - val_loss: 0.6855
# Epoch 45/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 29s 3s/step - accuracy: 0.5923 - loss: 0.6753 - val_accuracy: 0.5641 - val_loss: 0.6856
# Epoch 46/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 30s 3s/step - accuracy: 0.6002 - loss: 0.6590 - val_accuracy: 0.5641 - val_loss: 0.6866
# Epoch 47/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 30s 3s/step - accuracy: 0.5737 - loss: 0.6747 - val_accuracy: 0.5641 - val_loss: 0.6855
# Epoch 48/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 31s 3s/step - accuracy: 0.5501 - loss: 0.6950 - val_accuracy: 0.5641 - val_loss: 0.6849
# Epoch 49/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - accuracy: 0.5482 - loss: 0.6963 - val_accuracy: 0.5641 - val_loss: 0.6851
# Epoch 50/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 30s 3s/step - accuracy: 0.5495 - loss: 0.6947 - val_accuracy: 0.5641 - val_loss: 0.6859
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 63s 2s/step - accuracy: 0.5688 - loss: 0.6842
#
# ✅ Test Accuracy: 0.5760
# ⏱ Training Time: 1518.95s | Testing Time: 68.85s
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 73s 2s/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     infacted       0.58      1.00      0.73       519
# not_infacted       0.00      0.00      0.00       382
#
#     accuracy                           0.58       901
#    macro avg       0.29      0.50      0.37       901
# weighted avg       0.33      0.58      0.42       901
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ROC–AUC: 0.5998
# I0000 00:00:1761612050.163520      19 devices.cc:67] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 1
# I0000 00:00:1761612050.163674      19 single_machine.cc:361] Starting new session
# I0000 00:00:1761612050.164640      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# op: The nodes are operation kernel type, such as MatMul, Conv2D. Graph nodes belonging to the same type are aggregated together.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# Conv2D                   700.01m float_ops (100.00%, 87.17%)
# DepthwiseConv2dNative    69.06m float_ops (12.83%, 8.60%)
# Mul                      21.55m float_ops (4.23%, 2.68%)
# AddV2                    7.12m float_ops (1.55%, 0.89%)
# MatMul                   2.56m float_ops (0.66%, 0.32%)
# Mean                     2.37m float_ops (0.34%, 0.30%)
# Sub                      171.54k float_ops (0.05%, 0.02%)
# RealDiv                  150.53k float_ops (0.03%, 0.02%)
# Rsqrt                    42.02k float_ops (0.01%, 0.01%)
# BiasAdd                  10.34k float_ops (0.00%, 0.00%)
# Softmax                  5.00k float_ops (0.00%, 0.00%)
# Maximum                      3 float_ops (0.00%, 0.00%)
#
# ======================End of Report==========================
#
# ⚙️ GFLOPs per inference (input size (224, 224, 3)): 0.8031 GFLOPs

# %% [markdown]
# # Validation Split
# # train (20%)
# # test (80%)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Example: df should have columns ['filepath', 'label', 'group']

# Train 90% + Test 10%
train_df, test_df = train_test_split(
    df,
    test_size=0.8,
    stratify=df["label"],
    random_state=42
)

# Validation = 10% of total dataset → 10 / 20 = 0.5 of train
train_df, val_df = train_test_split(
    train_df,
    test_size=0.1,
    stratify=train_df["label"],
    random_state=42
)

# Step 3: Print results
print("Train size:", len(train_df))
print("Validation size:", len(val_df))
print("Test size:", len(test_df))

print("\nTrain class distribution:")
print(train_df["label"].value_counts())
print("\nValidation class distribution:")
print(val_df["label"].value_counts())
print("\nTest class distribution:")
print(test_df["label"].value_counts())

# Step 4: Save CSVs
train_df.to_csv("/kaggle/working/train_split.csv", index=False)
val_df.to_csv("/kaggle/working/val_split.csv", index=False)
test_df.to_csv("/kaggle/working/test_split.csv", index=False)

print("\n Train/Val/Test CSVs saved successfully!")
# Out:
# Train size: 231
# Validation size: 26
# Test size: 1030
#
# Train class distribution:
# label
# infacted        133
# not_infacted     98
# Name: count, dtype: int64
#
# Validation class distribution:
# label
# infacted        15
# not_infacted    11
# Name: count, dtype: int64
#
# Test class distribution:
# label
# infacted        593
# not_infacted    437
# Name: count, dtype: int64
#
#  Train/Val/Test CSVs saved successfully!

# %% [markdown]
# # EfficientNetB0 Version

# %%
import time
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
from sklearn.preprocessing import label_binarize
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.layers import GlobalAveragePooling2D, Dropout, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# ======= Adjustable Epochs =======
EPOCHS = 50  # 🔁 Change this number anytime
BATCH_SIZE = 32
IMAGE_SIZE = (224, 224)

# ======= Load CSVs =======
train_df = pd.read_csv("/kaggle/working/train_split.csv")
val_df = pd.read_csv("/kaggle/working/val_split.csv")
test_df = pd.read_csv("/kaggle/working/test_split.csv")

# ======= Image Data Generators =======
train_datagen = ImageDataGenerator(rescale=1./255, horizontal_flip=True)
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_gen = train_datagen.flow_from_dataframe(
    train_df, 
    x_col="filepath", 
    y_col="label",
    target_size=IMAGE_SIZE, 
    batch_size=BATCH_SIZE, 
    class_mode="categorical",
    shuffle=True
)

val_gen = val_datagen.flow_from_dataframe(
    val_df, 
    x_col="filepath", 
    y_col="label",
    target_size=IMAGE_SIZE, 
    batch_size=BATCH_SIZE, 
    class_mode="categorical",
    shuffle=False
)

test_gen = test_datagen.flow_from_dataframe(
    test_df, 
    x_col="filepath", 
    y_col="label",
    target_size=IMAGE_SIZE, 
    batch_size=BATCH_SIZE, 
    class_mode="categorical",
    shuffle=False
)

num_classes = len(train_gen.class_indices)


# ======= Build EfficientNetB0 Model =======
base_model = EfficientNetB0(weights="imagenet", include_top=False, input_shape=(224, 224, 3))
x = GlobalAveragePooling2D()(base_model.output)
x = Dropout(0.3)(x)
output = Dense(num_classes, activation="softmax")(x)

model = Model(inputs=base_model.input, outputs=output)

for layer in base_model.layers:
    layer.trainable = False

model.compile(optimizer=Adam(1e-4), loss="categorical_crossentropy", metrics=["accuracy"])


print("Classes in train set:", train_gen.class_indices)
print("Classes in test set:", test_gen.class_indices)


# ======= Train =======
start_train = time.time()
history = model.fit(train_gen, validation_data=val_gen, epochs=EPOCHS)
train_time = time.time() - start_train

# ======= Evaluate =======
start_test = time.time()
test_loss, test_acc = model.evaluate(test_gen)
test_time = time.time() - start_test

print(f"\n✅ Test Accuracy: {test_acc:.4f}")
print(f"⏱ Training Time: {train_time:.2f}s | Testing Time: {test_time:.2f}s")

# ======= Predictions =======
y_true = test_gen.classes
y_pred_probs = model.predict(test_gen)
y_pred = np.argmax(y_pred_probs, axis=1)
class_labels = list(test_gen.class_indices.keys())

# ======= Metrics =======
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_labels))

# ======= Confusion Matrix =======
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.title("Confusion Matrix — EfficientNetB0")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# ======= ROC–AUC for binary classification =======
from sklearn.metrics import roc_auc_score, roc_curve, auc

# Use probability of 'not_infacted' or positive class
y_pred_prob_pos = y_pred_probs[:, 1]  # probability of class 1

auc_score = roc_auc_score(y_true, y_pred_prob_pos)
fpr, tpr, _ = roc_curve(y_true, y_pred_prob_pos)

plt.figure()
plt.plot(fpr, tpr, label=f"Binary ROC (AUC={auc_score:.2f})")
plt.plot([0, 1], [0, 1], 'k--')
plt.title("ROC Curve — EfficientNetB0")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.show()

print(f"\nROC–AUC: {auc_score:.4f}")


# ======= GFLOPs =======
import os
import tensorflow as tf
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2

# ======= Suppress TensorFlow GPU info logs =======
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'  # Only show warnings and errors

# ======= Define your model =======
input_shape = (224, 224, 3)  # Fixed input size
model = EfficientNetB0(input_shape=input_shape, include_top=True, weights=None)

# ======= Convert to ConcreteFunction =======
full_model = tf.function(lambda x: model(x))
full_model = full_model.get_concrete_function(
    tf.TensorSpec([1, *input_shape], model.inputs[0].dtype)
)

# ======= Freeze the graph =======
frozen_func = convert_variables_to_constants_v2(full_model)
graph_def = frozen_func.graph.as_graph_def()

# ======= Use TF Profiler to calculate FLOPs =======
with tf.Graph().as_default() as graph:
    tf.import_graph_def(graph_def, name='')
    run_meta = tf.compat.v1.RunMetadata()
    opts = tf.compat.v1.profiler.ProfileOptionBuilder.float_operation()
    flops = tf.compat.v1.profiler.profile(graph=graph, run_meta=run_meta, cmd='op', options=opts)

# ======= Print GFLOPs per inference =======
print(f"\n⚙️ GFLOPs per inference (input size {input_shape}): {flops.total_float_ops / 1e9:.4f} GFLOPs")
# Out:
# Found 231 validated image filenames belonging to 2 classes.
# Found 26 validated image filenames belonging to 2 classes.
# Found 1030 validated image filenames belonging to 2 classes.
# Classes in train set: {'infacted': 0, 'not_infacted': 1}
# Classes in test set: {'infacted': 0, 'not_infacted': 1}
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 57s 4s/step - accuracy: 0.4596 - loss: 0.7242 - val_accuracy: 0.4231 - val_loss: 0.7142
# Epoch 2/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - accuracy: 0.4808 - loss: 0.7099 - val_accuracy: 0.5769 - val_loss: 0.6908
# Epoch 3/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 0.5269 - loss: 0.6854 - val_accuracy: 0.5769 - val_loss: 0.6831
# Epoch 4/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.5006 - loss: 0.6983 - val_accuracy: 0.5769 - val_loss: 0.6814
# Epoch 5/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - accuracy: 0.5605 - loss: 0.6837 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 6/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 0.5927 - loss: 0.6798 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 7/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 0.5662 - loss: 0.6941 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 8/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.5771 - loss: 0.6902 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 9/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.5625 - loss: 0.7031 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 10/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step - accuracy: 0.5486 - loss: 0.6765 - val_accuracy: 0.5769 - val_loss: 0.6815
# Epoch 11/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - accuracy: 0.5633 - loss: 0.6943 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 12/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - accuracy: 0.5972 - loss: 0.6819 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 13/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 0.6175 - loss: 0.6703 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 14/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 0.5344 - loss: 0.6921 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 15/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 0.5806 - loss: 0.6836 - val_accuracy: 0.5769 - val_loss: 0.6814
# Epoch 16/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 0.5955 - loss: 0.6794 - val_accuracy: 0.5769 - val_loss: 0.6815
# Epoch 17/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - accuracy: 0.5189 - loss: 0.6961 - val_accuracy: 0.5769 - val_loss: 0.6815
# Epoch 18/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step - accuracy: 0.5348 - loss: 0.7128 - val_accuracy: 0.5769 - val_loss: 0.6815
# Epoch 19/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 0.5681 - loss: 0.6889 - val_accuracy: 0.5769 - val_loss: 0.6817
# Epoch 20/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - accuracy: 0.5897 - loss: 0.6918 - val_accuracy: 0.5769 - val_loss: 0.6818
# Epoch 21/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 0.5842 - loss: 0.6823 - val_accuracy: 0.5769 - val_loss: 0.6819
# Epoch 22/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 0.5987 - loss: 0.6736 - val_accuracy: 0.5769 - val_loss: 0.6816
# Epoch 23/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step - accuracy: 0.5846 - loss: 0.6913 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 24/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step - accuracy: 0.5654 - loss: 0.6816 - val_accuracy: 0.5769 - val_loss: 0.6814
# Epoch 25/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 0.5640 - loss: 0.6928 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 26/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - accuracy: 0.5582 - loss: 0.6882 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 27/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - accuracy: 0.5367 - loss: 0.6851 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 28/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step - accuracy: 0.5590 - loss: 0.6781 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 29/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step - accuracy: 0.5806 - loss: 0.6807 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 30/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - accuracy: 0.5689 - loss: 0.6759 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 31/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step - accuracy: 0.5815 - loss: 0.6820 - val_accuracy: 0.5769 - val_loss: 0.6814
# Epoch 32/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 0.5606 - loss: 0.6957 - val_accuracy: 0.5769 - val_loss: 0.6814
# Epoch 33/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step - accuracy: 0.6158 - loss: 0.6871 - val_accuracy: 0.5769 - val_loss: 0.6815
# Epoch 34/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.5524 - loss: 0.6886 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 35/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 0.5033 - loss: 0.6865 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 36/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 0.5777 - loss: 0.6922 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 37/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - accuracy: 0.5339 - loss: 0.6974 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 38/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - accuracy: 0.5347 - loss: 0.7032 - val_accuracy: 0.5769 - val_loss: 0.6814
# Epoch 39/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 0.5573 - loss: 0.6853 - val_accuracy: 0.5769 - val_loss: 0.6814
# Epoch 40/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step - accuracy: 0.5492 - loss: 0.6905 - val_accuracy: 0.5769 - val_loss: 0.6816
# Epoch 41/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 0.5728 - loss: 0.6951 - val_accuracy: 0.5769 - val_loss: 0.6819
# Epoch 42/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 0.5717 - loss: 0.6923 - val_accuracy: 0.5769 - val_loss: 0.6814
# Epoch 43/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 0.6218 - loss: 0.6890 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 44/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - accuracy: 0.5417 - loss: 0.6840 - val_accuracy: 0.5769 - val_loss: 0.6818
# Epoch 45/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 0.6033 - loss: 0.6590 - val_accuracy: 0.5769 - val_loss: 0.6823
# Epoch 46/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 0.5974 - loss: 0.6816 - val_accuracy: 0.5769 - val_loss: 0.6821
# Epoch 47/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 0.6039 - loss: 0.6744 - val_accuracy: 0.5769 - val_loss: 0.6822
# Epoch 48/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step - accuracy: 0.5709 - loss: 0.6808 - val_accuracy: 0.5769 - val_loss: 0.6815
# Epoch 49/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 0.5678 - loss: 0.6893 - val_accuracy: 0.5769 - val_loss: 0.6813
# Epoch 50/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 0.5461 - loss: 0.6943 - val_accuracy: 0.5769 - val_loss: 0.6813
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 88s 3s/step - accuracy: 0.5802 - loss: 0.6801
#
# ✅ Test Accuracy: 0.5757
# ⏱ Training Time: 1025.72s | Testing Time: 94.44s
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 90s 3s/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     infacted       0.58      1.00      0.73       593
# not_infacted       0.00      0.00      0.00       437
#
#     accuracy                           0.58      1030
#    macro avg       0.29      0.50      0.37      1030
# weighted avg       0.33      0.58      0.42      1030
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ROC–AUC: 0.6236
# I0000 00:00:1761613278.724424      19 devices.cc:67] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 1
# I0000 00:00:1761613278.724632      19 single_machine.cc:361] Starting new session
# I0000 00:00:1761613278.725645      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# op: The nodes are operation kernel type, such as MatMul, Conv2D. Graph nodes belonging to the same type are aggregated together.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# Conv2D                   700.01m float_ops (100.00%, 87.17%)
# DepthwiseConv2dNative    69.06m float_ops (12.83%, 8.60%)
# Mul                      21.55m float_ops (4.23%, 2.68%)
# AddV2                    7.12m float_ops (1.55%, 0.89%)
# MatMul                   2.56m float_ops (0.66%, 0.32%)
# Mean                     2.37m float_ops (0.34%, 0.30%)
# Sub                      171.54k float_ops (0.05%, 0.02%)
# RealDiv                  150.53k float_ops (0.03%, 0.02%)
# Rsqrt                    42.02k float_ops (0.01%, 0.01%)
# BiasAdd                  10.34k float_ops (0.00%, 0.00%)
# Softmax                  5.00k float_ops (0.00%, 0.00%)
# Maximum                      3 float_ops (0.00%, 0.00%)
#
# ======================End of Report==========================
#
# ⚙️ GFLOPs per inference (input size (224, 224, 3)): 0.8031 GFLOPs

# %% [markdown]
# # Validation Split
# # train (10%)
# # test (90%)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# =======================
# Step 1: Split dataset into Train (10%) and Test (90%)
# =======================
train_df, test_df = train_test_split(
    df,
    test_size=0.9,  # 90% of total dataset for test
    stratify=df["label"],
    random_state=42
)

# =======================
# Step 2: Split Train into Train (90% of train) and Validation (10% of train)
# =======================
train_df, val_df = train_test_split(
    train_df,
    test_size=0.1,  # 10% of training portion
    stratify=train_df["label"] if len(train_df) > 1 else None,
    random_state=42
)

# =======================
# Step 3: Print results
# =======================
print("Train size:", len(train_df))
print("Validation size:", len(val_df))
print("Test size:", len(test_df))

print("\nTrain class distribution:")
print(train_df["label"].value_counts())
print("\nValidation class distribution:")
print(val_df["label"].value_counts())
print("\nTest class distribution:")
print(test_df["label"].value_counts())

# =======================
# Step 4: Save CSVs
# =======================
train_df.to_csv("/kaggle/working/train_split.csv", index=False)
val_df.to_csv("/kaggle/working/val_split.csv", index=False)
test_df.to_csv("/kaggle/working/test_split.csv", index=False)

print("\nTrain/Val/Test CSVs saved successfully!")
# Out:
# Train size: 115
# Validation size: 13
# Test size: 1159
#
# Train class distribution:
# label
# infacted        66
# not_infacted    49
# Name: count, dtype: int64
#
# Validation class distribution:
# label
# infacted        8
# not_infacted    5
# Name: count, dtype: int64
#
# Test class distribution:
# label
# infacted        667
# not_infacted    492
# Name: count, dtype: int64
#
# Train/Val/Test CSVs saved successfully!

# %% [markdown]
# # EfficientNetB0 Version

# %%
import time
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
from sklearn.preprocessing import label_binarize
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.layers import GlobalAveragePooling2D, Dropout, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# ======= Adjustable Epochs =======
EPOCHS = 50  # 🔁 Change this number anytime
BATCH_SIZE = 32
IMAGE_SIZE = (224, 224)

# ======= Load CSVs =======
train_df = pd.read_csv("/kaggle/working/train_split.csv")
val_df = pd.read_csv("/kaggle/working/val_split.csv")
test_df = pd.read_csv("/kaggle/working/test_split.csv")

# ======= Image Data Generators =======
train_datagen = ImageDataGenerator(rescale=1./255, horizontal_flip=True)
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_gen = train_datagen.flow_from_dataframe(
    train_df, 
    x_col="filepath", 
    y_col="label",
    target_size=IMAGE_SIZE, 
    batch_size=BATCH_SIZE, 
    class_mode="categorical",
    shuffle=True
)

val_gen = val_datagen.flow_from_dataframe(
    val_df, 
    x_col="filepath", 
    y_col="label",
    target_size=IMAGE_SIZE, 
    batch_size=BATCH_SIZE, 
    class_mode="categorical",
    shuffle=False
)

test_gen = test_datagen.flow_from_dataframe(
    test_df, 
    x_col="filepath", 
    y_col="label",
    target_size=IMAGE_SIZE, 
    batch_size=BATCH_SIZE, 
    class_mode="categorical",
    shuffle=False
)

num_classes = len(train_gen.class_indices)


# ======= Build EfficientNetB0 Model =======
base_model = EfficientNetB0(weights="imagenet", include_top=False, input_shape=(224, 224, 3))
x = GlobalAveragePooling2D()(base_model.output)
x = Dropout(0.3)(x)
output = Dense(num_classes, activation="softmax")(x)

model = Model(inputs=base_model.input, outputs=output)

for layer in base_model.layers:
    layer.trainable = False

model.compile(optimizer=Adam(1e-4), loss="categorical_crossentropy", metrics=["accuracy"])


print("Classes in train set:", train_gen.class_indices)
print("Classes in test set:", test_gen.class_indices)


# ======= Train =======
start_train = time.time()
history = model.fit(train_gen, validation_data=val_gen, epochs=EPOCHS)
train_time = time.time() - start_train

# ======= Evaluate =======
start_test = time.time()
test_loss, test_acc = model.evaluate(test_gen)
test_time = time.time() - start_test

print(f"\n✅ Test Accuracy: {test_acc:.4f}")
print(f"⏱ Training Time: {train_time:.2f}s | Testing Time: {test_time:.2f}s")

# ======= Predictions =======
y_true = test_gen.classes
y_pred_probs = model.predict(test_gen)
y_pred = np.argmax(y_pred_probs, axis=1)
class_labels = list(test_gen.class_indices.keys())

# ======= Metrics =======
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_labels))

# ======= Confusion Matrix =======
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.title("Confusion Matrix — EfficientNetB0")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# ======= ROC–AUC for binary classification =======
from sklearn.metrics import roc_auc_score, roc_curve, auc

# Use probability of 'not_infacted' or positive class
y_pred_prob_pos = y_pred_probs[:, 1]  # probability of class 1

auc_score = roc_auc_score(y_true, y_pred_prob_pos)
fpr, tpr, _ = roc_curve(y_true, y_pred_prob_pos)

plt.figure()
plt.plot(fpr, tpr, label=f"Binary ROC (AUC={auc_score:.2f})")
plt.plot([0, 1], [0, 1], 'k--')
plt.title("ROC Curve — EfficientNetB0")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.show()

print(f"\nROC–AUC: {auc_score:.4f}")


# ======= GFLOPs =======
import os
import tensorflow as tf
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2

# ======= Suppress TensorFlow GPU info logs =======
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'  # Only show warnings and errors

# ======= Define your model =======
input_shape = (224, 224, 3)  # Fixed input size
model = EfficientNetB0(input_shape=input_shape, include_top=True, weights=None)

# ======= Convert to ConcreteFunction =======
full_model = tf.function(lambda x: model(x))
full_model = full_model.get_concrete_function(
    tf.TensorSpec([1, *input_shape], model.inputs[0].dtype)
)

# ======= Freeze the graph =======
frozen_func = convert_variables_to_constants_v2(full_model)
graph_def = frozen_func.graph.as_graph_def()

# ======= Use TF Profiler to calculate FLOPs =======
with tf.Graph().as_default() as graph:
    tf.import_graph_def(graph_def, name='')
    run_meta = tf.compat.v1.RunMetadata()
    opts = tf.compat.v1.profiler.ProfileOptionBuilder.float_operation()
    flops = tf.compat.v1.profiler.profile(graph=graph, run_meta=run_meta, cmd='op', options=opts)

# ======= Print GFLOPs per inference =======
print(f"\n⚙️ GFLOPs per inference (input size {input_shape}): {flops.total_float_ops / 1e9:.4f} GFLOPs")
# Out:
# Found 115 validated image filenames belonging to 2 classes.
# Found 13 validated image filenames belonging to 2 classes.
# Found 1159 validated image filenames belonging to 2 classes.
# Classes in train set: {'infacted': 0, 'not_infacted': 1}
# Classes in test set: {'infacted': 0, 'not_infacted': 1}
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 51s 8s/step - accuracy: 0.4340 - loss: 0.7321 - val_accuracy: 0.3846 - val_loss: 0.7007
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.4617 - loss: 0.7257 - val_accuracy: 0.6154 - val_loss: 0.6893
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 11s 3s/step - accuracy: 0.5712 - loss: 0.6987 - val_accuracy: 0.6154 - val_loss: 0.6802
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.5246 - loss: 0.6977 - val_accuracy: 0.6154 - val_loss: 0.6751
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.6053 - loss: 0.6760 - val_accuracy: 0.6154 - val_loss: 0.6721
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 11s 3s/step - accuracy: 0.6010 - loss: 0.6782 - val_accuracy: 0.6154 - val_loss: 0.6698
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.5466 - loss: 0.7034 - val_accuracy: 0.6154 - val_loss: 0.6687
# Epoch 8/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.6014 - loss: 0.6611 - val_accuracy: 0.6154 - val_loss: 0.6680
# Epoch 9/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.5324 - loss: 0.6984 - val_accuracy: 0.6154 - val_loss: 0.6679
# Epoch 10/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 11s 3s/step - accuracy: 0.5351 - loss: 0.6937 - val_accuracy: 0.6154 - val_loss: 0.6679
# Epoch 11/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 11s 3s/step - accuracy: 0.5219 - loss: 0.6882 - val_accuracy: 0.6154 - val_loss: 0.6682
# Epoch 12/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - accuracy: 0.5601 - loss: 0.6831 - val_accuracy: 0.6154 - val_loss: 0.6679
# Epoch 13/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 11s 3s/step - accuracy: 0.5508 - loss: 0.7044 - val_accuracy: 0.6154 - val_loss: 0.6680
# Epoch 14/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 11s 3s/step - accuracy: 0.6146 - loss: 0.6847 - val_accuracy: 0.6154 - val_loss: 0.6679
# Epoch 15/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.5747 - loss: 0.6993 - val_accuracy: 0.6154 - val_loss: 0.6680
# Epoch 16/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.5064 - loss: 0.7281 - val_accuracy: 0.6154 - val_loss: 0.6684
# Epoch 17/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.5881 - loss: 0.6757 - val_accuracy: 0.6154 - val_loss: 0.6682
# Epoch 18/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.6118 - loss: 0.6743 - val_accuracy: 0.6154 - val_loss: 0.6683
# Epoch 19/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 11s 3s/step - accuracy: 0.5594 - loss: 0.6840 - val_accuracy: 0.6154 - val_loss: 0.6688
# Epoch 20/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 11s 3s/step - accuracy: 0.5876 - loss: 0.6928 - val_accuracy: 0.6154 - val_loss: 0.6692
# Epoch 21/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.5726 - loss: 0.6644 - val_accuracy: 0.6154 - val_loss: 0.6700
# Epoch 22/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.4974 - loss: 0.7069 - val_accuracy: 0.6154 - val_loss: 0.6705
# Epoch 23/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - accuracy: 0.5931 - loss: 0.6872 - val_accuracy: 0.6154 - val_loss: 0.6699
# Epoch 24/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.5217 - loss: 0.7136 - val_accuracy: 0.6154 - val_loss: 0.6701
# Epoch 25/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.6119 - loss: 0.6666 - val_accuracy: 0.6154 - val_loss: 0.6697
# Epoch 26/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 11s 3s/step - accuracy: 0.6206 - loss: 0.6634 - val_accuracy: 0.6154 - val_loss: 0.6697
# Epoch 27/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.5704 - loss: 0.6830 - val_accuracy: 0.6154 - val_loss: 0.6697
# Epoch 28/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.5712 - loss: 0.6983 - val_accuracy: 0.6154 - val_loss: 0.6695
# Epoch 29/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.5900 - loss: 0.6819 - val_accuracy: 0.6154 - val_loss: 0.6692
# Epoch 30/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - accuracy: 0.5507 - loss: 0.6850 - val_accuracy: 0.6154 - val_loss: 0.6690
# Epoch 31/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 11s 3s/step - accuracy: 0.5691 - loss: 0.6864 - val_accuracy: 0.6154 - val_loss: 0.6690
# Epoch 32/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.5716 - loss: 0.6918 - val_accuracy: 0.6154 - val_loss: 0.6696
# Epoch 33/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.6271 - loss: 0.6666 - val_accuracy: 0.6154 - val_loss: 0.6699
# Epoch 34/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - accuracy: 0.5365 - loss: 0.6888 - val_accuracy: 0.6154 - val_loss: 0.6704
# Epoch 35/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - accuracy: 0.4940 - loss: 0.7216 - val_accuracy: 0.6154 - val_loss: 0.6712
# Epoch 36/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 11s 3s/step - accuracy: 0.5243 - loss: 0.6856 - val_accuracy: 0.6154 - val_loss: 0.6709
# Epoch 37/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 11s 3s/step - accuracy: 0.5059 - loss: 0.7066 - val_accuracy: 0.6154 - val_loss: 0.6706
# Epoch 38/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.5476 - loss: 0.6757 - val_accuracy: 0.6154 - val_loss: 0.6708
# Epoch 39/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.5283 - loss: 0.7064 - val_accuracy: 0.6154 - val_loss: 0.6704
# Epoch 40/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.5598 - loss: 0.7020 - val_accuracy: 0.6154 - val_loss: 0.6698
# Epoch 41/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.5992 - loss: 0.6886 - val_accuracy: 0.6154 - val_loss: 0.6698
# Epoch 42/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.6036 - loss: 0.6772 - val_accuracy: 0.6154 - val_loss: 0.6694
# Epoch 43/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.5711 - loss: 0.6701 - val_accuracy: 0.6154 - val_loss: 0.6687
# Epoch 44/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.5842 - loss: 0.6773 - val_accuracy: 0.6154 - val_loss: 0.6684
# Epoch 45/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 11s 3s/step - accuracy: 0.5841 - loss: 0.6761 - val_accuracy: 0.6154 - val_loss: 0.6684
# Epoch 46/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.5733 - loss: 0.6720 - val_accuracy: 0.6154 - val_loss: 0.6685
# Epoch 47/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 11s 3s/step - accuracy: 0.6375 - loss: 0.6561 - val_accuracy: 0.6154 - val_loss: 0.6683
# Epoch 48/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.6003 - loss: 0.6684 - val_accuracy: 0.6154 - val_loss: 0.6687
# Epoch 49/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - accuracy: 0.5625 - loss: 0.6805 - val_accuracy: 0.6154 - val_loss: 0.6692
# Epoch 50/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 11s 3s/step - accuracy: 0.6068 - loss: 0.6716 - val_accuracy: 0.6154 - val_loss: 0.6700
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 91s 2s/step - accuracy: 0.5765 - loss: 0.6814
#
# ✅ Test Accuracy: 0.5755
# ⏱ Training Time: 555.57s | Testing Time: 95.79s
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 108s 3s/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     infacted       0.58      1.00      0.73       667
# not_infacted       0.00      0.00      0.00       492
#
#     accuracy                           0.58      1159
#    macro avg       0.29      0.50      0.37      1159
# weighted avg       0.33      0.58      0.42      1159
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ROC–AUC: 0.5304
# I0000 00:00:1761614056.989081      19 devices.cc:67] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 1
# I0000 00:00:1761614056.989254      19 single_machine.cc:361] Starting new session
# I0000 00:00:1761614056.990472      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# op: The nodes are operation kernel type, such as MatMul, Conv2D. Graph nodes belonging to the same type are aggregated together.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# Conv2D                   700.01m float_ops (100.00%, 87.17%)
# DepthwiseConv2dNative    69.06m float_ops (12.83%, 8.60%)
# Mul                      21.55m float_ops (4.23%, 2.68%)
# AddV2                    7.12m float_ops (1.55%, 0.89%)
# MatMul                   2.56m float_ops (0.66%, 0.32%)
# Mean                     2.37m float_ops (0.34%, 0.30%)
# Sub                      171.54k float_ops (0.05%, 0.02%)
# RealDiv                  150.53k float_ops (0.03%, 0.02%)
# Rsqrt                    42.02k float_ops (0.01%, 0.01%)
# BiasAdd                  10.34k float_ops (0.00%, 0.00%)
# Softmax                  5.00k float_ops (0.00%, 0.00%)
# Maximum                      3 float_ops (0.00%, 0.00%)
#
# ======================End of Report==========================
#
# ⚙️ GFLOPs per inference (input size (224, 224, 3)): 0.8031 GFLOPs
