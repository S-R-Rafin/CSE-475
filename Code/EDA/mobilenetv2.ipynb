jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610175355.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG_20230612_130011.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG_2002.JPG
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG_2047.JPG
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610182612.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG-20230529-WA0058.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230807183254.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG_1995.JPG
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610180154.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG-20230529-WA0030.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610183110.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG_20230612_130319.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610175720.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610180401.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG_3228.JPG
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610181237.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230807183517.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG-20230529-WA0022.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610182246.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG-20230529-WA0040.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG-20230611-WA0034.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610181153.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610182550.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG-20230529-WA0033.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610180803.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610181600.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG-20230611-WA0009.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610183047.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610182341.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG_2004.JPG
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG_2094.JPG
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610182711.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG-20230529-WA0020.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610181125.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610182932.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG_2092.JPG
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230807183129.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG_1989.JPG
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG_2070.JPG
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610180414.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230807183944.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610180335.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG-20230529-WA0043.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610181341.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230807183248.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610182556.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG_20230612_130055.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG-20230529-WA0039.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG_1980.JPG
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG_2095.JPG
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG_2005.JPG
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610180720.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG_2066.JPG
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610180822.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610175439.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG_20230612_125907.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230807183123.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230807183242.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610175401.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610180423.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG_20230612_130740.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG-20230529-WA0046.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG_2023.JPG
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610181241.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610175859.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610175939.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230807183922.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230807183559.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610183052.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230807183331.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610180340.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG-20230529-WA0038.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610175513.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG-20230611-WA0025.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230807183638.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230807183101.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG_1975.JPG
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610180232.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG_1999.JPG
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610182635.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG-20230529-WA0000.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG_1969.JPG
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG_3231.JPG
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG_1972.JPG
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230807183739.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610180815.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610182729.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230807183251.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG-20230529-WA0067.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610181120.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230807183159.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG-20230611-WA0007.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG_3240.JPG
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG-20230529-WA0045.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610180122.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230807183520.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610181353.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230807183231.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG_20230612_125915.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG-20230611-WA0008.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230807183145.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230807183622.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG_1968.JPG
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG_2058.JPG
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610180418.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610180523.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG_2014.JPG
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610180359.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230807183239.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610181617.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG-20230529-WA0006.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG-20230529-WA0032.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG_3239.JPG
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG-20230529-WA0015.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230807183126.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG-20230611-WA0037.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610175922.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG_2001.JPG
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230807183258.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG_20230616_153344.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230807183048.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG-20230529-WA0005.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230807183835.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG_2091.JPG
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG-20230529-WA0008.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610181404.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610182539.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG_20230612_130405.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610174916.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230807183054.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG_2037.JPG
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG_20230612_130039.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610175258.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610181207.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610182520.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG_20230616_153459.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG_20230618_002604.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610180326.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG_1983.JPG
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG-20230529-WA0057.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG_20230612_130400.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610180520.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG-20230529-WA0062.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610175815.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610175910.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610181741.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610182345.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610181332.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610175021.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230807183202.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610180431.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610175936.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG-20230529-WA0009.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG-20230529-WA0047.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610182301.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG_1984.JPG
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG20230610181316.jpg
# /kaggle/input/dip-arsenic/Original_Data/not_infacted/IMG_3234.JPG

# %% [markdown]
# # Import file

# %%
import os
import glob
import shutil
import itertools
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
from tqdm.notebook import tqdm
from sklearn.model_selection import GroupShuffleSplit
import torchvision.transforms as T
import cv2

# %% [markdown]
# # DATASET PATH VERIFICATION

# %%
# ============================================================
# STEP 1: DATASET PATH VERIFICATION
# ============================================================
data_dir ='/kaggle/input/dip-arsenic/Original_Data'
print("Dataset path:", data_dir)
print("Exists:", os.path.exists(data_dir))
print("Subfolders:", os.listdir(data_dir))

# Optional: Copy to local path for faster I/O
local_dir = '/content/Original_Data'
if not os.path.exists(local_dir):
    shutil.copytree(data_dir, local_dir)
    print("Dataset copied locally to:", local_dir)
else:
    print("Local dataset already exists at:", local_dir)

BASE_PATH = local_dir

filepaths = []
labels = []
groups = [] 


for label in os.listdir(BASE_PATH):
    label_path = os.path.join(BASE_PATH, label)
    if os.path.isdir(label_path):
        for fname in os.listdir(label_path):
            if fname.lower().endswith(('.jpg', '.jpeg', '.png')):
                filepaths.append(os.path.join(label_path, fname))
                labels.append(label)
                groups.append(label)  


df = pd.DataFrame({
    "filepath": filepaths,
    "label": labels,
    "group": groups
})

print("Total samples:", len(df))
print(df.head())
# Out:
# Dataset path: /kaggle/input/dip-arsenic/Original_Data
# Exists: True
# Subfolders: ['infacted', 'not_infacted']
# Dataset copied locally to: /content/Original_Data
# Total samples: 1287
#                                             filepath         label  \
# 0  /content/Original_Data/not_infacted/IMG2023061...  not_infacted
# 1  /content/Original_Data/not_infacted/IMG2023080...  not_infacted
# 2  /content/Original_Data/not_infacted/IMG2023080...  not_infacted
# 3  /content/Original_Data/not_infacted/IMG2023061...  not_infacted
# 4  /content/Original_Data/not_infacted/IMG2023080...  not_infacted
#
#           group
# 0  not_infacted
# 1  not_infacted
# 2  not_infacted
# 3  not_infacted
# 4  not_infacted

# %% [markdown]
# # CLASS DETECTION FROM FOLDER NAMES

# %%
available_classes = [f for f in os.listdir(BASE_PATH) if os.path.isdir(os.path.join(BASE_PATH, f))]
print("Available class folders:", available_classes)

if not available_classes:
    raise ValueError("No class folders found. Check dataset path.")

CLASSES = available_classes
# Out:
# Available class folders: ['not_infacted', 'infacted']

# %% [markdown]
# # COMPUTE IMAGE STATISTICS

# %%
def compute_image_stats(image):
    if image.mode != "RGB":
        image = image.convert("RGB")

    arr = np.asarray(image, dtype=np.float32) / 255.0
    hsv = np.asarray(image.convert("HSV"), dtype=np.float32) / 255.0

    stats = {}
    for i, c in enumerate(['R', 'G', 'B']):
        stats[f'{c}_mean'] = arr[:, :, i].mean()
        stats[f'{c}_std'] = arr[:, :, i].std()
    for i, c in enumerate(['H', 'S', 'V']):
        stats[f'{c}_mean'] = hsv[:, :, i].mean()
        stats[f'{c}_std'] = hsv[:, :, i].std()

    stats['brightness'] = hsv[:, :, 2].mean()
    stats['contrast'] = arr.std(axis=(0,1)).mean()

    s = hsv[:, :, 1]
    stats['sat_clip_low'] = np.mean(s < 0.05)
    stats['sat_clip_high'] = np.mean(s > 0.95)

    stats['width'], stats['height'] = image.size
    stats['aspect_ratio'] = image.width / image.height

    return stats

rows = []
MAX_IMAGES = None  # Set to a number for testing (e.g., 200)

for cls in CLASSES:
    folder = os.path.join(BASE_PATH, cls)
    img_paths = glob.glob(os.path.join(folder, "*.*"))
    if MAX_IMAGES:
        img_paths = img_paths[:MAX_IMAGES]

    if not img_paths:
        print(f"No images found in folder: {folder}")
        continue

    print(f"Processing {len(img_paths)} images in class '{cls}'...")
    for path in tqdm(img_paths, desc=f"{cls} images"):
        if not path.lower().endswith((".jpg", ".jpeg", ".png", ".bmp")):
            continue
        try:
            img = Image.open(path)
            stats = compute_image_stats(img)
            stats["class"] = cls
            stats["filename"] = os.path.basename(path)
            rows.append(stats)
        except:
            continue

if not rows:
    raise ValueError("No valid images found. Check dataset path or folder structure.")

df_stats = pd.DataFrame(rows)
print("Total images processed:", len(df_stats))
display(df_stats.head())
# Out:
# Processing 546 images in class 'not_infacted'...
# not_infacted images:   0%|          | 0/546 [00:00<?, ?it/s]
# Processing 741 images in class 'infacted'...
# infacted images:   0%|          | 0/741 [00:00<?, ?it/s]
# Total images processed: 1287
#      R_mean     R_std    G_mean     G_std    B_mean     B_std    H_mean  \
# 0  0.695316  0.088976  0.572566  0.088561  0.451598  0.090655  0.080867
# 1  0.577354  0.080682  0.503701  0.082955  0.405659  0.083312  0.093330
# 2  0.633974  0.059775  0.607313  0.069123  0.567375  0.078073  0.105668
# 3  0.707919  0.082438  0.577458  0.084216  0.462828  0.086566  0.075615
# 4  0.573293  0.057554  0.544498  0.059090  0.499595  0.060271  0.099822
#
#       H_std    S_mean     S_std  ...     V_std  brightness  contrast  \
# 0  0.005082  0.354899  0.062826  ...  0.088976    0.695316  0.093286
# 1  0.004695  0.302068  0.050794  ...  0.080682    0.577354  0.086205
# 2  0.033857  0.106743  0.056050  ...  0.059873    0.634150  0.076029
# 3  0.006143  0.350953  0.071282  ...  0.082438    0.707919  0.086152
# 4  0.009901  0.128594  0.023085  ...  0.057554    0.573294  0.060929
#
#    sat_clip_low  sat_clip_high  width  height  aspect_ratio         class  \
# 0  1.371910e-06   4.913934e-05   3468    4624          0.75  not_infacted
# 1  0.000000e+00   0.000000e+00   3468    4624          0.75  not_infacted
# 2  1.479995e-01   0.000000e+00   3468    4624          0.75  not_infacted
# 3  3.117978e-05   9.131935e-04   3468    4624          0.75  not_infacted
# 4  1.870787e-07   6.235957e-08   3468    4624          0.75  not_infacted
#
#                 filename
# 0  IMG20230610181733.jpg
# 1  IMG20230807183520.jpg
# 2  IMG20230807183123.jpg
# 3  IMG20230610181308.jpg
# 4  IMG20230807183248.jpg
#
# [5 rows x 21 columns]

# %% [markdown]
# # HISTOGRAM VISUALIZATION

# %%
sample_row = df_stats.iloc[0]
sample_img_path = os.path.join(BASE_PATH, sample_row["class"], sample_row["filename"])
sample_img = Image.open(sample_img_path)
arr = np.asarray(sample_img)

plt.figure(figsize=(12,4))
for i,color in enumerate(['r','g','b']):
    plt.hist(arr[:,:,i].ravel(), bins=256, color=color, alpha=0.5, label=color.upper())
plt.title("RGB Histogram (Sample)")
plt.legend()
plt.show()

hsv = np.asarray(sample_img.convert("HSV"))
plt.figure(figsize=(12,4))
for i,color in enumerate(['h','s','v']):
    plt.hist(hsv[:,:,i].ravel(), bins=256, alpha=0.5, label=color.upper())
plt.title("HSV Histogram (Sample)")
plt.legend()
plt.show()

# %% [markdown]
# # PER-CLASS SUMMARY STATISTICS

# %%
numeric_cols = df_stats.select_dtypes(include=np.number).columns.tolist()
summary = df_stats.groupby("class")[numeric_cols].agg(["mean","std"])
print("Per-Class Mean & STD:")
display(summary)

# Brightness vs Contrast
plt.figure(figsize=(7,6))
sns.scatterplot(data=df_stats, x="brightness", y="contrast", hue="class", alpha=0.7)
plt.title("Brightness vs Contrast Spread")
plt.show()

# Saturation Clipping
plt.figure(figsize=(6,5))
sns.boxplot(data=df_stats, x="class", y="sat_clip_high")
plt.title("Saturation Clipping (High values)")
plt.show()

# Resolution and Aspect Ratio
plt.figure(figsize=(7,5))
sns.histplot(data=df_stats, x="width", bins=30, hue="class", element="step")
plt.title("Width Distribution per Class")
plt.show()

plt.figure(figsize=(7,5))
sns.histplot(data=df_stats, x="height", bins=30, hue="class", element="step")
plt.title("Height Distribution per Class")
plt.show()

plt.figure(figsize=(7,5))
sns.histplot(data=df_stats, x="aspect_ratio", bins=30, hue="class", element="step")
plt.title("Aspect Ratio Distribution per Class")
plt.show()

# Suggested Resize Target
mean_w, mean_h = df_stats['width'].mean(), df_stats['height'].mean()
print(f"Suggested resize target: ({int(mean_w)}x{int(mean_h)})")
print("""
Suggested Strategy:
- Resize all images to a fixed size (e.g., 256×256)
- Maintain aspect ratio by padding (black or mean color)
- For CNNs, use random crop + resize augmentation
""")
# Out:
# Per-Class Mean & STD:
#                 R_mean               R_std              G_mean            \
#                   mean       std      mean       std      mean       std
# class
# infacted      0.684950  0.081812  0.140340  0.037378  0.545283  0.061217
# not_infacted  0.659803  0.077076  0.100049  0.039741  0.569448  0.080927
#
#                  G_std              B_mean            ... sat_clip_low  \
#                   mean       std      mean       std  ...         mean
# class                                                 ...
# infacted      0.139184  0.035920  0.456526  0.059377  ...     0.008509
# not_infacted  0.106481  0.042616  0.496035  0.083903  ...     0.029440
#
#                        sat_clip_high                  width              \
#                    std          mean       std         mean         std
# class
# infacted      0.029280      0.001327  0.005978  4032.000000     0.00000
# not_infacted  0.083165      0.001277  0.004610  3196.294872  1047.82375
#
#                    height              aspect_ratio
#                      mean          std         mean       std
# class
# infacted      3024.000000     0.000000     1.333333  0.000000
# not_infacted  3656.826007  1244.889474     0.929098  0.386921
#
# [2 rows x 38 columns]
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# Suggested resize target: (3677x3292)
#
# Suggested Strategy:
# - Resize all images to a fixed size (e.g., 256×256)
# - Maintain aspect ratio by padding (black or mean color)
# - For CNNs, use random crop + resize augmentation

# %% [markdown]
# # IMAGE QUALITY METRICS (LAPLACIAN VARIANCE & NOISE)

# %%
def laplacian_variance(image_path):
    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    if img is None:
        return None
    lap = cv2.Laplacian(img, cv2.CV_64F)
    return lap.var()

def noise_proxy(image_path):
    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    if img is None:
        return None
    blurred = cv2.GaussianBlur(img, (3, 3), 0)
    noise = img.astype("float") - blurred.astype("float")
    return noise.var()

categories = CLASSES
quality_data = []

for category in categories:
    folder_path = os.path.join(BASE_PATH, category)
    for filename in tqdm(os.listdir(folder_path), desc=f"Quality check: {category}"):
        img_path = os.path.join(folder_path, filename)
        lap_var = laplacian_variance(img_path)
        noise_val = noise_proxy(img_path)
        quality_data.append({
            'filename': filename,
            'category': category,
            'laplacian_variance': lap_var,
            'noise_proxy': noise_val
        })

df_quality = pd.DataFrame(quality_data)
output_csv = '/content/laplacian_noise_results.csv'
df_quality.to_csv(output_csv, index=False)
print("CSV saved to:", output_csv)
print(df_quality.groupby('category')[['laplacian_variance', 'noise_proxy']].mean())
# Out:
# Quality check: not_infacted:   0%|          | 0/546 [00:00<?, ?it/s]
# Quality check: infacted:   0%|          | 0/741 [00:00<?, ?it/s]
# CSV saved to: /content/laplacian_noise_results.csv
#               laplacian_variance  noise_proxy
# category
# infacted               22.096996     1.227764
# not_infacted           30.358032     1.568775

# %% [markdown]
# # DUPLICATE DETECTION (Perceptual Hashing)

# %%
def gray_world_correction(pil_image):
    if pil_image.mode != 'RGB':
        pil_image = pil_image.convert('RGB')
    arr = np.asarray(pil_image).astype(np.float32)
    mean_r, mean_g, mean_b = arr[:,:,0].mean(), arr[:,:,1].mean(), arr[:,:,2].mean()
    mean_gray = (mean_r + mean_g + mean_b) / 3.0
    arr[:,:,0] = np.clip(arr[:,:,0] * (mean_gray / mean_r), 0, 255)
    arr[:,:,1] = np.clip(arr[:,:,1] * (mean_gray / mean_g), 0, 255)
    arr[:,:,2] = np.clip(arr[:,:,2] * (mean_gray / mean_b), 0, 255)
    return Image.fromarray(arr.astype(np.uint8))

def ahash(image, hash_size=8):
    image = image.convert('L').resize((hash_size, hash_size), Image.Resampling.LANCZOS)
    pixels = np.array(image)
    avg = pixels.mean()
    return ''.join(['1' if p > avg else '0' for p in pixels.flatten()])

def dhash(image, hash_size=8):
    image = image.convert('L').resize((hash_size + 1, hash_size), Image.Resampling.LANCZOS)
    pixels = np.array(image)
    diff = pixels[:, 1:] > pixels[:, :-1]
    return ''.join(['1' if v else '0' for v in diff.flatten()])

def hamming_distance(hash1, hash2):
    return sum(c1 != c2 for c1, c2 in zip(hash1, hash2))

image_paths = glob.glob(os.path.join(BASE_PATH, '**', '*.*'), recursive=True)
image_paths = [p for p in image_paths if p.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp'))]
print("Total image paths found:", len(image_paths))

rows = []
for img_path in tqdm(image_paths, desc="Perceptual hashing"):
    try:
        img = Image.open(img_path)
        row = {
            "filename": os.path.basename(img_path),
            "path": img_path,
            "ahash": ahash(img),
            "dhash": dhash(img)
        }
        rows.append(row)
    except Exception as e:
        print(f"Error processing {img_path}: {e}")

if not rows:
    print("No valid image data found.")
else:
    df_hash = pd.DataFrame(rows)
    df_hash = df_hash.sort_values("filename").reset_index(drop=True)
    print("Hash DataFrame:")
    display(df_hash.head())

    duplicates = []
    threshold = 5
    for (i1, row1), (i2, row2) in itertools.combinations(df_hash.iterrows(), 2):
        hd_ahash = hamming_distance(row1['ahash'], row2['ahash'])
        hd_dhash = hamming_distance(row1['dhash'], row2['dhash'])
        if hd_ahash <= threshold and hd_dhash <= threshold:
            duplicates.append({
                "file1": row1['filename'],
                "file2": row2['filename'],
                "ahash_dist": hd_ahash,
                "dhash_dist": hd_dhash
            })

    dup_df = pd.DataFrame(duplicates)
    if not dup_df.empty:
        print("Duplicates found:")
        display(dup_df)
    else:
        print("No duplicates detected.")
# Out:
# Total image paths found: 1287
# Perceptual hashing:   0%|          | 0/1287 [00:00<?, ?it/s]
# Hash DataFrame:
#                   filename                                               path  \
# 0  IMG-20230529-WA0000.jpg  /content/Original_Data/not_infacted/IMG-202305...
# 1  IMG-20230529-WA0001.jpg  /content/Original_Data/not_infacted/IMG-202305...
# 2  IMG-20230529-WA0002.jpg  /content/Original_Data/not_infacted/IMG-202305...
# 3  IMG-20230529-WA0003.jpg  /content/Original_Data/not_infacted/IMG-202305...
# 4  IMG-20230529-WA0004.jpg  /content/Original_Data/not_infacted/IMG-202305...
#
#                                                ahash  \
# 0  0000000000000000000000011000011111011111111111...
# 1  0000111100111111011011010100110100010111000101...
# 2  0000011100001111000001110000011100001111000011...
# 3  0101111111001111110011101000000010000100000001...
# 4  0000111100001111000001110000011101111111111111...
#
#                                                dhash
# 0  1011011111101010011011110011110100110100100101...
# 1  0111101101101111110110011101100111110100011101...
# 2  1111111011111110011111101110111011101100111011...
# 3  1001101110011010000110100010100100111101001011...
# 4  1111111000111110111111101110111111011011110000...
# Duplicates found:
#                       file1                    file2  ahash_dist  dhash_dist
# 0   IMG-20230529-WA0019.jpg  IMG-20230529-WA0067.jpg           2           2
# 1   IMG-20230529-WA0021.jpg  IMG-20230529-WA0060.jpg           4           4
# 2   IMG-20230529-WA0021.jpg  IMG_20230612_130410.jpg           2           5
# 3   IMG-20230529-WA0042.jpg  IMG-20230529-WA0046.jpg           4           3
# 4   IMG-20230529-WA0042.jpg    IMG20230610182635.jpg           5           4
# ..                      ...                      ...         ...         ...
# 77  IMG_20230612_130815.jpg  IMG_20230612_130817.jpg           4           2
# 78  IMG_20230616_153459.jpg  IMG_20230616_153500.jpg           3           1
# 79             IMG_2025.JPG             IMG_2026.JPG           1           2
# 80             IMG_2074.JPG             IMG_2075.JPG           1           5
# 81             IMG_2074.JPG             IMG_2076.JPG           1           4
#
# [82 rows x 4 columns]

# %% [markdown]
# # DATAFRAME BUILDING & GROUPED TRAIN-TEST SPLIT

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import GroupShuffleSplit

train_groups = []
test_groups = []

# Split safely per label
for lbl, sub_df in df.groupby("label"):
    groups = sub_df["group"].unique()
    n_groups = len(groups)

    if n_groups < 2:
        print(f" Label '{lbl}' has only {n_groups} group(s) — assigning all to train.")
        train_groups.extend(groups)
        continue

    # otherwise, do normal 80/20 split
    gss = GroupShuffleSplit(n_splits=1, train_size=0.8, random_state=42)
    train_idx, test_idx = next(gss.split(groups, groups=groups))
    train_groups.extend(groups[train_idx])
    test_groups.extend(groups[test_idx])

# build full DataFrames
train_df = df[df["group"].isin(train_groups)].reset_index(drop=True)
test_df = df[df["group"].isin(test_groups)].reset_index(drop=True)

# print summary
print("\n Safe Label-wise Group Split Complete")
print("---------------------------------------")
print(f"Train size: {len(train_df)}")
print(f"Test size: {len(test_df)}")
print("Unique groups in train:", train_df["group"].nunique())
print("Unique groups in test:", test_df["group"].nunique())

print("\n Train class distribution:")
print(train_df["label"].value_counts())
print("\nTest class distribution:")
print(test_df["label"].value_counts())

# save csvs
train_df.to_csv("/kaggle/working/train_split.csv", index=False)
test_df.to_csv("/kaggle/working/test_split.csv", index=False)
print("\n Train/Test split CSVs saved in /kaggle/working/")
# Out:
#  Label 'infacted' has only 1 group(s) — assigning all to train.
#  Label 'not_infacted' has only 1 group(s) — assigning all to train.
#
#  Safe Label-wise Group Split Complete
# ---------------------------------------
# Train size: 1287
# Test size: 0
# Unique groups in train: 2
# Unique groups in test: 0
#
#  Train class distribution:
# label
# infacted        741
# not_infacted    546
# Name: count, dtype: int64
#
# Test class distribution:
# Series([], Name: count, dtype: int64)
#
#  Train/Test split CSVs saved in /kaggle/working/

# %% [markdown]
# # : AUGMENTATION PROBE

# %%
sample_path = train_df['filepath'].sample(1, random_state=42).iloc[0]
img = Image.open(sample_path)

augmentations = {
    "RandomCrop": T.RandomResizedCrop(size=244, scale=(0.8, 1.0)),
    "HorizontalFlip": T.RandomHorizontalFlip(p=1.0),
    "ColorJitter": T.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
    "GaussianBlur": T.GaussianBlur(kernel_size=5),
    "HeavyRotation": T.RandomRotation(degrees=90),
}

fig, axes = plt.subplots(1, len(augmentations)+1, figsize=(18,5))
axes[0].imshow(img)
axes[0].set_title("Original")
axes[0].axis("off")

for i, (name, aug) in enumerate(augmentations.items(), 1):
    transformed = aug(img)
    axes[i].imshow(transformed)
    axes[i].set_title(name)
    axes[i].axis("off")

plt.tight_layout()
plt.show()

print("Augmentation probe complete. Visually inspect which transforms are helpful or harmful.")
# Out:
# Augmentation probe complete. Visually inspect which transforms are helpful or harmful.

# %% [markdown]
# # Validation Split
# # train (90%)
# # test (10%)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Example: df should have columns ['filepath', 'label', 'group']

# Train 90% + Test 10%
train_df, test_df = train_test_split(
    df,
    test_size=0.1,
    stratify=df["label"],
    random_state=42
)

# Validation = 10% of total dataset → 10 / 90 = 0.1111 of train
train_df, val_df = train_test_split(
    train_df,
    test_size=0.1,
    stratify=train_df["label"],
    random_state=42
)

# Step 3: Print results
print("Train size:", len(train_df))
print("Validation size:", len(val_df))
print("Test size:", len(test_df))

print("\nTrain class distribution:")
print(train_df["label"].value_counts())
print("\nValidation class distribution:")
print(val_df["label"].value_counts())
print("\nTest class distribution:")
print(test_df["label"].value_counts())

# Step 4: Save CSVs
train_df.to_csv("/kaggle/working/train_split.csv", index=False)
val_df.to_csv("/kaggle/working/val_split.csv", index=False)
test_df.to_csv("/kaggle/working/test_split.csv", index=False)

print("\n Train/Val/Test CSVs saved successfully!")
# Out:
# Train size: 1042
# Validation size: 116
# Test size: 129
#
# Train class distribution:
# label
# infacted        600
# not_infacted    442
# Name: count, dtype: int64
#
# Validation class distribution:
# label
# infacted        67
# not_infacted    49
# Name: count, dtype: int64
#
# Test class distribution:
# label
# infacted        74
# not_infacted    55
# Name: count, dtype: int64
#
#  Train/Val/Test CSVs saved successfully!

# %% [markdown]
# # MobileNetV2

# %%
import time
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
from sklearn.preprocessing import label_binarize
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import GlobalAveragePooling2D, Dropout, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# ======= Adjustable Epochs =======
EPOCHS = 50 # 🔁 Change this number anytime
BATCH_SIZE = 32
IMAGE_SIZE = (224, 224)

# ======= Load CSVs =======
train_df = pd.read_csv("/kaggle/working/train_split.csv")
val_df = pd.read_csv("/kaggle/working/val_split.csv")
test_df = pd.read_csv("/kaggle/working/test_split.csv")

# ======= Image Data Generators =======
train_datagen = ImageDataGenerator(rescale=1./255, horizontal_flip=True)
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_gen = train_datagen.flow_from_dataframe(
    train_df, 
    x_col="filepath", 
    y_col="label",
    target_size=IMAGE_SIZE, 
    batch_size=BATCH_SIZE, 
    class_mode="categorical",
    shuffle=True
)

val_gen = val_datagen.flow_from_dataframe(
    val_df, 
    x_col="filepath", 
    y_col="label",
    target_size=IMAGE_SIZE, 
    batch_size=BATCH_SIZE, 
    class_mode="categorical",
    shuffle=False
)

test_gen = test_datagen.flow_from_dataframe(
    test_df, 
    x_col="filepath", 
    y_col="label",
    target_size=IMAGE_SIZE, 
    batch_size=BATCH_SIZE, 
    class_mode="categorical",
    shuffle=False
)

num_classes = len(train_gen.class_indices)


# ======= Build MobileNetV2 Model =======
base_model = MobileNetV2(weights="imagenet", include_top=False, input_shape=(224, 224, 3))
x = GlobalAveragePooling2D()(base_model.output)
x = Dropout(0.3)(x)
output = Dense(num_classes, activation="softmax")(x)

model = Model(inputs=base_model.input, outputs=output)

for layer in base_model.layers:
    layer.trainable = False

model.compile(optimizer=Adam(1e-4), loss="categorical_crossentropy", metrics=["accuracy"])

print("Classes in train set:", train_gen.class_indices)
print("Classes in test set:", test_gen.class_indices)


# ======= Train =======
start_train = time.time()
history = model.fit(train_gen, validation_data=val_gen, epochs=EPOCHS)
train_time = time.time() - start_train

# ======= Evaluate =======
start_test = time.time()
test_loss, test_acc = model.evaluate(test_gen)
test_time = time.time() - start_test

print(f"\n✅ Test Accuracy: {test_acc:.4f}")
print(f"⏱ Training Time: {train_time:.2f}s | Testing Time: {test_time:.2f}s")

# ======= Predictions =======
y_true = test_gen.classes
y_pred_probs = model.predict(test_gen)
y_pred = np.argmax(y_pred_probs, axis=1)
class_labels = list(test_gen.class_indices.keys())

# ======= Metrics =======
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_labels))

# ======= Confusion Matrix =======
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.title("Confusion Matrix — MobileNetV2")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# ======= ROC–AUC for binary classification =======
from sklearn.metrics import roc_auc_score, roc_curve, auc

# Use probability of 'not_infacted' or positive class
y_pred_prob_pos = y_pred_probs[:, 1]  # probability of class 1

auc_score = roc_auc_score(y_true, y_pred_prob_pos)
fpr, tpr, _ = roc_curve(y_true, y_pred_prob_pos)

plt.figure()
plt.plot(fpr, tpr, label=f"Binary ROC (AUC={auc_score:.2f})")
plt.plot([0, 1], [0, 1], 'k--')
plt.title("ROC Curve — MobileNetV2")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.show()

print(f"\nROC–AUC: {auc_score:.4f}")


# ======= GFLOPs =======
import os
import tensorflow as tf
from tensorflow.keras.applications import MobileNetV2
from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2

# ======= Suppress TensorFlow GPU info logs =======
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'  # Only show warnings and errors

# ======= Define your model =======
input_shape = (224, 224, 3)  # Fixed input size
model = MobileNetV2(input_shape=input_shape, include_top=True, weights=None)

# ======= Convert to ConcreteFunction =======
full_model = tf.function(lambda x: model(x))
full_model = full_model.get_concrete_function(
    tf.TensorSpec([1, *input_shape], model.inputs[0].dtype)
)

# ======= Freeze the graph =======
frozen_func = convert_variables_to_constants_v2(full_model)
graph_def = frozen_func.graph.as_graph_def()

# ======= Use TF Profiler to calculate FLOPs =======
with tf.Graph().as_default() as graph:
    tf.import_graph_def(graph_def, name='')
    run_meta = tf.compat.v1.RunMetadata()
    opts = tf.compat.v1.profiler.ProfileOptionBuilder.float_operation()
    flops = tf.compat.v1.profiler.profile(graph=graph, run_meta=run_meta, cmd='op', options=opts)

# ======= Print GFLOPs per inference =======
print(f"\n⚙️ GFLOPs per inference (input size {input_shape}): {flops.total_float_ops / 1e9:.4f} GFLOPs")
# Out:
# 2025-10-27 19:30:00.282134: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761593400.466099      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761593400.517443      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Found 1042 validated image filenames belonging to 2 classes.
# Found 116 validated image filenames belonging to 2 classes.
# Found 129 validated image filenames belonging to 2 classes.
# I0000 00:00:1761593411.629358      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Classes in train set: {'infacted': 0, 'not_infacted': 1}
# Classes in test set: {'infacted': 0, 'not_infacted': 1}
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1761593432.200803      66 service.cc:148] XLA service 0x784514004cd0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1761593432.201607      66 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1761593433.327738      66 cuda_dnn.cc:529] Loaded cuDNN version 90300
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 8:20 16s/step - accuracy: 0.4688 - loss: 0.9364
# I0000 00:00:1761593437.357298      66 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 111s 3s/step - accuracy: 0.
# Epoch 32/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 31s 3s/step - accuracy: 0.8506 - loss: 0.3676 - val_accuracy: 0.8718 - val_loss: 0.3780
# Epoch 33/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 31s 3s/step - accuracy: 0.8451 - loss: 0.3445 - val_accuracy: 0.8718 - val_loss: 0.3730
# Epoch 34/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 28s 3s/step - accuracy: 0.8506 - loss: 0.3811 - val_accuracy: 0.8718 - val_loss: 0.3684
# Epoch 35/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 30s 3s/step - accuracy: 0.8681 - loss: 0.3225 - val_accuracy: 0.8718 - val_loss: 0.3652
# Epoch 36/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 28s 3s/step - accuracy: 0.8664 - loss: 0.3807 - val_accuracy: 0.8718 - val_loss: 0.3618
# Epoch 37/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 31s 3s/step - accuracy: 0.8323 - loss: 0.3460 - val_accuracy: 0.8974 - val_loss: 0.3581
# Epoch 38/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 29s 3s/step - accuracy: 0.8458 - loss: 0.3494 - val_accuracy: 0.8974 - val_loss: 0.3549
# Epoch 39/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 29s 3s/step - accuracy: 0.8627 - loss: 0.3391 - val_accuracy: 0.8974 - val_loss: 0.3510
# Epoch 40/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 30s 3s/step - accuracy: 0.8714 - loss: 0.3341 - val_accuracy: 0.8974 - val_loss: 0.3475
# Epoch 41/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 31s 3s/step - accuracy: 0.8372 - loss: 0.3360 - val_accuracy: 0.8974 - val_loss: 0.3448
# Epoch 42/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 32s 3s/step - accuracy: 0.8410 - loss: 0.3309 - val_accuracy: 0.8974 - val_loss: 0.3410
# Epoch 43/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 31s 3s/step - accuracy: 0.8860 - loss: 0.3041 - val_accuracy: 0.8974 - val_loss: 0.3368
# Epoch 44/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 31s 3s/step - accuracy: 0.8743 - loss: 0.2847 - val_accuracy: 0.8974 - val_loss: 0.3331
# Epoch 45/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 30s 3s/step - accuracy: 0.9117 - loss: 0.2792 - val_accuracy: 0.8974 - val_loss: 0.3298
# Epoch 46/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 31s 3s/step - accuracy: 0.8789 - loss: 0.3324 - val_accuracy: 0.8974 - val_loss: 0.3262
# Epoch 47/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 29s 3s/step - accuracy: 0.8812 - loss: 0.3016 - val_accuracy: 0.8974 - val_loss: 0.3246
# Epoch 48/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 31s 3s/step - accuracy: 0.9014 - loss: 0.2746 - val_accuracy: 0.8974 - val_loss: 0.3220
# Epoch 49/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 29s 3s/step - accuracy: 0.8964 - loss: 0.2881 - val_accuracy: 0.8974 - val_loss: 0.3191
# Epoch 50/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 29s 3s/step - accuracy: 0.8879 - loss: 0.2881 - val_accuracy: 0.8974 - val_loss: 0.3169
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 65s 2s/step - accuracy: 0.8797 - loss: 0.3074
#
# ✅ Test Accuracy: 0.8912
# ⏱ Training Time: 1523.69s | Testing Time: 71.49s
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 71s 2s/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     infacted       0.88      0.94      0.91       519
# not_infacted       0.91      0.83      0.87       382
#
#     accuracy                           0.89       901
#    macro avg       0.89      0.88      0.89       901
# weighted avg       0.89      0.89      0.89       901
# ROC–AUC: 0.9490
# I0000 00:00:1761615149.784608      19 devices.cc:67] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 1
# I0000 00:00:1761615149.784831      19 single_machine.cc:361] Starting new session
# I0000 00:00:1761615149.786175      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# op: The nodes are operation kernel type, such as MatMul, Conv2D. Graph nodes belonging to the same type are aggregated together.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# Conv2D                   557.56m float_ops (100.00%, 90.62%)
# DepthwiseConv2dNative    41.43m float_ops (9.38%, 6.73%)
# AddV2                    6.91m float_ops (2.65%, 1.12%)
# Mul                      6.71m float_ops (1.53%, 1.09%)
# MatMul                   2.56m float_ops (0.44%, 0.42%)
# Mean                     62.72k float_ops (0.02%, 0.01%)
# Rsqrt                    34.11k float_ops (0.01%, 0.01%)
# Sub                      17.06k float_ops (0.00%, 0.00%)
# Softmax                  5.00k float_ops (0.00%, 0.00%)
# BiasAdd                  1.00k float_ops (0.00%, 0.00%)
#
# ======================End of Report==========================
#
# ⚙️ GFLOPs per inference (input size (224, 224, 3)): 0.6153 GFLOPs

# %% [markdown]
# # Validation Split
# # train (20%)
# # test (80%)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Example: df should have columns ['filepath', 'label', 'group']

# Train 90% + Test 10%
train_df, test_df = train_test_split(
    df,
    test_size=0.8,
    stratify=df["label"],
    random_state=42
)

# Validation = 10% of total dataset → 10 / 20 = 0.5 of train
train_df, val_df = train_test_split(
    train_df,
    test_size=0.1,
    stratify=train_df["label"],
    random_state=42
)

# Step 3: Print results
print("Train size:", len(train_df))
print("Validation size:", len(val_df))
print("Test size:", len(test_df))

print("\nTrain class distribution:")
print(train_df["label"].value_counts())
print("\nValidation class distribution:")
print(val_df["label"].value_counts())
print("\nTest class distribution:")
print(test_df["label"].value_counts())

# Step 4: Save CSVs
train_df.to_csv("/kaggle/working/train_split.csv", index=False)
val_df.to_csv("/kaggle/working/val_split.csv", index=False)
test_df.to_csv("/kaggle/working/test_split.csv", index=False)

print("\n Train/Val/Test CSVs saved successfully!")
# Out:
# Train size: 231
# Validation size: 26
# Test size: 1030
#
# Train class distribution:
# label
# infacted        133
# not_infacted     98
# Name: count, dtype: int64
#
# Validation class distribution:
# label
# infacted        15
# not_infacted    11
# Name: count, dtype: int64
#
# Test class distribution:
# label
# infacted        593
# not_infacted    437
# Name: count, dtype: int64
#
#  Train/Val/Test CSVs saved successfully!

# %% [markdown]
# # MobileNetV2 Version

# %%
import time
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
from sklearn.preprocessing import label_binarize
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import GlobalAveragePooling2D, Dropout, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# ======= Adjustable Epochs =======
EPOCHS = 50  # 🔁 Change this number anytime
BATCH_SIZE = 32
IMAGE_SIZE = (224, 224)

# ======= Load CSVs =======
train_df = pd.read_csv("/kaggle/working/train_split.csv")
val_df = pd.read_csv("/kaggle/working/val_split.csv")
test_df = pd.read_csv("/kaggle/working/test_split.csv")

# ======= Image Data Generators =======
train_datagen = ImageDataGenerator(rescale=1./255, horizontal_flip=True)
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_gen = train_datagen.flow_from_dataframe(
    train_df, 
    x_col="filepath", 
    y_col="label",
    target_size=IMAGE_SIZE, 
    batch_size=BATCH_SIZE, 
    class_mode="categorical",
    shuffle=True
)

val_gen = val_datagen.flow_from_dataframe(
    val_df, 
    x_col="filepath", 
    y_col="label",
    target_size=IMAGE_SIZE, 
    batch_size=BATCH_SIZE, 
    class_mode="categorical",
    shuffle=False
)

test_gen = test_datagen.flow_from_dataframe(
    test_df, 
    x_col="filepath", 
    y_col="label",
    target_size=IMAGE_SIZE, 
    batch_size=BATCH_SIZE, 
    class_mode="categorical",
    shuffle=False
)

num_classes = len(train_gen.class_indices)


# ======= Build MobileNetV2 Model =======
base_model = MobileNetV2(weights="imagenet", include_top=False, input_shape=(224, 224, 3))
x = GlobalAveragePooling2D()(base_model.output)
x = Dropout(0.3)(x)
output = Dense(num_classes, activation="softmax")(x)

model = Model(inputs=base_model.input, outputs=output)

for layer in base_model.layers:
    layer.trainable = False

model.compile(optimizer=Adam(1e-4), loss="categorical_crossentropy", metrics=["accuracy"])

print("Classes in train set:", train_gen.class_indices)
print("Classes in test set:", test_gen.class_indices)


# ======= Train =======
start_train = time.time()
history = model.fit(train_gen, validation_data=val_gen, epochs=EPOCHS)
train_time = time.time() - start_train

# ======= Evaluate =======
start_test = time.time()
test_loss, test_acc = model.evaluate(test_gen)
test_time = time.time() - start_test

print(f"\n✅ Test Accuracy: {test_acc:.4f}")
print(f"⏱ Training Time: {train_time:.2f}s | Testing Time: {test_time:.2f}s")

# ======= Predictions =======
y_true = test_gen.classes
y_pred_probs = model.predict(test_gen)
y_pred = np.argmax(y_pred_probs, axis=1)
class_labels = list(test_gen.class_indices.keys())

# ======= Metrics =======
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_labels))

# ======= Confusion Matrix =======
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.title("Confusion Matrix — MobileNetV2")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# ======= ROC–AUC for binary classification =======
from sklearn.metrics import roc_auc_score, roc_curve, auc

# Use probability of 'not_infacted' or positive class
y_pred_prob_pos = y_pred_probs[:, 1]  # probability of class 1

auc_score = roc_auc_score(y_true, y_pred_prob_pos)
fpr, tpr, _ = roc_curve(y_true, y_pred_prob_pos)

plt.figure()
plt.plot(fpr, tpr, label=f"Binary ROC (AUC={auc_score:.2f})")
plt.plot([0, 1], [0, 1], 'k--')
plt.title("ROC Curve — MobileNetV2")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.show()

print(f"\nROC–AUC: {auc_score:.4f}")


# ======= GFLOPs =======
import os
import tensorflow as tf
from tensorflow.keras.applications import MobileNetV2
from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2

# ======= Suppress TensorFlow GPU info logs =======
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'  # Only show warnings and errors

# ======= Define your model =======
input_shape = (224, 224, 3)  # Fixed input size
model = MobileNetV2(input_shape=input_shape, include_top=True, weights=None)

# ======= Convert to ConcreteFunction =======
full_model = tf.function(lambda x: model(x))
full_model = full_model.get_concrete_function(
    tf.TensorSpec([1, *input_shape], model.inputs[0].dtype)
)

# ======= Freeze the graph =======
frozen_func = convert_variables_to_constants_v2(full_model)
graph_def = frozen_func.graph.as_graph_def()

# ======= Use TF Profiler to calculate FLOPs =======
with tf.Graph().as_default() as graph:
    tf.import_graph_def(graph_def, name='')
    run_meta = tf.compat.v1.RunMetadata()
    opts = tf.compat.v1.profiler.ProfileOptionBuilder.float_operation()
    flops = tf.compat.v1.profiler.profile(graph=graph, run_meta=run_meta, cmd='op', options=opts)

# ======= Print GFLOPs per inference =======
print(f"\n⚙️ GFLOPs per inference (input size {input_shape}): {flops.total_float_ops / 1e9:.4f} GFLOPs")
# Out:
# Found 231 validated image filenames belonging to 2 classes.
# Found 26 validated image filenames belonging to 2 classes.
# Found 1030 validated image filenames belonging to 2 classes.
# Classes in train set: {'infacted': 0, 'not_infacted': 1}
# Classes in test set: {'infacted': 0, 'not_infacted': 1}
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 35s 3s/step - accuracy: 0.5513 - loss: 0.8398 - val_accuracy: 0.5769 - val_loss: 0.7214
# Epoch 2/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.5649 - loss: 0.7870 - val_accuracy: 0.5769 - val_loss: 0.6981
# Epoch 3/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - accuracy: 0.6239 - loss: 0.7770 - val_accuracy: 0.5769 - val_loss: 0.6793
# Epoch 4/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 0.5817 - loss: 0.7769 - val_accuracy: 0.5769 - val_loss: 0.6641
# Epoch 5/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step - accuracy: 0.6216 - loss: 0.6994 - val_accuracy: 0.5769 - val_loss: 0.6495
# Epoch 6/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.6354 - loss: 0.7003 - val_accuracy: 0.5769 - val_loss: 0.6370
# Epoch 7/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 0
# Epoch 45/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 0.8978 - loss: 0.3197 - val_accuracy: 0.9231 - val_loss: 0.3913
# Epoch 46/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.8404 - loss: 0.3686 - val_accuracy: 0.9231 - val_loss: 0.3883
# Epoch 47/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.8765 - loss: 0.3475 - val_accuracy: 0.9231 - val_loss: 0.3874
# Epoch 48/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 0.8493 - loss: 0.3375 - val_accuracy: 0.9231 - val_loss: 0.3884
# Epoch 49/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 22s 3s/step - accuracy: 0.8395 - loss: 0.3695 - val_accuracy: 0.9231 - val_loss: 0.3874
# Epoch 50/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 0.9049 - loss: 0.2946 - val_accuracy: 0.9231 - val_loss: 0.3848
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 84s 2s/step - accuracy: 0.8790 - loss: 0.3526
#
# ✅ Test Accuracy: 0.8883
# ⏱ Training Time: 1044.02s | Testing Time: 88.61s
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 87s 3s/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     infacted       0.88      0.93      0.91       593
# not_infacted       0.90      0.83      0.86       437
#
#     accuracy                           0.89      1030
#    macro avg       0.89      0.88      0.88      1030
# weighted avg       0.89      0.89      0.89      1030
# ROC–AUC: 0.9423
# I0000 00:00:1761616384.415064      19 devices.cc:67] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 1
# I0000 00:00:1761616384.415301      19 single_machine.cc:361] Starting new session
# I0000 00:00:1761616384.416544      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# op: The nodes are operation kernel type, such as MatMul, Conv2D. Graph nodes belonging to the same type are aggregated together.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# Conv2D                   557.56m float_ops (100.00%, 90.62%)
# DepthwiseConv2dNative    41.43m float_ops (9.38%, 6.73%)
# AddV2                    6.91m float_ops (2.65%, 1.12%)
# Mul                      6.71m float_ops (1.53%, 1.09%)
# MatMul                   2.56m float_ops (0.44%, 0.42%)
# Mean                     62.72k float_ops (0.02%, 0.01%)
# Rsqrt                    34.11k float_ops (0.01%, 0.01%)
# Sub                      17.06k float_ops (0.00%, 0.00%)
# Softmax                  5.00k float_ops (0.00%, 0.00%)
# BiasAdd                  1.00k float_ops (0.00%, 0.00%)
#
# ======================End of Report==========================
#
# ⚙️ GFLOPs per inference (input size (224, 224, 3)): 0.6153 GFLOPs

# %% [markdown]
# # Validation Split
# # train (10%)
# # test (90%)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# =======================
# Step 1: Split dataset into Train (10%) and Test (90%)
# =======================
train_df, test_df = train_test_split(
    df,
    test_size=0.9,  # 90% of total dataset for test
    stratify=df["label"],
    random_state=42
)

# =======================
# Step 2: Split Train into Train (90% of train) and Validation (10% of train)
# =======================
train_df, val_df = train_test_split(
    train_df,
    test_size=0.1,  # 10% of training portion
    stratify=train_df["label"] if len(train_df) > 1 else None,
    random_state=42
)

# =======================
# Step 3: Print results
# =======================
print("Train size:", len(train_df))
print("Validation size:", len(val_df))
print("Test size:", len(test_df))

print("\nTrain class distribution:")
print(train_df["label"].value_counts())
print("\nValidation class distribution:")
print(val_df["label"].value_counts())
print("\nTest class distribution:")
print(test_df["label"].value_counts())

# =======================
# Step 4: Save CSVs
# =======================
train_df.to_csv("/kaggle/working/train_split.csv", index=False)
val_df.to_csv("/kaggle/working/val_split.csv", index=False)
test_df.to_csv("/kaggle/working/test_split.csv", index=False)

print("\nTrain/Val/Test CSVs saved successfully!")
# Out:
# Train size: 115
# Validation size: 13
# Test size: 1159
#
# Train class distribution:
# label
# infacted        66
# not_infacted    49
# Name: count, dtype: int64
#
# Validation class distribution:
# label
# infacted        8
# not_infacted    5
# Name: count, dtype: int64
#
# Test class distribution:
# label
# infacted        667
# not_infacted    492
# Name: count, dtype: int64
#
# Train/Val/Test CSVs saved successfully!

# %% [markdown]
# # MobileNetV2 Version

# %%
import time
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
from sklearn.preprocessing import label_binarize
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import GlobalAveragePooling2D, Dropout, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# ======= Adjustable Epochs =======
EPOCHS = 50  # 🔁 Change this number anytime
BATCH_SIZE = 32
IMAGE_SIZE = (224, 224)

# ======= Load CSVs =======
train_df = pd.read_csv("/kaggle/working/train_split.csv")
val_df = pd.read_csv("/kaggle/working/val_split.csv")
test_df = pd.read_csv("/kaggle/working/test_split.csv")

# ======= Image Data Generators =======
train_datagen = ImageDataGenerator(rescale=1./255, horizontal_flip=True)
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_gen = train_datagen.flow_from_dataframe(
    train_df, 
    x_col="filepath", 
    y_col="label",
    target_size=IMAGE_SIZE, 
    batch_size=BATCH_SIZE, 
    class_mode="categorical",
    shuffle=True
)

val_gen = val_datagen.flow_from_dataframe(
    val_df, 
    x_col="filepath", 
    y_col="label",
    target_size=IMAGE_SIZE, 
    batch_size=BATCH_SIZE, 
    class_mode="categorical",
    shuffle=False
)

test_gen = test_datagen.flow_from_dataframe(
    test_df, 
    x_col="filepath", 
    y_col="label",
    target_size=IMAGE_SIZE, 
    batch_size=BATCH_SIZE, 
    class_mode="categorical",
    shuffle=False
)

num_classes = len(train_gen.class_indices)


# ======= Build MobileNetV2 Model =======
base_model = MobileNetV2(weights="imagenet", include_top=False, input_shape=(224, 224, 3))
x = GlobalAveragePooling2D()(base_model.output)
x = Dropout(0.3)(x)
output = Dense(num_classes, activation="softmax")(x)

model = Model(inputs=base_model.input, outputs=output)

for layer in base_model.layers:
    layer.trainable = False

model.compile(optimizer=Adam(1e-4), loss="categorical_crossentropy", metrics=["accuracy"])

print("Classes in train set:", train_gen.class_indices)
print("Classes in test set:", test_gen.class_indices)


# ======= Train =======
start_train = time.time()
history = model.fit(train_gen, validation_data=val_gen, epochs=EPOCHS)
train_time = time.time() - start_train

# ======= Evaluate =======
start_test = time.time()
test_loss, test_acc = model.evaluate(test_gen)
test_time = time.time() - start_test

print(f"\n✅ Test Accuracy: {test_acc:.4f}")
print(f"⏱ Training Time: {train_time:.2f}s | Testing Time: {test_time:.2f}s")

# ======= Predictions =======
y_true = test_gen.classes
y_pred_probs = model.predict(test_gen)
y_pred = np.argmax(y_pred_probs, axis=1)
class_labels = list(test_gen.class_indices.keys())

# ======= Metrics =======
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_labels))

# ======= Confusion Matrix =======
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.title("Confusion Matrix — MobileNetV2")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# ======= ROC–AUC for binary classification =======
from sklearn.metrics import roc_auc_score, roc_curve, auc

# Use probability of 'not_infacted' or positive class
y_pred_prob_pos = y_pred_probs[:, 1]  # probability of class 1

auc_score = roc_auc_score(y_true, y_pred_prob_pos)
fpr, tpr, _ = roc_curve(y_true, y_pred_prob_pos)

plt.figure()
plt.plot(fpr, tpr, label=f"Binary ROC (AUC={auc_score:.2f})")
plt.plot([0, 1], [0, 1], 'k--')
plt.title("ROC Curve — MobileNetV2")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.show()

print(f"\nROC–AUC: {auc_score:.4f}")


# ======= GFLOPs =======
import os
import tensorflow as tf
from tensorflow.keras.applications import MobileNetV2
from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2

# ======= Suppress TensorFlow GPU info logs =======
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'  # Only show warnings and errors

# ======= Define your model =======
input_shape = (224, 224, 3)  # Fixed input size
model = MobileNetV2(input_shape=input_shape, include_top=True, weights=None)

# ======= Convert to ConcreteFunction =======
full_model = tf.function(lambda x: model(x))
full_model = full_model.get_concrete_function(
    tf.TensorSpec([1, *input_shape], model.inputs[0].dtype)
)

# ======= Freeze the graph =======
frozen_func = convert_variables_to_constants_v2(full_model)
graph_def = frozen_func.graph.as_graph_def()

# ======= Use TF Profiler to calculate FLOPs =======
with tf.Graph().as_default() as graph:
    tf.import_graph_def(graph_def, name='')
    run_meta = tf.compat.v1.RunMetadata()
    opts = tf.compat.v1.profiler.ProfileOptionBuilder.float_operation()
    flops = tf.compat.v1.profiler.profile(graph=graph, run_meta=run_meta, cmd='op', options=opts)

# ======= Print GFLOPs per inference =======
print(f"\n⚙️ GFLOPs per inference (input size {input_shape}): {flops.total_float_ops / 1e9:.4f} GFLOPs")
# Out:
# Found 115 validated image filenames belonging to 2 classes.
# Found 13 validated image filenames belonging to 2 classes.
# Found 1159 validated image filenames belonging to 2 classes.
# Classes in train set: {'infacted': 0, 'not_infacted': 1}
# Classes in test set: {'infacted': 0, 'not_infacted': 1}
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 26s 4s/step - accuracy: 0.5904 - loss: 0.7246 - val_accuracy: 0.3846 - val_loss: 0.9052
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 11s 3s/step - accuracy: 0.5944 - loss: 0.7835 - val_accuracy: 0.4615 - val_loss: 0.8898
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.6048 - loss: 0.7099 - val_accuracy: 0.4615 - val_loss: 0.8813
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 11s 3s/step - accuracy: 0.5782 - loss: 0.7945 - val_accuracy: 0.4615 - val_loss: 0.8774
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.5814 - loss: 0.7869 - val_accuracy: 0.4615 - val_loss: 0.8743
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.6255 - loss: 0.6737 - val_accuracy: 0.4615 - val_loss: 0.8722
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.5260 - loss: 0.7593 - val_accuracy: 0.5385 - val_loss: 0.8701
# Epoch 8/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.5870 - loss: 0.6414 - val_accuracy: 0.5385 - val_loss: 0.8670
# Epoch 9/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.7215 - loss: 0.5982 - val_accuracy: 0.5385 - val_loss: 0.8653
# Epoch 10/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.6476 - loss: 0.6641 - val_accuracy: 0.5385 - val_loss: 0.8634
# Epoch 11/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.6167 - loss: 0.7265 - val_accuracy: 0.5385 - val_loss: 0.8600
# Epoch 12/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.6532 - loss: 0.6199 - val_accuracy: 0.5385 - val_loss: 0.8567
# Epoch 13/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.6392 - loss: 0.7008 - val_accuracy: 0.4615 - val_loss: 0.8532
# Epoch 14/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.6316 - loss: 0.6583 - val_accuracy: 0.4615 - val_loss: 0.8490
# Epoch 15/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - accuracy: 0.6575 - loss: 0.6522 - val_accuracy: 0.4615 - val_loss: 0.8453
# Epoch 16/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 11s 3s/step - accuracy: 0.6923 - loss: 0.5518 - val_accuracy: 0.4615 - val_loss: 0.8417
# Epoch 17/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 11s 3s/step - accuracy: 0.6900 - loss: 0.6091 - val_accuracy: 0.4615 - val_loss: 0.8381
# Epoch 18/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.7314 - loss: 0.5426 - val_accuracy: 0.4615 - val_loss: 0.8341
# Epoch 19/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.7297 - loss: 0.5617 - val_accuracy: 0.4615 - val_loss: 0.8314
# Epoch 20/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 11s 3s/step - accuracy: 0.7425 - loss: 0.6173 - val_accuracy: 0.4615 - val_loss: 0.8269
# Epoch 21/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 11s 3s/step - accuracy: 0.6876 - loss: 0.5707 - val_accuracy: 0.4615 - val_loss: 0.8232
# Epoch 22/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.6962 - loss: 0.6079 - val_accuracy: 0.4615 - val_loss: 0.8195
# Epoch 23/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.7283 - loss: 0.5326 - val_accuracy: 0.4615 - val_loss: 0.8140
# Epoch 24/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 11s 3s/step - accuracy: 0.7575 - loss: 0.5412 - val_accuracy: 0.4615 - val_loss: 0.8086
# Epoch 25/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.7465 - loss: 0.4787 - val_accuracy: 0.4615 - val_loss: 0.8035
# Epoch 26/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 11s 3s/step - accuracy: 0.6324 - loss: 0.5461 - val_accuracy: 0.4615 - val_loss: 0.7987
# Epoch 27/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 11s 3s/step - accuracy: 0.7255 - loss: 0.5494 - val_accuracy: 0.4615 - val_loss: 0.7943
# Epoch 28/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.7840 - loss: 0.4866 - val_accuracy: 0.4615 - val_loss: 0.7909
# Epoch 29/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.7245 - loss: 0.5119 - val_accuracy: 0.4615 - val_loss: 0.7862
# Epoch 30/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 11s 3s/step - accuracy: 0.7690 - loss: 0.4873 - val_accuracy: 0.4615 - val_loss: 0.7821
# Epoch 31/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 11s 3s/step - accuracy: 0.7118 - loss: 0.4703 - val_accuracy: 0.5385 - val_loss: 0.7779
# Epoch 32/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.7593 - loss: 0.5631 - val_accuracy: 0.5385 - val_loss: 0.7737
# Epoch 33/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 12s 3s/step - accuracy: 0.7482 - loss: 0.4799 - val_accuracy: 0.6154 - val_loss: 0.7687
# Epoch 34/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.7836 - loss: 0.4722 - val_accuracy: 0.6154 - val_loss: 0.7604
# Epoch 35/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 12s 3s/step - accuracy: 0.7612 - loss: 0.5108 - val_accuracy: 0.6154 - val_loss: 0.7551
# Epoch 36/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 11s 3s/step - accuracy: 0.7733 - loss: 0.4621 - val_accuracy: 0.6154 - val_loss: 0.7491
# Epoch 37/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 11s 3s/step - accuracy: 0.8079 - loss: 0.4453 - val_accuracy: 0.6154 - val_loss: 0.7429
# Epoch 38/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.7932 - loss: 0.4857 - val_accuracy: 0.6154 - val_loss: 0.7376
# Epoch 39/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 11s 3s/step - accuracy: 0.7225 - loss: 0.5380 - val_accuracy: 0.6154 - val_loss: 0.7330
# Epoch 40/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.7905 - loss: 0.4794 - val_accuracy: 0.6154 - val_loss: 0.7297
# Epoch 41/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.7287 - loss: 0.4809 - val_accuracy: 0.6154 - val_loss: 0.7261
# Epoch 42/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.7852 - loss: 0.4418 - val_accuracy: 0.6154 - val_loss: 0.7231
# Epoch 43/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.8221 - loss: 0.4030 - val_accuracy: 0.6154 - val_loss: 0.7206
# Epoch 44/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.7397 - loss: 0.5142 - val_accuracy: 0.6154 - val_loss: 0.7184
# Epoch 45/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.7395 - loss: 0.5397 - val_accuracy: 0.5385 - val_loss: 0.7154
# Epoch 46/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 12s 4s/step - accuracy: 0.8161 - loss: 0.3759 - val_accuracy: 0.6154 - val_loss: 0.7136
# Epoch 47/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.7734 - loss: 0.4748 - val_accuracy: 0.6154 - val_loss: 0.7113
# Epoch 48/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 12s 3s/step - accuracy: 0.7872 - loss: 0.3945 - val_accuracy: 0.6154 - val_loss: 0.7089
# Epoch 49/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.8393 - loss: 0.4234 - val_accuracy: 0.6154 - val_loss: 0.7074
# Epoch 50/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 11s 3s/step - accuracy: 0.8387 - loss: 0.3985 - val_accuracy: 0.6154 - val_loss: 0.7055
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 93s 2s/step - accuracy: 0.7542 - loss: 0.4952
#
# ✅ Test Accuracy: 0.7921
# ⏱ Training Time: 543.33s | Testing Time: 97.98s
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 95s 2s/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     infacted       0.78      0.88      0.83       667
# not_infacted       0.81      0.67      0.73       492
#
#     accuracy                           0.79      1159
#    macro avg       0.80      0.78      0.78      1159
# weighted avg       0.79      0.79      0.79      1159
# ROC–AUC: 0.8659
# I0000 00:00:1761617135.308961      19 devices.cc:67] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 1
# I0000 00:00:1761617135.309152      19 single_machine.cc:361] Starting new session
# I0000 00:00:1761617135.310341      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# op: The nodes are operation kernel type, such as MatMul, Conv2D. Graph nodes belonging to the same type are aggregated together.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# Conv2D                   557.56m float_ops (100.00%, 90.62%)
# DepthwiseConv2dNative    41.43m float_ops (9.38%, 6.73%)
# AddV2                    6.91m float_ops (2.65%, 1.12%)
# Mul                      6.71m float_ops (1.53%, 1.09%)
# MatMul                   2.56m float_ops (0.44%, 0.42%)
# Mean                     62.72k float_ops (0.02%, 0.01%)
# Rsqrt                    34.11k float_ops (0.01%, 0.01%)
# Sub                      17.06k float_ops (0.00%, 0.00%)
# Softmax                  5.00k float_ops (0.00%, 0.00%)
# BiasAdd                  1.00k float_ops (0.00%, 0.00%)
#
# ======================End of Report==========================
#
# ⚙️ GFLOPs per inference (input size (224, 224, 3)): 0.6153 GFLOPs
